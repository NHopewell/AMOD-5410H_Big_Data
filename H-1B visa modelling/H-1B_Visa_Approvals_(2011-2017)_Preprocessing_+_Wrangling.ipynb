# %% [markdown]
# # H-1B Visa Approvals  (2011-2017): Part 1
#
#
# ## Preprocessing and Wrangling
#
#
# **AMOD-5410H: Big Data**
# **Winter 2018**
# **Nicholas Hopewell - 0496633**

# %% [markdown]
# **Overview:**
# The original source of these data comes from the US department of labour. H-1B visas are a category of employment-based, non-immigrant visas for temporary foreign workers in the United States. For a foreign national to apply for H1-B visa, a US employer must offer them a job and submit a petition for a H-1B visa to the US immigration department. This is also the most common visa status applied for and held by international students once they complete college or higher education and begin working in a full-time position.
#
# **Data:**
# This dataset contains seven year's worth of H-1B petition data, with a little over 3.6 million records in total. The columns in the final dataset (after preprocessing and explpratory analysis) include case status, employer name, worksite coordinates, job title, prevailing wage, occupation code, and year filed.
#
# **Note:** The fully cleaned and combined version of these data appeared partially on Kaggle.com: https://www.kaggle.com/nsharan/h-1b-visa
#
# For the Kaggle data, the data wrangling and cleaning was done with R (mostly with dplyr) - this process will be replicated here with Python (see below):
#
# **The current work:** I will not use the cleaned and combined data but instead begin with the raw separate data files and do my own cleaning, wrangling, and analysis of the data with Python. I will also be using more recently available data in addition to that included on kaggle. My goal is to arrive at the same cleaned state as the data used on Kaggle by using Python and Pandas/Numpy for cleaning and wrangling instead of R and dplyr. I will also replicate some of this process with pyspark as well.
#
# It should also be noted that I greatly improved the data wrangling process compared to the original process done in R.
#
# The supervised learning stage will also be done with both python ml libraries (scikit) and spark ml libraries (mllib). I may also do this phase with R and Caret as well as with sparklyr. The R component would not be included in this notebook but instead in an Rmarkdown file.

# %%
import pandas as pd
import numpy as np
# to avoid scientific notation
pd.options.display.float_format = '{:.2f}'.format
# filte out package warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# The data come from seven separate .csv files. First, I need to create a main data frame as an empty frame which I will concatenate the data from each excel file to.

# %%
#empty dframe to populate
main_frame = pd.DataFrame()

# %% [markdown]
# Now I can read in each of the data files. Data before 2015 had slightly different variable names but the same information. These columns will be renamed to match the new variable names. Some of the unnecessary columns will also be filtered out of the data.

# %%
# for each year, year is injected into the f-string and the apporpriate file is read.
# file_path is created as a 1-dimensional list - if it were not within the forloop, list comprehension would
# include an imbedded for

for year in range(2011, 2018):
    print(f"***Reading {year} data files...")
    file_path = [f"C:/Users/nicho/Desktop/big data course proj/H-1B data/H-1B_{year}.xlsx"]
    my_df = pd.read_excel(file_path[0])
    
    # rename old columns to match
    if year < 2015:
        print("Renaming old columns...")
        my_df.rename(columns={'LCA_CASE_NUMBER' : 'CASE_NUMBER', 
                             'STATUS' : 'CASE_STATUS',
                             'LCA_CASE_EMPLOYER_NAME' : 'EMPLOYER_NAME', 
                             'LCA_CASE_SOC_NAME' : 'SOC_NAME',
                             'LCA_CASE_SOC_CODE' : 'SOC_CODE', 
                             'LCA_CASE_JOB_TITLE' : 'JOB_TITLE',
                             'FULL_TIME_POS' : 'FULL_TIME_POSITION', 
                             'PW_1' : 'PREVAILING_WAGE', 
                             'PW_UNIT_1' : 'PW_UNIT_OF_PAY',
                             'LCA_CASE_WORKLOC1_CITY' : 'WORKSITE_CITY',
                             'LCA_CASE_WORKLOC1_STATE' : 'WORKSITE_STATE'}, inplace=True)
    
    # add year
    print("Adding year column...")
    my_df['YEAR'] = str(year)
    
    print(f"Dimension of data frame: {my_df.shape}")
    
    # select appropriate columns
    print("Selecting required columns...")
    my_df = my_df[['CASE_NUMBER',
                    'CASE_STATUS',
                    'EMPLOYER_NAME',
                    'SOC_NAME',
                    'SOC_CODE',
                    'JOB_TITLE',
                    'FULL_TIME_POSITION',
                    'PREVAILING_WAGE',
                    'PW_UNIT_OF_PAY',
                    'WORKSITE_CITY',
                    'WORKSITE_STATE',
                    'YEAR']]
    
    # merge data into main dframe
    print("Joining data onto main frame...")
    main_frame = pd.concat([main_frame, my_df])
    
    print(f"Dimension of main data frame: {main_frame.shape}\n")
# Out:
# ***Reading 2011 data files...
# Renaming old columns...
# Adding year column...
# Dimension of data frame: (358857, 36)
# Selecting required columns...
# Joining data onto main frame...
# Dimension of main data frame: (358857, 12)
#
# ***Reading 2012 data files...
# Renaming old columns...
# Adding year column...
# Dimension of data frame: (415845, 36)
# Selecting required columns...
# Joining data onto main frame...
# Dimension of main data frame: (774702, 12)
#
# ***Reading 2013 data files...
# Renaming old columns...
# Adding year column...
# Dimension of data frame: (442275, 36)
# Selecting required columns...
# Joining data onto main frame...
# Dimension of main data frame: (1216977, 12)
#
# ***Reading 2014 data files...
# Renaming old columns...
# Adding year column...
# Dimension of data frame: (519504, 36)
# Selecting required columns...
# Joining data onto main frame...
# Dimension of main data frame: (1736481, 12)
#
# ***Reading 2015 data files...
# Adding year column...
# Dimension of data frame: (618804, 41)
# Selecting required columns...
# Joining data onto main frame...
# Dimension of main data frame: (2355285, 12)
#
# ***Reading 2016 data files...
# Adding year column...
# Dimension of data frame: (647852, 41)
# Selecting required columns...
# Joining data onto main frame...
# Dimension of main data frame: (3003137, 12)
#
# ***Reading 2017 data files...
# Adding year column...
# Dimension of data frame: (624650, 53)
# Selecting required columns...
# Joining data onto main frame...
# Dimension of main data frame: (3627787, 12)

# %% [markdown]
# 3,627,787 rows x 12 columns.

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# Only including the attributes used. Complete dictionary can be found at: https://www.foreignlaborcert.doleta.gov/docs/Performance_Data/Disclosure/FY15-FY16/H-1B_FY16_Record_Layout.pdf
#
# * **CASE_NUMBER:** Unique identifier assigned to each application submitted for processing to the Chicago National Processing Center.
# * **CASE_STATUS:** Status associated with the last significant event or decision. Valid values include "Certified," "Certified-Withdrawn," Denied," and "Withdrawn."
# * **EMPLOYER_NAME:** Name of employer submitting labor condition application.
# * **SOC_NAME:** Occupational name associated with the SOC_CODE.
# * **SOC_CODE:** Occupational code associated with the job being requested for temporary labor condition, as classified by the Standard Occupational Classification (SOC) System.
# * **JOB_TITLE:** Title of the job.
# * **FULL_TIME_POSITION:** Y = Full Time Position; N = Part Time Position.
# * **PREVAILING_WAGE:** Prevailing Wage for the job being requested for temporary labor condition.
# * **PW_UNIT_OF_PAY:** Unit of Pay. Valid values include "Daily (DAI)," "Hourly (HR)," "Bi-weekly (BI)," "Weekly (WK)," "Monthly (MTH)," and "Yearly (YR)."
# * **WORKSITE_CITY:** City information of the foreign worker's intended area of employment.
# * **WORKSITE_STATE:** State information of the foreign worker's intended area of employment.
# * **YEAR:** Year petition was filed.

# %% [markdown]
# Here is what a portion of the data looks like. Notice the 'YEAR' column. As the separate data files have been concatenated by rows, the oldest data (from 2011) appears first.

# %%
main_frame.head(5)
# Out:
#           CASE_NUMBER          CASE_STATUS                  EMPLOYER_NAME  \
# 0  I-200-09124-371007            CERTIFIED   WILLISTON NORTHAMPTON SCHOOL
# 1  I-200-09125-717448            CERTIFIED                    NYFIX, INC.
# 2  I-200-09126-530125  CERTIFIED-WITHDRAWN  TGS-NOPEC GEOPHYSICAL COMPANY
# 3  I-200-09127-370154            CERTIFIED                AFREN USA, INC.
# 4  I-200-09127-334015            CERTIFIED                BA-INSIGHT, LLC
#
#                                     SOC_NAME    SOC_CODE  \
# 0       Teachers and Instructors, All Other*     25-3999
# 1  Computer Software Engineers, Applications  15-1031.00
# 2  Computer Software Engineers, Applications  15-1031.00
# 3                       Engineering Managers  11-9041.00
# 4               Computer Support Specialists  15-1041.00
#
#                                  JOB_TITLE FULL_TIME_POSITION PREVAILING_WAGE  \
# 0                          CHINESE TEACHER                  Y           23350
# 1                          PROJECT MANAGER                  Y          101088
# 2  PRINCIPAL TRAINER / DEVELOPMENT ANALYST                  Y           77480
# 3                         DRILLING MANAGER                  Y          165506
# 4               TECHNICAL SUPPORT ENGINEER                  Y           62358
#
#   PW_UNIT_OF_PAY  WORKSITE_CITY WORKSITE_STATE  YEAR
# 0           Year    EASTHAMPTON             MA  2011
# 1           Year       NEW YORK             NY  2011
# 2           Year        HOUSTON             TX  2011
# 3           Year  THE WOODLANDS             TX  2011
# 4           Year         BOSTON             MA  2011

# %% [markdown]
# The most recent data from 2017...

# %%
main_frame.tail(5)
# Out:
#                CASE_NUMBER          CASE_STATUS  \
# 624645  I-200-16188-449352  CERTIFIED-WITHDRAWN
# 624646  I-200-16309-239165            CERTIFIED
# 624647  I-200-16363-692687            CERTIFIED
# 624648  I-200-17055-511599            CERTIFIED
# 624649  I-200-17068-828736            CERTIFIED
#
#                                 EMPLOYER_NAME  \
# 624645                        FAST SWITCH LTD
# 624646  MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 624647  MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 624648  MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 624649    PARK VIEW TRAVEL BEVERLY HILLS, LLC
#
#                                                  SOC_NAME SOC_CODE  \
# 624645                  SOFTWARE DEVELOPERS, APPLICATIONS  15-1132
# 624646                                         PHYSICISTS  19-2012
# 624647  GEOSCIENTISTS, EXCEPT HYDROLOGISTS AND GEOGRAP...  19-2042
# 624648                                MATERIALS ENGINEERS  17-2131
# 624649            MEETING, CONVENTION, AND EVENT PLANNERS  13-1121
#
#                                 JOB_TITLE FULL_TIME_POSITION PREVAILING_WAGE  \
# 624645              SENIOR JAVA DEVELOPER                  Y           37.12
# 624646             POSTDOCTORAL ASSOCIATE                  Y        50398.00
# 624647                 RESEARCH SCIENTIST                  Y        61069.00
# 624648             POSTDOCTORAL ASSOCIATE                  Y        41392.00
# 624649  EVENTS AND INCENTIVES COORDINATOR                  Y        45198.00
#
#        PW_UNIT_OF_PAY  WORKSITE_CITY WORKSITE_STATE  YEAR
# 624645           Hour         DUBLIN             OH  2017
# 624646           Year      CAMBRIDGE             MA  2017
# 624647           Year      CAMBRIDGE             MA  2017
# 624648           Year      CAMBRIDGE             MA  2017
# 624649           Year  BEVERLY HILLS             CA  2017

# %% [markdown]
# I will save this data file as a master file before making a copy of it for analysis.

# %%
# write to csv
main_frame.to_csv("./Desktop/big data course proj/H-1B data/complete_data_v1.csv", index = False)

# %%
# make a copy of the dframe
h1b_data = main_frame
# confirm copy
h1b_data.shape
# Out:
# (3627787, 12)

# %%
# verify pd df:
type(h1b_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Working with the copied data, it is important to see whether python has classified the data types appropriately:

# %%
h1b_data.dtypes
# Out:
# CASE_NUMBER           object
# CASE_STATUS           object
# EMPLOYER_NAME         object
# SOC_NAME              object
# SOC_CODE              object
# JOB_TITLE             object
# FULL_TIME_POSITION    object
# PREVAILING_WAGE       object
# PW_UNIT_OF_PAY        object
# WORKSITE_CITY         object
# WORKSITE_STATE        object
# YEAR                  object
# dtype: object

# %% [markdown]
# Notice every variable is classified as an object. The native python type equivalent to a pandas object type is a string. The object pandas data type is the most generic data type and is assigned to any column which contains multiple data type or if the data types could not be classified correctly (common with larger amounts of data). If this becomes a problem they should be explicitly changed. Wage is really the only one which should be changed.

# %% [markdown]
# For each column, how many rows contain missing data:

# %%
h1b_data.isnull().sum()
# Out:
# CASE_NUMBER                0
# CASE_STATUS                0
# EMPLOYER_NAME            417
# SOC_NAME               18023
# SOC_CODE                 511
# JOB_TITLE                328
# FULL_TIME_POSITION    648166
# PREVAILING_WAGE          666
# PW_UNIT_OF_PAY           738
# WORKSITE_CITY            529
# WORKSITE_STATE           474
# YEAR                       0
# dtype: int64

# %% [markdown]
# A significant number of records do not contain information on whether the position was full time ('Y') or not ('N'). Just under 18% of the data.

# %%
# proportion with missing position data
h1b_data['FULL_TIME_POSITION'].isnull().sum() / len(h1b_data.index)
# Out:
# 0.17866704963659663

# %% [markdown]
# ### Comparing wages

# %% [markdown]
# Upon researching issues with prevailing wage calculations, americanimmigrationcouncil.org stated there are a few issues:
#
# > "Calculating the prevailing wage in an occupation is critical to ensuring that foreign-born workers do not get paid more than native-born workers (or vice versa) for performing comparable tasks. Pay inequity could give an unfair advantage to one group of workers over another. It is for that reason that the prevailing wage determination is such an important aspect of the employment-based immigration system.
#
# > However, there are three sets of problems surrounding the way in which a current Prevailing Wage Determination is issued in our high-skilled immigration system: (1) the underlying data is based on very broad pay ranges; (2) there are intrinsic weaknesses in issuing prevailing wage determinations for specific positions offered by an individual employer based on generalized occupational employment statistics; and (3) the current system does not reflect education, experience, and supervision."

# %% [markdown]
# To make sure these calculations were done and entered validly, it is important to explore the prevailing wage data. Inspecting wages, pay was not recorded in the same time intervals across the board. To make comparisons, this scale must be of equal time intervals for all records.
#
# Here are the counts for the different units of pay used in the data set:

# %%
# group by unit of pay, summarize as count
units = h1b_data.groupby('PW_UNIT_OF_PAY').agg('count').iloc[:,1]
units
# Out:
# PW_UNIT_OF_PAY
# Bi-Weekly        377
# Hour          270919
# Month           3708
# Week            1756
# Year         3350289
# Name: CASE_STATUS, dtype: int64

# %%
# proportions
units/len(h1b_data.index)
# Out:
# PW_UNIT_OF_PAY
# Bi-Weekly   0.00
# Hour        0.07
# Month       0.00
# Week        0.00
# Year        0.92
# Name: CASE_STATUS, dtype: float64

# %% [markdown]
# The large majority of records are associated with a yearly unit of pay (> 92% ), a fair number include hourly unit of pay (> 7% ), while other units of pay are barely represented in the dataset. These units of pay can all easily be converted to match the yearly unit of pay to make all records consistent.

# %%
h1b_data.iloc[1,8] == 'Year'
# Out:
# True

# %%
# to convert units of pay
def pay_to_yearly(wage, unit):
    if unit == "Year":
        result = wage
    elif unit   == "Week":
        result = 52 * wage
    elif unit   == "Month":
        result = 12 * wage
    elif unit == "Hour":
        result = 2080 * wage
    else :
        result = 26 * wage
    return result

# %% [markdown]
# Attempting to convert the prevailing wage column to numeric yields an error. Row 455172 cannot be converted to type numeric.

# %%
h1b_data.iloc[455172, 7:9]
# Out:
# PREVAILING_WAGE    9.78
# PW_UNIT_OF_PAY     Hour
# Name: 96315, dtype: object

# %% [markdown]
# Now it is clear that this record contains a range of values separated by a hyphen. This individuals wage is \$20 to \$70 an hour. Not very helpful to us. How many records contain a similar issue?

# %%
sum(h1b_data.PREVAILING_WAGE.str.contains('-', na = False))
# Out:
# 1

# %% [markdown]
# Thankfully, it seems that only the one record has this issue and can simply be removed.

# %%
# drop record
h1b_data = h1b_data[~h1b_data.PREVAILING_WAGE.str.contains('-', na = False)]

# %% [markdown]
# Now wages can be converted and units of pay can be standardized to yearly pay for all records.

# %%
# drop missing data from col, transform to num + str
h1b_data = h1b_data.dropna(subset=['PW_UNIT_OF_PAY'])
h1b_data['PREVAILING_WAGE'] = h1b_data['PREVAILING_WAGE'].transform(pd.to_numeric)
h1b_data['PW_UNIT_OF_PAY'] = h1b_data['PW_UNIT_OF_PAY'].astype(str)

# %% [markdown]
# Before prevailing wage is altered, it is crucial to understand some basic information about the wages to ensure applying any function results in intended outcomes. Summary statistics:

# %%
#summary statistics:
h1b_data['PREVAILING_WAGE'].describe()
# Out:
# count     3626977.00
# mean        67774.66
# std        782127.16
# min             0.00
# 25%         52395.00
# 50%         64501.00
# 75%         81515.00
# max     820132347.00
# Name: PREVAILING_WAGE, dtype: float64

# %% [markdown]
# Something which immediately jumps out is the very high max value and seemingly also very high standard deviation for wages. This would imply that there are some huge outliers which are pulling the mean wage up and hugely inflating the standard deviation. The standard deviation is only slightly being impacted by the outliers, the huge SD mainly is a result of having prevailing wages in multiple units (some of which are orders of magnitude different). The mean here is also very misleading, in fact, it is artificially low due to the presence of some units of pay being sub $100. The max values are most interesting from these data.
#
# The median prevailing wage will give a better idea of central tendency but will still be biased due to the presence of multiple scales:

# %%
h1b_data['PREVAILING_WAGE'].median()
# Out:
# 64501.0

# %% [markdown]
#  Let's inspect the records with the highest wages to see if possible data entry errors have occurred:

# %%
h1b_data.nlargest(40, 'PREVAILING_WAGE')
# Out:
#                CASE_NUMBER CASE_STATUS  \
# 407395  I-200-14163-698141      DENIED
# 33769   I-200-12314-455612      DENIED
# 132271  I-200-11067-452033      DENIED
# 281084  I-200-14077-075359      DENIED
# 401912  I-200-14160-081071      DENIED
# 222828  I-200-17064-887537      DENIED
# 188236  I-200-11108-332859      DENIED
# 93267   I-200-12005-031899   WITHDRAWN
# 327136  I-200-11236-463527      DENIED
# 317641  I-200-13141-752670      DENIED
# 513363  I-203-14031-891269      DENIED
# 326811  I-200-12167-578347      DENIED
# 106767  I-200-17013-437831      DENIED
# 337092  I-200-13161-861134      DENIED
# 375277  I-200-12223-346038      DENIED
# 223738  I-200-12107-500629      DENIED
# 240543  I-200-12116-507507      DENIED
# 243102  I-200-13084-581875      DENIED
# 480761  I-200-15155-159837      DENIED
# 382806  I-200-12228-591238   CERTIFIED
# 513354  I-203-14031-739144   WITHDRAWN
# 513377  I-203-14034-137426      DENIED
# 389791  I-200-14148-045695   WITHDRAWN
# 49886   I-200-13303-012739      DENIED
# 230987  I-200-14067-257597      DENIED
# 242436  I-200-14070-253653   WITHDRAWN
# 273689  I-200-11187-239095      DENIED
# 77516   I-200-13335-697813      DENIED
# 321052  I-200-15072-304243   WITHDRAWN
# 247608  I-200-11161-863052      DENIED
# 54155   I-200-10336-244124      DENIED
# 319761  I-200-11229-295822      DENIED
# 12432   I-200-10285-696414      DENIED
# 155642  I-200-11083-213136      DENIED
# 293324  I-200-14078-494088      DENIED
# 188949  I-200-13073-010429      DENIED
# 82207   I-200-11007-255804      DENIED
# 115701  I-200-11047-930261      DENIED
# 314951  I-200-11225-958580      DENIED
# 138393  I-200-11070-484375      DENIED
#
#                                             EMPLOYER_NAME  \
# 407395                             DISCOVER PRODUCTS INC.
# 33769                                       IDEXCEL, INC.
# 132271                                COMMONHEALTH ACTION
# 281084                                         ARKRIT LLC
# 401912                    HOWARD HUGHES MEDICAL INSTITUTE
# 222828                                          WIPRO LLC
# 188236                                XORIANT CORPORATION
# 93267                  UNIVERSITY OF CALIFORNIA, BERKELEY
# 327136                                     BYTEWARE, INC.
# 317641           MARYLAND INPATIENT CARE SPECIALISTS, LLC
# 513363                             FOUND ORGANIC USA, LLC
# 326811                                 AVM SOFTWARE, INC.
# 106767                    COMMUNITY HEALTH SERVICES, INC.
# 337092                                  HOPSTOP.COM, INC.
# 375277                       SMALL SMILES OF ROANOKE, LLC
# 223738                      ANIMEX LATIN PRODUCTIONS INC.
# 240543                      ANIMEX LATIN PRODUCTIONS INC.
# 243102                                  JD SOFTWARE, INC.
# 480761                                 I&I SOFTWARE, INC.
# 382806                        SELECT SOURCE INTERNATIONAL
# 513354                             FOUND ORGANIC USA, LLC
# 513377                             FOUND ORGANIC USA, LLC
# 389791                                    IBM CORPORATION
# 49886                                  UNISYS CORPORATION
# 230987                                        AMDOCS INC.
# 242436                                        AMDOCS INC.
# 273689            SPECIAL METALS WELDING PRODUCTS COMPANY
# 77516                             BAZILIO COBB ASSOCIATES
# 321052                  ATLAS SOFTWARE TECHNOLOGIES, INC.
# 247608                                  HOWARD UNIVERSITY
# 54155                                 AMERICAN MARINE LLC
# 319761                      SOFTWARE ANALYSTS CORPORATION
# 12432   UNIVERSITY OF TEXAS HEALTH SCIENCE CENTER AT S...
# 155642                               R & L CARRIERS, INC.
# 293324                    ABC IMAGING OF WASHINGTON, INC.
# 188949                                    NCR CORPORATION
# 82207                                TERRA INFOTECH, INC.
# 115701                                MONMOUTH UNIVERSITY
# 314951                         ARCADIUM TECHNOLOGIES, LLC
# 138393                                COMMONHEALTH ACTION
#
#                                                  SOC_NAME    SOC_CODE  \
# 407395                                      Statisticians     15-2041
# 33769                   Software Developers, Applications     15-1132
# 132271               Medical and Health Services Managers  11-9111.00
# 281084                          Computer Systems Analysts     15-1121
# 401912                         Life Scientists, All Other     19-1099
# 222828                    COMPUTER OCCUPATIONS, ALL OTHER     15-1199
# 188236      Computer Software Engineers, Systems Software  15-1032.00
# 93267                       Biochemists and Biophysicists     19-1021
# 327136                          Computer Systems Analysts     15-1121
# 317641                                Internists, General     29-1063
# 513363                                 Marketing Managers     11-2021
# 326811                    General and Operations Managers     11-1021
# 106767               MEDICAL AND HEALTH SERVICES MANAGERS  11-9111.00
# 337092              Software Developers, Systems Software     15-1133
# 375277                                  Dentists, General     29-1021
# 223738                            Producers and Directors     27-2012
# 240543                            Producers and Directors     27-2012
# 243102                  Software Developers, Applications     15-1132
# 480761                  SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 382806                   Computer Occupations, All Other*     15-1799
# 513354  Market Research Analysts and Marketing Special...     13-1161
# 513377  Market Research Analysts and Marketing Special...     13-1161
# 389791                  Software Developers, Applications     15-1132
# 49886                     Computer Occupations, All Other     15-1199
# 230987                    Computer Occupations, All Other     15-1199
# 242436                    Computer Occupations, All Other     15-1199
# 273689                               Engineers, All Other     17-2199
# 77516                       Information Security Analysts     15-1122
# 321052                  SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 247608           Computer Science Teachers, Postsecondary  25-1021.00
# 54155          Business Operations Specialists, All Other  13-1199.99
# 319761                  Software Developers, Applications     15-1132
# 12432          Health Specialties Teachers, Postsecondary  25-1071.00
# 155642                                                NaN     15-1031
# 293324                  Software Developers, Applications     15-1132
# 188949                            Database Administrators     15-1141
# 82207                                Computer Programmers  15-1021.00
# 115701                  Education Teachers, Postsecondary  25-1081.00
# 314951                  Software Developers, Applications     15-1132
# 138393               Medical and Health Services Managers  11-9111.00
#
#                                                 JOB_TITLE FULL_TIME_POSITION  \
# 407395                                    PROJECT MANAGER                  Y
# 33769                                      .NET DEVELOPER                  Y
# 132271                PROGRAM MANAGER (POSITIVE PATHWAYS)                  Y
# 281084                                 PROGRAMMER/ANALYST                  Y
# 401912                                 RESEARCH ASSOCIATE                  Y
# 222828                                 CONSULTANT LEVEL 3                  Y
# 188236                 COMPUTER SYSTEMS SOFTWARE ENGINEER                  Y
# 93267                         ASSISTANT PROJECT SCIENTIST                  Y
# 327136                                   BUSINESS ANALYST                  Y
# 317641                                        HOSPITALIST                  Y
# 513363                                  MARKETING MANAGER                  Y
# 326811                                       SVP STRATEGY                  Y
# 106767                CLINICAL DIRECTOR OF ADULT MEDICINE                  Y
# 337092                               DIRECTOR ENGINEERING                  Y
# 375277                                  ASSOCIATE DENTIST                  Y
# 223738                           PRODUCER/DIRECTOR/WRITER                  Y
# 240543                           PRODUCER/DIRECTOR/WRITER                  Y
# 243102                             LEAD SOFTWARE ENGINEER                  Y
# 480761                                  SOFTWARE ENGINEER                  Y
# 382806                                    PROJECT MANAGER                  Y
# 513354                            MARKET RESEARCH ANALYST                  Y
# 513377                            MARKET RESEARCH ANALYST                  Y
# 389791                                MANAGING CONSULTANT                  Y
# 49886                                         ARCHITECT 3                  Y
# 230987                                        RF ENGINEER                  Y
# 242436                              PRINCIPLE RF ENGINEER                  Y
# 273689                              SR. PRODUCT DEVELOPER                  Y
# 77516                                    IT AUDIT MANAGER                  Y
# 321052                                   DEV/OPS ENGINEER                  Y
# 247608                                ASSISTANT PROFESSOR                  Y
# 54155   SR. VICEPRESIDENT, WORLD WIDE  BUSINESS DEVELO...                  Y
# 319761                              SENIOR SAP CONSULTANT                  Y
# 12432                           PROFESSOR OF PHARMACOLOGY                  Y
# 155642                         SENIOR LOGISTICS DEVELOPER                  Y
# 293324                                 SOFTWARE DEVELOPER                  Y
# 188949                      SENIOR DATABASE ADMINISTRATOR                  Y
# 82207                                  PROGRAMMER ANALYST                  Y
# 115701                                ASSISTANT PROFESSOR                  Y
# 314951                    SR. CRM IMPLEMENTATION ENGINEER                  Y
# 138393                                    PROGRAM MANAGER                  Y
#
#         PREVAILING_WAGE PW_UNIT_OF_PAY     WORKSITE_CITY WORKSITE_STATE  YEAR
# 407395     820132347.00           Year        RIVERWOODS             IL  2014
# 33769      709999949.00           Year          COLUMBUS             OH  2013
# 132271     657900000.00           Year        WASHINGTON            NaN  2011
# 281084     616931693.00           Year          SAN JOSE             CA  2014
# 401912     413472579.00           Year           ASHBURN             VA  2014
# 222828     201622735.00           Year         SUNNYVALE             CA  2017
# 188236      77147000.00           Year         SUNNYVALE             CA  2011
# 93267       52354498.00           Year          BERKELEY             CA  2012
# 327136      35266600.00           Year         ST. LOUIS             MO  2011
# 317641      15094600.00           Year         BALTIMORE             MD  2013
# 513363      13759200.00           Year         MANHATTAN             NY  2014
# 326811      11839400.00           Year          NEW YORK             NY  2012
# 106767      10293900.00           Year          HARTFORD             CT  2017
# 337092      10175400.00           Year          NEW YORK             NY  2013
# 375277       9755200.00           Year           ROANOKE             VA  2012
# 223738       9214400.00           Year       CHULA VISTA             CA  2012
# 240543       9214400.00           Year       CHULA VISTA             CA  2012
# 243102       9110400.00           Year             SALEM             MA  2013
# 480761       9110400.00           Year          NEW YORK             NY  2015
# 382806       9062600.00           Year     BROOKLYN PARK             MN  2012
# 513354       8958600.00           Year         MANHATTAN             NY  2014
# 513377       8958600.00           Year         MANHATTAN             NY  2014
# 389791       8937800.00           Year          SECAUCUS             NJ  2014
# 49886        8927499.00           Year            RESTON             VA  2014
# 230987       8927400.00           Year           HERNDON             VA  2014
# 242436       8927400.00           Year           HERNDON             VA  2014
# 273689       8771400.00           Year            NEWTON             NC  2011
# 77516        8738100.00           Year   WASHINGTON D.C.             DC  2014
# 321052       8490600.00           Year           CHICAGO             IL  2015
# 247608       8055000.00           Year        WASHINGTON             DC  2011
# 54155        7991400.00           Year         SAN DIEGO             CA  2011
# 319761       7777100.00           Year          ST. PAUL             MN  2011
# 12432        7629000.00           Year          EDINBURG             TX  2011
# 155642       7113600.00           Year       GAINESVILLE             FL  2011
# 293324       7049100.00           Year        WASHINGTON             DC  2014
# 188949       6882700.00           Year            DULUTH             GA  2013
# 82207        6872300.00           Year            MCLEAN             VA  2011
# 115701       6704500.00           Year  WEST LONG BRANCH             NJ  2011
# 314951       6676800.00           Year            KELLER             TX  2011
# 138393       6579000.00           Year        WASHINGTON             DC  2011

# %% [markdown]
# Notice that every one of the highest values are in yearly units. This does not confirm data entry errors were not committed but it does rule out any obvious errors (such as an individual making 45 million dollars an hour).

# %% [markdown]
# Visualizing the distribution of wages:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("white")
# to remove plot.show requirement
# %matplotlib inline

# %%
# create the matplotlib Figure and Axes objects
ax_dims = (16, 8)
fig, ax = plt.subplots(figsize=ax_dims)
#remove borders including left which is not needed to see shape of dist
sns.despine(left=True)
plt.yticks([]) # hide y ticks
# plot yearly prevailing wage (subset)
sns.distplot(h1b_data[(h1b_data['PW_UNIT_OF_PAY']  == 'Year') & 
                      (h1b_data['PREVAILING_WAGE'] <= 250000)]['PREVAILING_WAGE']).set_title(
                                'Distribution of Yearly Prevailing Wage (up to $250,000 USD)', weight='bold').set_fontsize('14')

# %% [markdown]
# As expected with most financial data (wages, house prices, etc.) the distribution is very positively skewed. Even subsetting the data down to a maximum yearly prevailing wage of $250000, the strong skew of the distribution is seen. I will not remove the very large positive outliers at this point, but I may later on. As the large majority of the data is in yearly units of pay and the records falling under the other units would be expected to show a similar distribution, they will not be plotted.

# %% [markdown]
# I can now apply the previously made function to standardize units of pay to all be in yearly units:

# %%
# apply function to wage
h1b_data['PREVAILING_WAGE'] = h1b_data[['PREVAILING_WAGE', 'PW_UNIT_OF_PAY']].apply(
    lambda x: pay_to_yearly(*x), axis = 1
)

# check it first:
#test = h1b_data[['PREVAILING_WAGE', 'PW_UNIT_OF_PAY']].apply(lambda x: pay_to_yearly(*x), axis = 1)

# %% [markdown]
# After standardizing, let's make sure the wages are all correct.

# %%
# confirm
h1b_data.tail(5)
# Out:
#                CASE_NUMBER          CASE_STATUS  \
# 624645  I-200-16188-449352  CERTIFIED-WITHDRAWN
# 624646  I-200-16309-239165            CERTIFIED
# 624647  I-200-16363-692687            CERTIFIED
# 624648  I-200-17055-511599            CERTIFIED
# 624649  I-200-17068-828736            CERTIFIED
#
#                                 EMPLOYER_NAME  \
# 624645                        FAST SWITCH LTD
# 624646  MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 624647  MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 624648  MASSACHUSETTS INSTITUTE OF TECHNOLOGY
# 624649    PARK VIEW TRAVEL BEVERLY HILLS, LLC
#
#                                                  SOC_NAME SOC_CODE  \
# 624645                  SOFTWARE DEVELOPERS, APPLICATIONS  15-1132
# 624646                                         PHYSICISTS  19-2012
# 624647  GEOSCIENTISTS, EXCEPT HYDROLOGISTS AND GEOGRAP...  19-2042
# 624648                                MATERIALS ENGINEERS  17-2131
# 624649            MEETING, CONVENTION, AND EVENT PLANNERS  13-1121
#
#                                 JOB_TITLE FULL_TIME_POSITION  PREVAILING_WAGE  \
# 624645              SENIOR JAVA DEVELOPER                  Y         77209.60
# 624646             POSTDOCTORAL ASSOCIATE                  Y         50398.00
# 624647                 RESEARCH SCIENTIST                  Y         61069.00
# 624648             POSTDOCTORAL ASSOCIATE                  Y         41392.00
# 624649  EVENTS AND INCENTIVES COORDINATOR                  Y         45198.00
#
#        PW_UNIT_OF_PAY  WORKSITE_CITY WORKSITE_STATE  YEAR
# 624645           Hour         DUBLIN             OH  2017
# 624646           Year      CAMBRIDGE             MA  2017
# 624647           Year      CAMBRIDGE             MA  2017
# 624648           Year      CAMBRIDGE             MA  2017
# 624649           Year  BEVERLY HILLS             CA  2017

# %% [markdown]
# Notice the wage of the first record was originally in hours (with an hourly pay of \$37.12) and has been successfully converted to yearly. Also notice that the wages which were in yearly units remain unchanged. Now that units are all in yearly, the units column adds no information and can be dropped.

# %% [markdown]
# Density plot of the complete data set after the transformation to look for any issues:

# %%
# entire data set
sns.distplot(h1b_data[h1b_data['PREVAILING_WAGE'] <= 250000]['PREVAILING_WAGE']).set_title(
                                 'Distribution of Yearly Prevailing Wage (up to $250,000 USD)', 
                                 weight='bold').set_fontsize('14')

# %% [markdown]
# It appears the transformation was successful, the distribution of the entire standardized data is identical to that of the yearly subsetted data.

# %% [markdown]
# Now that the wages are standardized, descriptive statistics will be reflective of the data equally:

# %%
h1b_data['PREVAILING_WAGE'].describe()
# Out:
# count      3626977.00
# mean        138840.36
# std        4869080.00
# min              0.00
# 25%          55162.00
# 50%          66206.00
# 75%          82888.00
# max     6997606720.00
# Name: PREVAILING_WAGE, dtype: float64

# %% [markdown]
# Looking closer at the error:

# %%
h1b_data.nlargest(10, 'PREVAILING_WAGE')
# Out:
#                CASE_NUMBER CASE_STATUS  \
# 377434  I-200-13198-142691      DENIED
# 154357  I-200-11082-413524      DENIED
# 407395  I-200-14163-698141      DENIED
# 33769   I-200-12314-455612      DENIED
# 132271  I-200-11067-452033      DENIED
# 281084  I-200-14077-075359      DENIED
# 401912  I-200-14160-081071      DENIED
# 19923   I-200-12296-827859      DENIED
# 152446  I-200-11081-099118   WITHDRAWN
# 596248  I-200-17239-563554      DENIED
# 431854  I-200-14189-549551      DENIED
# 358868  I-200-12201-159657      DENIED
# 513606  I-203-14042-090601      DENIED
# 398304  I-200-13189-889499   WITHDRAWN
# 404284  I-200-13224-817098      DENIED
# 405200  I-200-13189-566815      DENIED
# 42013   I-200-10320-527355      DENIED
# 294219  I-200-12139-619595      DENIED
# 277598  I-200-11192-683946      DENIED
# 5580    I-203-16061-479563      DENIED
#
#                                             EMPLOYER_NAME  \
# 377434                GUARDIAN HEALTHCARE PROVIDERS, INC.
# 154357                                   SCIVANTAGE, INC.
# 407395                             DISCOVER PRODUCTS INC.
# 33769                                       IDEXCEL, INC.
# 132271                                COMMONHEALTH ACTION
# 281084                                         ARKRIT LLC
# 401912                    HOWARD HUGHES MEDICAL INSTITUTE
# 19923                                         GOOGLE INC.
# 152446                                ICAP CORPORATES LLC
# 596248  MGMC, LLC, A SUBSIDIARY OF MEDSTAR GEORGETOWN ...
# 431854                             SAN LUIS VALLEY HEALTH
# 358868                     BAYSHORE GLOBAL MANAGEMENT LLC
# 513606                HUNTSWORTH HEALTH NORTH AMERICA LLC
# 398304  MCLEOD REGIONAL MEDICAL CENTER OF THE PEE DEE,...
# 404284  MCLEOD REGIONAL MEDICAL CENTER OF THE PEE DEE,...
# 405200  MCLEOD REGIONAL MEDICAL CENTER OF THE PEE DEE,...
# 42013                                  UROLOGY TODAY, LLC
# 294219                             CLINIC BY THE SEA, LLC
# 277598                         AIR RESOURCES AMERICAS LLC
# 5580                                   E AND D MEDIA INC.
#
#                                       SOC_NAME             SOC_CODE  \
# 377434                     Physical Therapists              29-1123
# 154357                    Computer Programmers           15-1021.00
# 407395                           Statisticians              15-2041
# 33769        Software Developers, Applications              15-1132
# 132271    Medical and Health Services Managers           11-9111.00
# 281084               Computer Systems Analysts              15-1121
# 401912              Life Scientists, All Other              19-1099
# 19923   Architectural and Engineering Managers              11-9041
# 152446                      Financial Managers           11-3031.00
# 596248                     INTERNISTS, GENERAL              29-1063
# 431854                     Internists, General              29-1063
# 358868                      Financial Managers  1931-11-01 00:00:00
# 513606                      Financial Managers              11-3031
# 398304      Physicians and Surgeons, All Other              29-1069
# 404284                     Internists, General              29-1063
# 405200                     Internists, General              29-1063
# 42013       Physicians and Surgeons, All Other           29-1069.99
# 294219      Physicians and Surgeons, All Other              29-1069
# 277598                     Petroleum Engineers              17-2171
# 5580                        MARKETING MANAGERS              11-2021
#
#                                                 JOB_TITLE FULL_TIME_POSITION  \
# 377434                                PHYSICAL THERAPISTS                  Y
# 154357                                 SOFTWARE DEVELOPER                  Y
# 407395                                    PROJECT MANAGER                  Y
# 33769                                      .NET DEVELOPER                  Y
# 132271                PROGRAM MANAGER (POSITIVE PATHWAYS)                  Y
# 281084                                 PROGRAMMER/ANALYST                  Y
# 401912                                 RESEARCH ASSOCIATE                  Y
# 19923                       MANAGER, SOFTWARE ENGINEERING                  Y
# 152446              MANAGING DIRECTOR, EQUITY DERIVATIVES                  Y
# 596248                                        HOSPITALIST                  Y
# 431854                                          INTERNIST                  Y
# 358868                           CHIEF INVESTMENT OFFICER                  Y
# 513606  CHIEF FINANCIAL OFFICER, HUNTSWORTH HEALTH GLOBAL                  Y
# 398304  ASSOCIATE MED. DIRECTOR & HOSPICE/PALLIATIVE CARE                  Y
# 404284  ASSOCIATE MED. DIRECTOR & HOSPICE/PALLIATIVE CARE                  Y
# 405200  ASSOCIATE MED. DIRECTOR & HOSPICE/PALLIATIVE CARE                  Y
# 42013                                PHYSICIAN, UROLOGIST                  Y
# 294219  PHYSICIAN (GENERAL INVASIVE CARDIOLOGY/ELECTRO...                  Y
# 277598          ELECTRICAL COMPLETIONS ENGINEER - LEVEL 4                  Y
# 5580                   DIRECTOR, SOCIAL AND DIGITAL MEDIA                NaN
#
#         PREVAILING_WAGE PW_UNIT_OF_PAY  WORKSITE_CITY WORKSITE_STATE  YEAR
# 377434    6997606720.00           Hour          PEKIN             IL  2013
# 154357    1007814080.00           Hour    JERSEY CITY             NJ  2011
# 407395     820132347.00           Year     RIVERWOODS             IL  2014
# 33769      709999949.00           Year       COLUMBUS             OH  2013
# 132271     657900000.00           Year     WASHINGTON            NaN  2011
# 281084     616931693.00           Year       SAN JOSE             CA  2014
# 401912     413472579.00           Year        ASHBURN             VA  2014
# 19923      410315360.00           Hour  MOUNTAIN VIEW             CA  2013
# 152446     406637920.00           Hour    JERSEY CITY             NJ  2011
# 596248     401360960.00           Hour          OLNEY             MD  2017
# 431854     389376000.00           Hour        ALAMOSA             CO  2014
# 358868     378343680.00           Hour      LOS ALTOS             CA  2012
# 513606     361038080.00           Hour        YARDLEY             PA  2014
# 398304     348751520.00           Hour       FLORENCE             SC  2013
# 404284     348751520.00           Hour       FLORENCE             SC  2013
# 405200     348751520.00           Hour     DARLINGTON             SC  2013
# 42013      346112000.00           Hour   CRYSTAL CITY             MO  2011
# 294219     346112000.00           Hour      MILLSBORO             DE  2012
# 277598     340358720.00           Hour        HOUSTON             TX  2011
# 5580       329139200.00           Hour   SANTA MONICA             CA  2016

# %% [markdown]
# Most of the very high outliers (including the new maximum wage) are actually those whose prevailing wages were in hourly units. This has massively inflated the standard deviation. A sense of how powerful the positive skew in these data are can be found by comparing the max prevailing wage values to the 75% percentile. 75% of the wages fall below \$82888 while the highest wage values are many orders of magnitude greater. One can see that, after standardization, the 75th percentile remained mostly unchanged but the max value and SD were pulled way up due to the number of hourly outliers who were converted to yearly.

# %% [markdown]
# Another keen observation is that the min value is \$0.0. It does not make sense to have a prevailing wage for a job requested to be $0. This is likely a placeholder for missing data but I do not believe it should be and is misleading and could inject error into a decision-making algorithm if not noticed. If the data are missing and simply replaced by 0.0, any model that requires no data to be missing will not complain about this scenario and will run as expected but the results will not be as accurate.
#
# The influence of this issue, and how much error it might inject into a model, depends on how represented the issue is in these data.

# %%
sum(h1b_data['PREVAILING_WAGE'] == 0.0)
# Out:
# 41

# %% [markdown]
# It looks like only 41 records were encoded in this way. This is good because now I can simply drop these values without having to sacrifice much useful training data and overall the model will not be worse off in any significant way (due to the shear size of this data set).

# %%
# drop records with replaced vals
h1b_data = h1b_data.drop(h1b_data.index[h1b_data.PREVAILING_WAGE == 0.0])
sum(h1b_data['PREVAILING_WAGE'] == 0.0)
# Out:
# 0

# %% [markdown]
# Now these values have been dropped from the data, let's look at the new minimum:

# %%
h1b_data['PREVAILING_WAGE'].min()
# Out:
# 15.16

# %% [markdown]
# In yearly units, this value does not make sense. Let's look at the smallest values of these data:

# %%
h1b_data.nsmallest(10, 'PREVAILING_WAGE')
# Out:
#                CASE_NUMBER CASE_STATUS  \
# 30386   I-200-11298-492780      DENIED
# 356204  I-200-17079-327361      DENIED
# 382915  I-200-12228-770804      DENIED
# 612589  I-200-16144-004009      DENIED
# 606179  I-201-15111-542646      DENIED
# 28588   I-200-10303-461255      DENIED
# 313333  I-200-16035-732538      DENIED
# 484985  I-200-15159-617383      DENIED
# 321180  I-200-12160-259771      DENIED
# 314224  I-200-12157-169778      DENIED
# 370170  I-200-12219-653896   WITHDRAWN
# 647701  I-200-16026-864138      DENIED
# 619015  I-200-16017-163172      DENIED
# 250     I-200-12272-437206      DENIED
# 29518   I-200-12293-197972      DENIED
# 236469  I-200-12116-519039      DENIED
# 351496  I-200-11259-325272      DENIED
# 13059   I-200-11280-950501      DENIED
# 13062   I-200-11280-976017      DENIED
# 19143   I-200-11287-114023      DENIED
#
#                                    EMPLOYER_NAME  \
# 30386                        FREEDOM GUITAR INC.
# 356204                             KNOWBE4, INC.
# 382915                   KALVEN TECHNOLOGIES INC
# 612589               CENTRO CULTURAL ESPANOL INC
# 606179                                      TEST
# 28588                     ALTUS TECHNOLOGIES,INC
# 313333                           GOR CORPORATION
# 484985                WESTERN DATA MEMORIES. INC
# 321180                  PANDIT VIEW SOFTWARE LLC
# 314224              VISIONSOFT INTERNATIONAL INC
# 370170  INTERNATIONAL SYSTEMS TECHNOLOGIES, INC.
# 647701                           STYLEADDICT LLC
# 619015      DUKE CITY SPORTS ENTERTAINMENT GROUP
# 250                      COMPLEX TV NETWORK, INC
# 29518    STATE UNIVERSITY OF NEW YORK AT GENESEO
# 236469                     FEATHER RIVER COLLEGE
# 351496    PROMONTORY INTERFINANCIAL NETWORK, LLC
# 13059          ROTA TERMINAL & TRANSFER CO., INC
# 13062          ROTA TERMINAL & TRANSFER CO., INC
# 19143          ROTA TERMINAL & TRANSFER CO., INC
#
#                                                  SOC_NAME    SOC_CODE  \
# 30386                       Sound Engineering Technicians     27-4014
# 356204                  SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 382915                  Software Developers, Applications     15-1132
# 612589                                      ART DIRECTORS     27-1011
# 606179                           ADVERTISING SALES AGENTS     41-3011
# 28588                       Computer Programmer Non R & D  15-1022.00
# 313333                  SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 484985                           ADVERTISING SALES AGENTS     41-3011
# 321180                               Computer Programmers     15-1131
# 314224                               Computer Programmers     15-1131
# 370170                               Computer Programmers     15-1131
# 647701                           SEWING MACHINE OPERATORS     51-6031
# 619015                    ATHLETES AND SPORTS COMPETITORS     27-2021
# 250                                  Engineers, All Other     17-2199
# 29518       Art, Drama, and Music Teachers, Postsecondary     25-1121
# 236469                                 Coaches and Scouts     27-2022
# 351496                  Software Developers, Applications     15-1132
# 13059   Electrical and Electronics Repairers, Commerci...     49-2094
# 13062                            Accountants and Auditors     13-2011
# 19143   Electrical and Electronics Repairers, Commerci...     49-2094
#
#                              JOB_TITLE FULL_TIME_POSITION  PREVAILING_WAGE  \
# 30386                   SOUND ENGINEER                  N            15.16
# 356204               SOFTWARE ENGINEER                  Y            25.58
# 382915               SOFTWARE ENGINEER                  N            31.69
# 612589               CULTURAL DIRECTOR                NaN            35.00
# 606179                            ADSF                  Y            52.00
# 28588               PROGRAMMER ANALYST                  Y            63.45
# 313333       IOS AND ANDROID DEVELOPER                NaN          1278.94
# 484985         INTERNATIONAL SALES RAP                  Y          2000.00
# 321180                  SAP CONSULTANT                  Y          2011.00
# 314224     COMPUTER PROGRAMMER ANALYST                  Y          2012.00
# 370170              PROGRAMMER ANALYST                  Y          2012.00
# 647701                      SEAMSTRESS                NaN          2783.00
# 619015                          PLAYER                NaN          3900.00
# 250                TELEVISION ENGINEER                  Y          7799.00
# 29518               ADJUNCT INSTRUCTOR                  N          8236.25
# 236469          ASSISTANT SOCCER COACH                  N          9500.00
# 351496            ENTERPRISE DEVELOPER                  Y         10090.00
# 13059   ELECTRONIC & COMPUTER REPAIRER                  Y         10504.00
# 13062                       ACCOUNTANT                  Y         10504.00
# 19143   ELECTRONIC & COMPUTER REPAIRER                  Y         10504.00
#
#        PW_UNIT_OF_PAY      WORKSITE_CITY WORKSITE_STATE  YEAR
# 30386            Year          SAN DIEGO             CA  2012
# 356204           Year         CLEARWATER             FL  2017
# 382915           Year  ELK GROVE VILLAGE             IL  2012
# 612589           Year              MIAMI             FL  2016
# 606179           Week               TEST             DE  2015
# 28588            Year            RALEIGH             NC  2011
# 313333      Bi-Weekly           GLENDALE             CA  2016
# 484985           Year       REDWOOD CITY             CA  2015
# 321180           Year         CENTENNIAL             CO  2012
# 314224           Year            ATLANTA             GA  2012
# 370170           Year         PISCATAWAY             NJ  2012
# 647701           Year      SANDY SPRINGS             GA  2016
# 619015           Week        ALBUQUERQUE             NM  2016
# 250              Year             ENCINO             CA  2013
# 29518            Year            GENESEO             NY  2013
# 236469           Year             QUINCY             CA  2012
# 351496           Year          ARLINGTON             VA  2011
# 13059            Hour               ROTA             MP  2012
# 13062            Hour               ROTA             MP  2012
# 19143            Hour               ROTA             MP  2012

# %% [markdown]
# As you can see, a lot of these very small values were already in yearly units even before conversion (and as such, were not altered during standardization). This leads me to believe these data are surely not accurate and the information was not entered or not provided properly. I will drop any records with values < 1000 to cut off these suspicious data. Again, due to the size of these data, errors like this may not have had much of an impact but should be dropped none-the-less.

# %%
# drop records
h1b_data = h1b_data.drop(h1b_data.index[h1b_data.PREVAILING_WAGE < 1000])

# %% [markdown]
# Confirm new min:

# %%
h1b_data['PREVAILING_WAGE'].min()
# Out:
# 1278.9400000000001

# %% [markdown]
# For the sake of being conservative, I will remove the very high outliers in this data set. Dropping even a number of thousands of records should not be too large of a sacrifice. Let's see how many outliers are present in the data using the 1.5x IQR method. Because these data are heavily positively skewed, I am only interested in positive outliers.

# %%
# q1, q3, and IQR:
q1 = h1b_data['PREVAILING_WAGE'].quantile(0.25)
q3 = h1b_data['PREVAILING_WAGE'].quantile(0.75)

# %% [markdown]
# Check calculation by ensuring that 50% of data falls within IQR:

# %%
round(sum((h1b_data['PREVAILING_WAGE'] > q1) & (h1b_data['PREVAILING_WAGE'] < q3)) / len(h1b_data.index), 2)
# Out:
# 0.5

# %%
IQR = q3 - q1
# low outliers:
q1 - 1.5*IQR
# Out:
# 13573.0

# %%
# high outliers:
q3 + 1.5*IQR
# Out:
# 124477.0

# %% [markdown]
# Using this method, any record with a prevailing wage > \$124,477 is considered to be an outlier. That being said, outliers are expected and should not be removed. Very extreme outliers perhaps can be removed.

# %%
round(sum(h1b_data['PREVAILING_WAGE'] > q3 + 1.5*IQR) / len(h1b_data.index), 4)
# Out:
# 0.0391

# %% [markdown]
# Less than 4% of these data are positive outliers. This is to be expected with any distribution of finances. Let's look at extreme outliers:

# %%
# high outliers:
q3 + 5*IQR
# Out:
# 221518.0

# %%
round(sum(h1b_data['PREVAILING_WAGE'] > q3 + 5*IQR) / len(h1b_data.index), 4)
# Out:
# 0.002

# %% [markdown]
# Individuals whose wage is are around \$221,518 are very extreme outliers and make up around .02 percent of records.

# %% [markdown]
# As expected, a very small number of individuals earn these wages. The incredibly large wages are cause for concern. I will have to assume are entry errors (some of these records have wages in the tens of millions). To be conservative, I will remove these outliers to try to avoid data quality concerns.
#
# Below is a function for returning the data only considered non-outliers if it is of interest at a later time.

# %%
# drop records
h1b_data = h1b_data.drop(h1b_data.index[h1b_data.PREVAILING_WAGE > 1000000])

# %%
# return non-outliers - tweak distance from quartile:
def remove_outliers(df,column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    IQR = (df[column] > q1) & (df[column] < q3)
    non_outliers = (df[column] > q1 - 1.5*IQR) & (df[column] < q3 + 1.5*IQR)
    return df.loc[non_outliers]

# %% [markdown]
# Now that the missing records and very extreme outliers are removed, descriptive statistics should be reflective of a more accurate measure of central tendency and spread.

# %%
h1b_data['PREVAILING_WAGE'].describe()
# Out:
# count   3612480.00
# mean      71581.56
# std       26993.30
# min        1278.94
# 25%       55162.00
# 50%       66186.00
# 75%       82846.00
# max     1000000.00
# Name: PREVAILING_WAGE, dtype: float64

# %% [markdown]
# These numbers seem much more realistic.

# %% [markdown]
# Finally, since prevailing wages have been standardized to yearly, the unit of pay column can be removed without losing any information.

# %%
# drop col
h1b_data = h1b_data.drop(['PW_UNIT_OF_PAY'], axis = 1)

# %% [markdown]
# ### Full Time Position

# %% [markdown]
# We saw earlier that there was quite a lot of missing data in the column which indicated whether the position was full time or not. In fact, almost 18% of the total records had missing information in that column. It would be rash to scrap all this missing data before investigating further.

# %% [markdown]
# I will visualize the center of the distribution (filtering out the very long positive skew) to see how prevailing wage differs between full-time and not full-time positions.

# %%
# create the matplotlib Figure and Axes objects
ax_dims = (16, 8)
fig, ax = plt.subplots(figsize=ax_dims)
sns.despine()
# create boxplot
sns.boxplot(x="YEAR", y="PREVAILING_WAGE", hue = "FULL_TIME_POSITION",
                    data=h1b_data, palette="muted").set_ylim([0, 142000]);
# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);

# %% [markdown]
# Firstly, 2016 has missing data in the full time position column. How much data is missing overall in this field?

# %%
# return percent missing data of col

def percent_missing(df, column):
    miss = df[column].isnull().sum()
    complete = len(df.index)
    return 100*(miss/complete)

# %%
percent_missing(h1b_data, 'FULL_TIME_POSITION')
# Out:
# 17.871969143134589

# %% [markdown]
# Overall, just under 18% of the records in this data set have missing data in this column. This is an issue because knowing whether or not the is full-time is likely a significant predictor of approval. Also, because such a large number of records contain missing data in this field, it is not wise to simply throw these incomplete data away.

# %% [markdown]
# One way to go about filling in such categorical data is to first refer back to the summary statistics of prevailing wages grouped by full-time position values. Looking at the 75 percentile in particular for cut-offs.

# %%
# 75th percentile 
h1b_data.groupby('FULL_TIME_POSITION')['PREVAILING_WAGE'].quantile(.75)
# Out:
# FULL_TIME_POSITION
# N   70324.80
# Y   82659.00
# Name: PREVAILING_WAGE, dtype: float64

# %%
# 25th percentile 
h1b_data.groupby('FULL_TIME_POSITION')['PREVAILING_WAGE'].quantile(.25)
# Out:
# FULL_TIME_POSITION
# N   44616.00
# Y   55016.00
# Name: PREVAILING_WAGE, dtype: float64

# %% [markdown]
# Based on the 75th percentile, \$7000 will be used to separate full-time from non-full time jobs. This method is far from perfect and will strongly bias the distributions. Full-time wage distribution will be most impacted as it will have a very high floor effect which pulls the distribution up.

# %%
# use imbedded np.where calls to fill missing vals (ifelse in R)
h1b_data['FULL_TIME_POSITION'] = np.where(h1b_data['FULL_TIME_POSITION'].isnull() == True, 
                                          np.where(h1b_data['PREVAILING_WAGE'] > 70000, 'Y', 'N'), 
                                          h1b_data['FULL_TIME_POSITION'])

# %%
# create the matplotlib Figure and Axes objects
ax_dims = (16, 8)
fig, ax = plt.subplots(figsize=ax_dims)
sns.despine()
# create boxplot
sns.boxplot(x="YEAR", y="PREVAILING_WAGE", hue = "FULL_TIME_POSITION",
                    data=h1b_data, palette="muted").set_ylim([0, 142000]);
# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);

# %% [markdown]
# To get a sense of how much this process of replacing missing data biased the distributions of prevailing wages split by full time position, it is important to look at the overlap between the 2016 box plots and those of the other years. Looking at the 2016 prevailing wage distribution for full-time positions (Blue), we can see that the 50th percentile (median) lies above the 75th of the wage distributions of all other years, excluding 2017. Although the distributions overlap, I believe this is a problem which is not easily solved here. Any solution would introduce equivalent bias in the non-full-time distribution.

# %% [markdown]
# ### Location Transformations

# %% [markdown]
# This section will deal with making multiple location-based changes, beginning with cities from states.

# %% [markdown]
# Here are a list of the cities to inspect:

# %%
h1b_data['WORKSITE_CITY'].unique().tolist()
# Out:
# ['EASTHAMPTON',
#  'NEW YORK',
#  'HOUSTON',
#  'THE WOODLANDS',
#  'BOSTON',
#  'BEAVERTON',
#  'SALISBURY',
#  'MERRIMACK',
#  'FORT MYERS',
#  'SAN DIEGO',
#  'NEWARK',
#  'VISTA',
#  'FREDERICK',
#  'SEATTLE',
#  'BROOKLYN',
#  'SANTA CLARA',
#  'NEW ALBANY',
#  'WESTON',
#  'HONOLULU',
#  'HARTLAND',
#  'SAN ANTONIO',
#  'MALVERN',
#  'WATERTOWN',
#  'ANDREWS',
#  'COLLIERVILLE',
#  'WASHINGTON',
#  'NEWPORT BEACH',
#  'RICHMOND',
#  'MIAMI',
#  'AUSTIN',
#  'SUNNYVALE',
#  nan,
#  'NORTHWOOD',
#  'RIVERWOODS',
#  'HOPEWELL',
#  'WEST CHESTER',
#  'JACKSONVILLE',
#  'CARLSBAD',
#  'FEDERAL WAY',
#  'DURHAM',
#  'CINCINNATI',
#  'PUEBLO',
#  'EAST WINDSOR',
#  'MILFORD',
#  'SAN RAFAEL',
#  'JACKSON',
#  'PETERSBURG',
#  'TYLER',
#  'CAMBRIDGE',
#  'WINSTEAD',
#  'GREENSBORO',
#  'BERKELEY HEIGHTS',
#  'CHAMBERSBURG',
#  'WESTMONT',
#  'CARSON CITY',
#  'MIAMI BEACH',
#  'SPRINGFIELD',
#  'CLARKSBURG',
#  'WEST DESMOINES',
#  'COLORADO SPRINGS',
#  'BEDFORD',
#  'DULUTH',
#  'LOS ANGELES',
#  'MEMPHIS',
#  'NEW ORLEANS',
#  'LEWISPORT',
#  'MARSHALL',
#  'AUBURN HILLS',
#  'PHOENIX',
#  'SAN JOSE',
#  'BOCA RATON',
#  'OCALA',
#  'GLEN ALLEN',
#  'CARY',
#  'PLANO',
#  'WAYNE',
#  'POMONA',
#  'MIDLAND',
#  'ASSUMPTION',
#  'LAKE FOREST',
#  'MCLEAN',
#  'SHORTER',
#  'NASHVILLE',
#  'STERLING',
#  'PLYMOUTH',
#  'ROCKVILLE',
#  'SECAUCUS',
#  'DAYTON',
#  'RIVERWOOD',
#  'CHICAGO',
#  'LA PALMA',
#  'ATLANTA',
#  'HARTFORD',
#  'CALISTOGA',
#  'GREENVILLE',
#  'BUFFALO',
#  'MOUNTAIN VIEW',
#  'ALTON',
#  'BREA',
#  'GRAND RAPIDS',
#  'SOMERSET',
#  'TORRANCE',
#  'TALLAHASSEE',
#  'APPLETON',
#  'CONCORD',
#  'BLOOMINGTON',
#  'LOWELL',
#  'RED BANK',
#  'MAHWAH',
#  'NORCROSS',
#  'BOTHELL',
#  'TAMPA',
#  'NEEDHAM',
#  'CHELMSFORD',
#  'IRVING',
#  'NAPERVILLE',
#  'TROY',
#  'GRANVILLE',
#  'MENLO PARK',
#  'HARRISON',
#  'LA CROSSE',
#  'CUPERTINO',
#  'REDWOOD CITY',
#  'ISLANDIA',
#  'JERSEY CITY',
#  'ALLSTON',
#  'WHITE PLAINS',
#  'TEANECK',
#  'OMAHA',
#  'PARSIPPANY',
#  'FRAMINGHAM',
#  'WILMINGTON',
#  'MOUNTLAKE TERRACE',
#  'FLUSHING',
#  'FORT WORTH',
#  'RESTON',
#  'WASHINGTON, DC',
#  'MANASSAS',
#  'COLUMIBA',
#  'SUGAR LAND',
#  'SOUTH PLAINFIELD',
#  'ALISO VIEJO',
#  'CITY OF INDUSTRY',
#  'BOULDER',
#  'PAOLI',
#  'BOISE',
#  'JAMAICA',
#  'FARGO',
#  "JOHN'S CREEK",
#  'CLARKSVILLE',
#  'LONGVIEW',
#  'ELK GROVE VILLAGE',
#  'WALLINGFORD',
#  'MACON',
#  'NEW YORK CITY',
#  'SAN FRANCISCO',
#  'CARIBOU',
#  'NOBLESVILLE',
#  'HAMILTON',
#  'RANCHO PALOS VERDES',
#  'IRVINE',
#  'CARTERET',
#  'LEWIS CENTER',
#  'PHILADELPHIA',
#  'PLATTSBURGH',
#  'BROOMFIELD',
#  'GREENWOOD VILLAGE',
#  'MERIDEN',
#  'DANVILLE',
#  'FRANKFORT',
#  'EDISON',
#  'HUNTINGTON BEACH',
#  'CHASKA',
#  'MELVILLE',
#  'NANUET',
#  'ALBANY',
#  'CARSON',
#  'GALVESTON',
#  'EVANSTON',
#  'SAN MATEO',
#  'HENRICO',
#  'RAYMOND',
#  'NEW HUDSON',
#  'DALLAS',
#  'AHOSKIE',
#  'DANVERS',
#  'FOOTHILL RANCH',
#  'CARMEL',
#  'BRISBANE',
#  'HARRISONBURG',
#  'ORLANDO',
#  'RYE',
#  'INDIANAPOLIS',
#  'SOUTHGATE',
#  'ST. LOUIS',
#  'DETROIT',
#  'GAINESVILLE',
#  'AMARILLO',
#  'SWAMPSCOTT',
#  'ANGLETON',
#  'DANBURY',
#  'MOON TOWNSHIP',
#  'WACO',
#  'MINNEAPOLIS',
#  'ST. LOUIS PARK',
#  'COLLEGE STATION',
#  'PACIFIC',
#  'PORTLAND',
#  'ALEXANDRIA',
#  'DAVENPORT',
#  'CHARLOTTE',
#  'SAN JUAN CAPISTRANO',
#  'DELAND',
#  'BALTIMORE',
#  'REYNOLDSBURG',
#  'PRINCETON JUNCTION',
#  'BELLEVUE',
#  'SANTA CRUZ',
#  'DENVER',
#  'FOSTER CITY',
#  'EASTON',
#  'NORWALK',
#  'MILWAUKEE',
#  'ARDEN HILLS',
#  'MIDLOTHIAN',
#  'OAKLAND',
#  'REDMOND',
#  'KENNER',
#  'ARLINGTON HEIGHTS',
#  'BOLINGBROOK',
#  'LINCOLNSHIRE',
#  'DAVIE',
#  'EL SEGUNDO',
#  'WILLIAMSBURG',
#  'ROLLING MEADOWS',
#  'BRAINTREE',
#  'TORRINGTON',
#  'PASADENA',
#  'NORTH BRUNSWICK',
#  'ST CHARLES',
#  'ARLINGTON',
#  'ST LOUIS',
#  'WOLCOTT',
#  'NAPA',
#  'BURLINGTON',
#  'ANNANDALE',
#  'CHEYENNE',
#  'BIRMINGHAM',
#  'BRYAN',
#  'TECUMSEH',
#  'BAD AXE',
#  'HERNDON',
#  'BEAR',
#  'WESTMINSTER',
#  'OLDSMAR',
#  'PROVIDENCE',
#  'PRINCETON',
#  'KANSAS CITY',
#  'ARMONK',
#  'BAY POINT',
#  'COLUMBUS',
#  'FREMONT',
#  'GONZALES',
#  'LOUISVILLE',
#  'PRATTVILLE',
#  'TUSCALOOSA',
#  'UPPER SADDLE RIVER',
#  'COSTA MESA',
#  'FONTANA',
#  'HAUPPAUGE',
#  'NEWTOWN',
#  'MOUNT CLEMENS',
#  'ST. THOMAS',
#  'EAGAN',
#  'REDWOOD SHORES',
#  'SACRAMENTO',
#  'JAMAICA PLAIN',
#  'LUMBERTON',
#  'DEVON',
#  'WENTZVILLE',
#  'MONTEREY PARK',
#  'S FORT WORTH',
#  'NAMPA',
#  'PLAINVILLE',
#  'ST THOMAS',
#  'BENSENVILLE',
#  'ROSEMONT',
#  'DES PLAINES',
#  'FULLERTON',
#  'ALPHARETTA',
#  'MORGANTOWN',
#  'CONROE',
#  'DECATUR',
#  'EVERETT',
#  'KINGWOOD',
#  'RIVERSIDE',
#  'STURGEON BAY',
#  'LEHI',
#  'DOVER',
#  'SAINT JOSEPH',
#  'COLUMBIA',
#  'ATHENS',
#  'MONTGOMERY',
#  'HICKORY, NC',
#  'SOUTH BARRINGTON',
#  'LAFAYETTE',
#  'LOS ALTOS',
#  'CALABASAS',
#  'ARLINGTON HEIGH',
#  'JOHNSON CITY',
#  'ST. CROIX',
#  'ZION',
#  'LANSING',
#  'PICATAWAY',
#  'LONG ISLAND CITY',
#  'NORTH ANDOVER',
#  'WHIPPANY',
#  'GERMANTWON',
#  'PERTH AMBOY',
#  'NORTHBROOK',
#  'KOKOMO',
#  'CAMP HILL',
#  'EAST RUTHERFORD',
#  'SYRACUSE',
#  'FRANKLIN LAKES',
#  'CULVER CITY',
#  'UPPER ARLINGTON',
#  'MT. VERNON',
#  'UNION CITY',
#  'LYNCHBURG',
#  'CHEVY CHASE',
#  'GROTON',
#  'SUNYVALE',
#  'SHREWSBURY',
#  'FOSTER',
#  'BRANCHBURG',
#  'CHATTANOOGA',
#  'SOUTH PORTLAND',
#  'SKOKIE',
#  'SKOWHEGAN',
#  'CANTON',
#  'LITTLE ROCK',
#  'ST. PETERSBURG',
#  'HALLANDALE',
#  'ROYAL OAKS',
#  'GAITHERSBURG',
#  'NEW BRIGHTON',
#  'PITTSBURGH',
#  'BELTSVILLE',
#  'GLENDALE',
#  'METRO CHICAGO',
#  'BELLAIRE',
#  'EDGEWOOD',
#  'HOLLYWOOD',
#  'MURRAY',
#  'LIVINGSTON',
#  'WOBURN',
#  'ISELIN',
#  'MARLBOROUGH',
#  'REDBANK',
#  'OVERLAND PARK',
#  'PORT WASHINGTON',
#  'RICHARDSON',
#  'HUMBLE',
#  'MORRISTOWN',
#  'ST. PAUL',
#  'FOLSOM',
#  'HUNTINGTON',
#  'EDINA',
#  'PONTIAC',
#  'KIRKLAND',
#  'GRAPEVINE',
#  'ISSAQUAH',
#  'SURRY',
#  'GREENBELT',
#  'MONTVALE',
#  'HEBRON',
#  'ADDISON',
#  'ARTESIA',
#  'ANKENY',
#  'CHAPARRAL',
#  'MUNROE FALLS',
#  'ORANGE',
#  'WORCESTER',
#  'WARREN',
#  'WARRENVILLE',
#  'ODGENSBURG',
#  'WEEHAWKEN',
#  'MIDDLESEX',
#  'PORTSMOUTH',
#  'KING OF PRUSSIA',
#  'TRINITY',
#  'FRANKLIN',
#  'CYPRESS',
#  'SCOTTSDALE',
#  'SIOUX FALLS',
#  'LAKE MARY',
#  'ORANGE COUNTY',
#  'PLEASANTON',
#  'HOPKINS',
#  'ALLENTOWN',
#  'NEW ROCHELLE',
#  'JERICHO',
#  'LIVERMORE',
#  'DENHAM SPRINGS',
#  'STONE MTN',
#  'ALBUQUERQUE',
#  'METAIRIE',
#  'AKRON',
#  'GARLAND',
#  'MIDDLETOWN',
#  'WASHINGTON DC',
#  'WILLOUGHBY',
#  'SUNRISE',
#  'ROCHESTER',
#  'OAK CREEK',
#  'PLAINVIEW',
#  'BLOOMFIELD',
#  'WEST LAFAYETTE',
#  'BAYTOWN',
#  'HORSHAM',
#  'SAN BRUNO',
#  'WEST KINGSTON',
#  'BUCKEYE',
#  'EWING',
#  'MADISON',
#  'FLORHAM PARK',
#  'STAMFORD',
#  'DUBLIN',
#  'RANCHO CORDOVA',
#  'SANTA CLARITA',
#  'DUNEDIN',
#  'SANFORD',
#  'MORROW',
#  'MOONACHIE',
#  'MANCHESTER',
#  'PISCATAWAY',
#  'SHELBY TOWNSHIP',
#  'HAILEY',
#  'MERIDIAN',
#  'VIENNA',
#  'STOCKTON',
#  'ALAMEDA',
#  'CHANTILLY',
#  'CLOVIS',
#  'SILVER SPRING',
#  'WILTON MANORS',
#  'TIMONIUM',
#  'STANFORD',
#  'RUTHERFORD',
#  'HARRISBURG',
#  'COMMACK',
#  'CRYSTAL RIVER',
#  'SMYRNA',
#  'BERNARDSVILLE',
#  'FARMINGDALE',
#  'GREAT BARRINGTON',
#  'PRESIDIO',
#  'GREENWICH',
#  'LAS VEGAS',
#  'MILLS',
#  'EL DORADO HILLS',
#  'NORMAL',
#  'ROLLING FORK',
#  'GAHANNA',
#  'SANTA MONICA',
#  'SOUTHFIELD',
#  'LEXINGTON',
#  'PENNINGTON',
#  'PEORIA',
#  'SANTA ANA',
#  'EDEN PRAIRIE',
#  'MASON',
#  'CORTE MADERA',
#  'OXFORD',
#  'PALO ALTO',
#  'PALATINE',
#  'NOVI',
#  'PLAINSBORO',
#  'CHINO',
#  'GALENA PARK',
#  'ELLICOTT CITY',
#  'LADYSMITH',
#  'NEWTON',
#  'GEORGETOWN',
#  'BERKELEY',
#  'OKLAHOMA CITY',
#  'DRAPER',
#  'WAUKESHA',
#  'BEVERLY HILLS',
#  'JONESBORO',
#  'RENTON',
#  'BROWNSVILLE',
#  'HARWICK',
#  'HENDERSON',
#  'EAU CLAIRE',
#  'ARLINGTON HTS',
#  'GREAT NECK',
#  'ELMHURST',
#  'LANHAM',
#  'RICHFIELD',
#  'CLEARWATER',
#  'SIDNEY',
#  'GARDENA',
#  'EAST MOLINE',
#  'TARRYTOWN',
#  'HOBOKEN',
#  'WAUWATOSA',
#  'CHANDLER',
#  'PALM BEACH GARDENS',
#  'ST. JOSEPH',
#  'EL PASO',
#  'HAMDEN',
#  'CHARLESTON',
#  'TOWN AND COUNTRY',
#  'CLEVELAND',
#  'LAVERGNE',
#  'PASCO',
#  'LAKE WORTH',
#  'SAN RAMON',
#  'BUFORD',
#  'ANDOVER',
#  'CENTENNIAL',
#  'TUSTIN',
#  'FALL RIVER',
#  'HARBOR CITY',
#  'MONROVIA',
#  'TULSA',
#  'FALLS CHURCH',
#  'LAGUNA BEACH',
#  'ENGLEWOOD',
#  'WEBSTER',
#  'CHESTER',
#  'DULLES',
#  'OPELOUSAS',
#  'PAINTED POST',
#  'RAMSEY',
#  'EUREKA',
#  'SCHWARTZ CREEK',
#  'LAKEWOOD',
#  'CHATHAM',
#  'PINGREE GROVE',
#  'DORAL',
#  'ALACHUA',
#  'BLACKSBURG',
#  'ONE ELLIOT WAY',
#  'HYATTSVILLE',
#  'SALT LAKE CITY',
#  'NORTH GRAFTON',
#  'PORT CHARLOTTE',
#  'BRADENTON',
#  'EATONTOWN',
#  'COTTONDALE',
#  'GLEN BURNIE',
#  'STRAWBERRY PLAINS',
#  'TEMPLE',
#  'FAIRFIELD',
#  'ALBURQUERQUE',
#  'LOVEJOY',
#  'SAN RAMAN',
#  'SHORT HILLS',
#  'CROSSVILLE',
#  'SHOREVIEW',
#  'OAK BROOK',
#  'GLASTONBURY',
#  'PEARLAND',
#  'FRANKLIN PARK',
#  'ATHERTON',
#  'WEST DES MOINES',
#  'BETHESDA',
#  'BOONE',
#  'SEBRING',
#  'WESTBOROUGH',
#  'CAMPBELL',
#  'LAUREL',
#  'BATTLE CREEK',
#  'SIMI VALLEY',
#  'BARRINGTON',
#  'CHESAPEAKE CITY',
#  'WILTON',
#  'RALEIGH',
#  'IRWINDALE',
#  'LOGAN',
#  'HAMMONDSPORT',
#  'FRESNO',
#  'ITASCA',
#  'SUGARLAND',
#  'SUITE 230',
#  'BRENTWOOD',
#  'TUCSON',
#  'EAST ROCHESTER',
#  'MINNETONKA',
#  'COTTAGE GROVE',
#  'GREELEY',
#  'LAKEVILLE',
#  'NASHUA',
#  'SUMMIT',
#  'GATHERSBURG',
#  'BROCKTON',
#  'SUITE # 903',
#  'QUINCY',
#  'COVINGTON',
#  'HAZLET',
#  'WOODCLIFF LAKE',
#  'WALNUT CREEK',
#  'LAMAR',
#  'PALM COAST',
#  'DEL MAR',
#  'HUTTO',
#  'NEW CASTLE',
#  'IPSWICH',
#  'FORT COLLINS',
#  'TINTON FALLS',
#  'WINSTON SALEM',
#  'ANNAPOLIS',
#  'URBANCREST',
#  'LAKELAND',
#  'EAST HANOVER',
#  'SIGNAL HILL',
#  'MESA',
#  'ALLEN',
#  'MIDDLEBURG',
#  'WESTBURY',
#  'FORESTVILLE',
#  'SANTA FE',
#  'VALLEY LEE',
#  'LAGRANGE',
#  'NORMAN',
#  'BETHESDA, MD',
#  'WILLIAMSPORT',
#  'WASILLA',
#  'ROUND ROCK',
#  'WESTLAKE VILLAGE',
#  'WINDSOR',
#  'ANN ARBOR',
#  'BETHPAGE',
#  'STILLWATER',
#  'MENOMONEE FALLS',
#  'WALNUT',
#  'OLYMPIA',
#  'ORANGEBURG',
#  'WEST NEWBURY',
#  'NOVATO',
#  'MILWAUKIE',
#  'YPSILANTI',
#  'HOFFMAN ESTATES',
#  'LAVONIA',
#  'KENT',
#  'PARKER',
#  'CHESTERTOWN',
#  'MORGANVILLE',
#  'CLINTON',
#  'BRIDGEWATER',
#  'MCALLEN',
#  'RESEARCH TRIANGLE PARK',
#  'WEST HAVEN',
#  'PERRYTON',
#  'LONG PRAIRIE',
#  'UNIVERSAL CITY',
#  'MAPLE GROVE',
#  'GRANDVIEW',
#  'YORK',
#  'SPENCER',
#  'BERKLEY',
#  'WALTHAM',
#  'HILLSBORO',
#  'KATY',
#  'MADISON HEIGHTS',
#  'MOUNT PROSPECT',
#  'OAK PARK',
#  'BERGENFIELD',
#  'SCHAUMBURG',
#  'CELEBRATION',
#  'THORNWOOD',
#  'WHEATON',
#  'HARLINGEN',
#  'HOPKINTON',
#  'BROOKFIELD',
#  'LOVELAND',
#  'SMITHFIELD',
#  'NEW BRUNSWICK',
#  'SOUTHBOROUGH',
#  'COMMERCE',
#  'NEW HAVEN',
#  'PLYMOUTH MEETING',
#  'PORT ARTHUR',
#  'ROWLAND HEIGHTS',
#  'NORTH OLMSTED',
#  'GLENWOOD',
#  'MUNHALL',
#  'HUNT VALLEY',
#  'VISALIA',
#  'SHELTON',
#  'WEST SACRAMENTO',
#  'JACSKONVILLE',
#  'HUDSON',
#  'THOUSAND OAKS',
#  'WATERLOO',
#  'ALTANTA',
#  '6015 WILSON BLVD.',
#  'MANHATTAN BEACH',
#  'BURR RIDGE',
#  'CORNING',
#  'DEER PARK',
#  'UNIVESAL CITY',
#  'CORONA',
#  'FAIRFAX',
#  'BRANDON',
#  'MILPITAS',
#  'TEMPE',
#  'EVANSVILLE',
#  'COLLEGEVILLE',
#  'GRASS VALLEY',
#  'JUNO BEACH',
#  'DORCHESTER',
#  'SNOQUALMIE',
#  'FORT LEE',
#  'NILES',
#  'LIBERTY',
#  'FAYETTEVILLE',
#  'BATON ROUGE',
#  'NORTH HAVEN',
#  'HERCULES',
#  'WELLESLEY',
#  'ALTAMONTE SPRINGS',
#  'NEW HOPE',
#  'DIAMOND BAR',
#  'CAMAS',
#  'CARLSTADT',
#  'MARYVILLE',
#  'ST. AUGUSTINE',
#  'WOODBURY',
#  'MORRISVILLE',
#  'MIAMI LAKES',
#  'FORT LAUDERDALE',
#  'COPPELL',
#  'WARWICK',
#  'PEARL RIVER',
#  'ANNANDALE-ON-HUDSON',
#  'WEST NYACK',
#  'WESTFORD',
#  'MORRIS PLAINS',
#  'OPA LOCKA',
#  'MIRAMAR',
#  'NORTH QUINCY',
#  'WESTWOOD',
#  'COLUMUBUS',
#  'PHOENIXVILLE',
#  'INVER GROVE HEIGHTS',
#  'VOORHEES',
#  'MARTINSBURG',
#  'FOWLERVILLE',
#  'RAINELLE',
#  'HAGERSTOWN',
#  'EMERYVILLE',
#  'LEWISBERRY',
#  'HOLLAND',
#  'SOUTH SAN FRANCISCO',
#  'READING',
#  'AGOURA HILLS',
#  'WINONA',
#  'LEBANON',
#  'OAKTON',
#  'OLNEY',
#  'TUCKER',
#  'LIBERTYVILLE',
#  'BELLVUE',
#  'TACOMA',
#  'ARLINGTON HEIGHTS,',
#  'BURBANK',
#  'BLAINE',
#  'COMPTON',
#  'BARTLETT',
#  'EAST FISHKILL',
#  'DEARBORN',
#  'LITITZ',
#  'WEST NORRITON',
#  'KEW GARDENS',
#  'MURRAYVILLE',
#  'FARMINGTON',
#  'BRONX',
#  'WATERBURY',
#  'LINCOLN',
#  'LEONIA',
#  'BYRON CENTER',
#  'HAGATNA',
#  'FOOTHILLS RANCH',
#  'BLOUNTSTOWN',
#  'MEDIA',
#  'CREVE COEUR',
#  "ST. MARY'S CITY",
#  'PUTNAM',
#  'BALA CYNWYD',
#  'AMHERST',
#  'GRAND PRAIRIE',
#  'MATEWAN',
#  'NEW KENSINGTON',
#  'FORT SMITH',
#  'BINGHAMTON',
#  'TOMBALL',
#  'SHADY GROVE',
#  'CINCINNATTI',
#  'TEMPLE TERRACE',
#  'NORTH TONAWANDA',
#  'ELKHART',
#  'GOLDEN',
#  'OSSINING',
#  'COLLEGE POINT',
#  'MIAMISBURG',
#  'WORTHINGTON',
#  'WALPOLE',
#  'CARMICHAEL',
#  'ST. CHARLES',
#  'RICHWOOD',
#  'BEND',
#  'MISSION',
#  'HANOVER',
#  'STAFFORD',
#  'SEAFORD',
#  'GOODYEAR',
#  'LINDON',
#  'DOWNERS GROVE',
#  'SANTA ROSA',
#  'FORT WASHINGTON',
#  'MONTEREY',
#  'LYNNWOOD',
#  'METTAWA',
#  'GETZVILLE',
#  'BLOOMFIELD HILLS',
#  'POUGHKEEPSIE',
#  'HERMITAGE',
#  'REDLANDS',
#  'NEWPORT',
#  'MCCLEAN',
#  'JEFFERSON CITY',
#  'SUSSEX',
#  'LEAGUE CITY',
#  'BAKERSFIELD',
#  'LIVONIA',
#  'WYOMING',
#  'MCKINLEYVILLE',
#  'WAVERLY',
#  'DEDHAM',
#  'GLEN ELLYN',
#  'ROANOKE',
#  'EL MONTE',
#  'GUAM',
#  'WALKERSVILLE',
#  'GROVE CITY',
#  'DES MOINES',
#  'YONKERS',
#  'LA JOLLA',
#  'NUTLEY',
#  'MODESTO',
#  'KOHLER',
#  'FRIDLEY',
#  'ARCADIA',
#  'BELMONT',
#  'FLORENCE',
#  'HALSEY',
#  'GLEN RAVEN',
#  'CEDAR RAPIDS',
#  'EAST BRUNSWICK',
#  'WINSTON-SALEM',
#  'NATICK',
#  'VERNON',
#  'RIO PIEDRAS, SAN JUAN',
#  'MADBURY',
#  'CERRITOS',
#  'GARDEN GROVE',
#  'BROCKPORT',
#  'LAKE SUCCESS',
#  'BASKING RIDGE',
#  'OKEMOS',
#  'D/FW AIRPORT',
#  'STONY BROOK',
#  'PLAYA VISTA',
#  'STRASBURG',
#  'FRISCO',
#  'FT. DODGE',
#  'LONG BEACH',
#  'ROCKLIN',
#  'GROVEPORT',
#  'ROCKLEIGH',
#  'MARSHFIELD',
#  'MOUNTAINVIEW',
#  'MARLBORO',
#  'PORT ST. LUCIE',
#  'RENSSELAER',
#  'GLEN MILLS',
#  'SPRING',
#  'WARSAW',
#  'WESTPORT',
#  'SUMNER',
#  'CARROLLTON',
#  'HIGHLANDS RANCH',
#  'CHATSWORTH',
#  'AJO',
#  'ESSEX JUNCTION',
#  'WILSONVILLE',
#  'FARMINGTON HILLS',
#  'TAMUNING',
#  'PIMA',
#  'THE VILLAGE',
#  'EDMOND',
#  'TIGARD',
#  'WOODLAND HILLS',
#  'RUSSELLVILLE',
#  'HERSHEY',
#  'BELLMORE',
#  'DAVIDSON',
#  'NORTH DARTMOUTH',
#  'BALDWIN',
#  'POMPANO BEACH',
#  'SOUTHLAKE',
#  'MONTGOMERYVILLE',
#  'WINTER PARK',
#  'COVINA',
#  'ROSEMEAD',
#  'MARYLAND HEIGHTS',
#  'MOUNTIAN VIEW',
#  'HACKETTSTOWN',
#  'STOUGHTON',
#  'CHULA VISTA',
#  'VAN NUYS',
#  'WICHITA',
#  'LAKEWAY',
#  'WALL TOWNSHIP',
#  'WELLESLEY HILLS',
#  'TAYLOR',
#  'PORTERVILLE',
#  'MANGILAO',
#  'UNIVERSITY PARK',
#  'MARYSVILLE',
#  'UNIONDALE',
#  'VERSAILLES',
#  'KNOXVILLE',
#  'BRIDGEPORT',
#  'SPARTANBURG',
#  'LAKE OSWEGO',
#  'SENATOBIA',
#  'SANTA FE SPRINGS',
#  'PRESQUE ISLE',
#  'SOUTH MILWAUKEE',
#  'TEMECULA',
#  'FAIRLESS HILLS',
#  'ANAHEIM',
#  'LEWISVILLE',
#  'FT. BELVOIR',
#  'ELKRIDGE',
#  'COLCHESTER',
#  'CRAWFORDSVILLE',
#  'MONMOUTH JUNCTION',
#  'MANSFIELD',
#  'NAPLES',
#  'SOUTH HAMILTON',
#  'RACINE',
#  'NORTH KINGSTON',
#  'PATERSON',
#  'AVENTURA',
#  'EVERGREEN',
#  'EDWARDSPORT',
#  'MOSSVILLE',
#  'CARPINTERIA',
#  'TARZANA',
#  'MUKILTEO',
#  'CHESAPEAKE',
#  'SAN LEANDRO',
#  'VERNON HILLS',
#  'BAY HARBOR ISLANDS',
#  'RIVERDALE',
#  'WAUKEGAN',
#  'HUNTSVILLE',
#  'NORWOOD',
#  'NEWPORT NEWS',
#  'PALM DESERT',
#  'GREENWOOD',
#  'THOMASVILLE',
#  'CALHOUN',
#  'OCEANPORT',
#  'BENTONVILLE',
#  'MELBOURNE',
#  'ESTERO',
#  'MOLINE',
#  'URBANA',
#  'TURTLE CREEK',
#  'DEERFIELD',
#  'BOHEMIA',
#  'BETHEL PARK',
#  'RIDGE',
#  'SAINT LOUIS',
#  'WILKESBORO',
#  'INGLESIDE',
#  'CONYERS',
#  'PHARR',
#  'DEKALB',
#  'FISHERS',
#  'SAN CLEMENTE',
#  'MIDDLE TOWN',
#  'MT. LAUREL',
#  ...]

# %%
# number of unique cities (including nan)
len(h1b_data['WORKSITE_CITY'].unique().tolist())
# Out:
# 19785

# %% [markdown]
# Some of these records have issues with worksite values. The first issue is that some contain commas which separate the city from the state. This is not necessary as a column containing the state information already exists.
#
# Here is a subset of the data which contains a comma in the WORKSITE_CITY column:

# %%
# subset with comma
h1b_data[h1b_data['WORKSITE_CITY'].str.contains(",", na= False)]
# Out:
#                CASE_NUMBER          CASE_STATUS  \
# 229     I-200-09238-727580            CERTIFIED
# 436     I-200-09342-235537            WITHDRAWN
# 691     I-200-10064-534888            CERTIFIED
# 1904    I-200-10243-622106            CERTIFIED
# 2482    I-200-10265-003788            CERTIFIED
# 2525    I-200-10266-000003            CERTIFIED
# 2968    I-200-10273-492661            CERTIFIED
# 5558    I-200-10277-287795            CERTIFIED
# 5646    I-200-10277-019771            CERTIFIED
# 5828    I-200-10277-170857            CERTIFIED
# 6819    I-200-10278-900101            CERTIFIED
# 7047    I-200-10278-306101  CERTIFIED-WITHDRAWN
# 7691    I-200-10279-631700            CERTIFIED
# 7706    I-200-10279-549605            CERTIFIED
# 8092    I-200-10279-273707            CERTIFIED
# 8176    I-200-10279-683151            CERTIFIED
# 8328    I-200-10279-742684            CERTIFIED
# 8379    I-200-10279-730316            WITHDRAWN
# 8384    I-200-10279-314878            WITHDRAWN
# 8814    I-200-10280-361945            CERTIFIED
# 9198    I-200-10280-490600               DENIED
# 9661    I-200-10280-386680  CERTIFIED-WITHDRAWN
# 9678    I-200-10280-793197  CERTIFIED-WITHDRAWN
# 9686    I-200-10280-121004            CERTIFIED
# 9706    I-200-10280-412306            CERTIFIED
# 9856    I-200-10281-629214            CERTIFIED
# 9860    I-200-10281-070083            CERTIFIED
# 9867    I-200-10281-331996            CERTIFIED
# 9869    I-200-10281-583091            CERTIFIED
# 9888    I-200-10281-143314            CERTIFIED
# ...                    ...                  ...
# 608198  I-200-17254-594044            CERTIFIED
# 608941  I-200-17255-244066            CERTIFIED
# 609336  I-200-17255-654627            CERTIFIED
# 611078  I-200-17256-305972            CERTIFIED
# 611392  I-200-15079-770372  CERTIFIED-WITHDRAWN
# 612142  I-200-17257-320978            CERTIFIED
# 612148  I-200-17257-973394            CERTIFIED
# 612855  I-200-17257-729515            CERTIFIED
# 612968  I-200-17254-351338            WITHDRAWN
# 613292  I-203-17255-913759            CERTIFIED
# 615270  I-200-17261-751861            CERTIFIED
# 615378  I-200-17261-497419            CERTIFIED
# 615730  I-200-17261-387656            CERTIFIED
# 616311  I-200-17265-328398            WITHDRAWN
# 617005  I-200-17262-448908            CERTIFIED
# 617320  I-200-17262-117959            CERTIFIED
# 617415  I-200-17262-228556            CERTIFIED
# 618301  I-200-17263-132980            CERTIFIED
# 618475  I-200-17263-109647            CERTIFIED
# 618638  I-200-17263-980792            CERTIFIED
# 618687  I-200-17263-375234            CERTIFIED
# 618779  I-200-17262-629334            CERTIFIED
# 619427  I-200-17263-095517            CERTIFIED
# 620483  I-200-17264-067891            CERTIFIED
# 621127  I-200-17264-929844            CERTIFIED
# 621520  I-200-16106-092890  CERTIFIED-WITHDRAWN
# 622081  I-200-17265-126223            CERTIFIED
# 623301  I-200-15260-660375  CERTIFIED-WITHDRAWN
# 624033  I-200-17268-495321            CERTIFIED
# 624262  I-200-17268-998189            CERTIFIED
#
#                                         EMPLOYER_NAME  \
# 229                            ISTREAM SOLUTIONS INC.
# 436                            ISTREAM SOLUTIONS INC.
# 691                     THE PRINCIPAL CONSULTING INC.
# 1904                                SUBURBAN HOSPITAL
# 2482                               CQUENT SYSTEMS INC
# 2525                             EXECUTEK SYSTEMS LLC
# 2968    UNIVERSITY OF PUERTO RICO, RIO PIEDRAS CAMPUS
# 5558                           COMPEST SOLUTIONS INC.
# 5646                                     MARLABS, INC
# 5828                                     MARLABS, INC
# 6819                          AMZUR TECHNOLOGIES, INC
# 7047                                     MARLABS, INC
# 7691                                     MARLABS, INC
# 7706                                     MARLABS, INC
# 8092                                 MULTIVISION INC.
# 8176              NORCAPCO INTEGRATED SOLUTIONS, INC.
# 8328                                     MARLABS, INC
# 8379                                     MARLABS, INC
# 8384                                     MARLABS, INC
# 8814                         VEDICSOFT SOLUTIONS, INC
# 9198                        THERMALTAKE (U.S.A.) INC.
# 9661                                     MARLABS, INC
# 9678                                     MARLABS, INC
# 9686                                     MARLABS, INC
# 9706                                   SMALLARC, INC.
# 9856         ORACLE FINANCIAL SERVICES SOFTWARE INC.,
# 9860         ORACLE FINANCIAL SERVICES SOFTWARE INC.,
# 9867         ORACLE FINANCIAL SERVICES SOFTWARE INC.,
# 9869         ORACLE FINANCIAL SERVICES SOFTWARE INC.,
# 9888                             OPTIMOS INCORPORATED
# ...                                               ...
# 608198                                 HIRE IT PEOPLE
# 608941              PROFICIENT BUSINESS SYSTEMS, INC.
# 609336                                     VCARVE INC
# 611078    AMERICAN ASSOCIATION OF COLLEGES OF NURSING
# 611392                      THE UNIVERSITY OF ARIZONA
# 612142                                       CA, INC.
# 612148                                   DIASPARK INC
# 612855                                    AMENSYS INC
# 612968                    EVANGELICAL LAYMAN'S CHURCH
# 613292                                   HOYNSCHE LLC
# 615270                            CROM TECHNOLOGY INC
# 615378                     MY SUPPLY CHAIN GROUP, LLC
# 615730                               FIRST TEK , INC.
# 616311                           TEXARA SOLUTIONS LLC
# 617005                            MALAX SOLUTIONS INC
# 617320                               APEX SYSTEMS LLC
# 617415                          CAPGEMINI AMERICA INC
# 618301                            MALAX SOLUTIONS INC
# 618475              EVANGELICAL LAYMAN'S CHURCH, INC.
# 618638                QUANTUM INTEGRATORS GROUP , LLC
# 618687                        DELOITTE CONSULTING LLP
# 618779                        INFOSTRETCH CORPORATION
# 619427                                FIRST TEK, INC.
# 620483              PROFICIENT BUSINESS SYSTEMS, INC.
# 621127                               FIRST TEK , INC.
# 621520                    COVEY SOFTWARE SYSTEMS, INC
# 622081                           TEXARA SOLUTIONS LLC
# 623301                         ELITE IT SOLUTIONS INC
# 624033                               FIRST TEK , INC.
# 624262                        ALLIED INFORMATICS, INC
#
#                                                 SOC_NAME    SOC_CODE  \
# 229                            Computer Systems Analysts  15-1051.00
# 436                            Computer Systems Analysts  15-1051.00
# 691                            Computer Systems Analysts  15-1051.00
# 1904          Medical Scientists, Except Epidemiologists     19-1042
# 2482                                Computer Programmers  15-1021.00
# 2525                           Computer Systems Analysts  15-1051.00
# 2968                  Zoologists and Wildlife Biologists  19-1023.00
# 5558                                Computer Programmers  15-1021.00
# 5646                                Computer Programmers  15-1021.00
# 5828                                Computer Programmers  15-1021.00
# 6819                                Computer Programmers  15-1021.00
# 7047                                Computer Programmers  15-1021.00
# 7691                                Computer Programmers  15-1021.00
# 7706                                Computer Programmers  15-1021.00
# 8092           Computer Software Engineers, Applications  15-1031.00
# 8176           Computer Software Engineers, Applications  15-1031.00
# 8328                                Computer Programmers  15-1021.00
# 8379                                Computer Programmers  15-1021.00
# 8384                             Database Administrators  15-1061.00
# 8814    Network Systems and Data Communications Analysts  15-1081.00
# 9198                                  Financial Analysts  13-2051.00
# 9661                             Database Administrators  15-1061.00
# 9678                                Computer Programmers  15-1021.00
# 9686                                Computer Programmers  15-1021.00
# 9706                                Computer Programmers  15-1021.00
# 9856                           Computer Systems Analysts  15-1051.00
# 9860               Computer Systems Engineers/Architects  15-1099.02
# 9867           Computer Software Engineers, Applications  15-1031.00
# 9869                           Computer Systems Analysts  15-1051.00
# 9888           Computer Software Engineers, Applications  15-1031.00
# ...                                                  ...         ...
# 608198                   COMPUTER OCCUPATIONS, ALL OTHER     15-1199
# 608941                 SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 609336                 SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 611078                                SURVEY RESEARCHERS     19-3022
# 611392        MEDICAL SCIENTISTS, EXCEPT EPIDEMIOLOGISTS     19-1042
# 612142                 SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 612148                         COMPUTER SYSTEMS ANALYSTS     15-1121
# 612855       NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS     15-1142
# 612968     DIRECTORS, RELIGIOUS ACTIVITIES AND EDUCATION     21-2021
# 613292                             FOOD SERVICE MANAGERS     11-9051
# 615270                 SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 615378                         COMPUTER SYSTEMS ANALYSTS     15-1121
# 615730                         COMPUTER SYSTEMS ANALYSTS     15-1121
# 616311                 SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 617005                   COMPUTER OCCUPATIONS, ALL OTHER     15-1199
# 617320                   COMPUTER OCCUPATIONS, ALL OTHER     15-1199
# 617415                   COMPUTER OCCUPATIONS, ALL OTHER     15-1199
# 618301                   COMPUTER OCCUPATIONS, ALL OTHER     15-1199
# 618475     DIRECTORS, RELIGIOUS ACTIVITIES AND EDUCATION     21-2021
# 618638                 SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 618687                         COMPUTER SYSTEMS ANALYSTS     15-1121
# 618779                   COMPUTER OCCUPATIONS, ALL OTHER     15-1199
# 619427                              COMPUTER PROGRAMMERS     15-1131
# 620483                         COMPUTER SYSTEMS ANALYSTS     15-1121
# 621127                         COMPUTER SYSTEMS ANALYSTS     15-1121
# 621520                              COMPUTER PROGRAMMERS     15-1131
# 622081                           DATABASE ADMINISTRATORS     15-1141
# 623301                              COMPUTER PROGRAMMERS     15-1131
# 624033                 SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 624262                              COMPUTER PROGRAMMERS     15-1131
#
#                                                 JOB_TITLE FULL_TIME_POSITION  \
# 229                                    PROGRAMMER ANALYST                  Y
# 436                                    PROGRAMMER ANALYST                  Y
# 691                                    PROGRAMMER ANALYST                  Y
# 1904                                      RESEARCH FELLOW                  Y
# 2482                                   PROGRAMMER ANALYST                  Y
# 2525               ASSOCIATE PARTNER AND SYSTEMS ENGINEER                  Y
# 2968             ASSISTANT RESEARCHER IN BIOLOGY POST DOC                  Y
# 5558                     PROGRAMMER / PERFORMANCE ANALYST                  Y
# 5646                                   PROGRAMMER/ANALYST                  Y
# 5828                                   PROGRAMMER/ANALYST                  Y
# 6819                                   PROGRAMMER ANALYST                  Y
# 7047                                   PROGRAMMER/ANALYST                  Y
# 7691                                   PROGRAMMER/ANALYST                  Y
# 7706                                   PROGRAMMER/ANALYST                  Y
# 8092                                   SOFTWARE DEVELOPER                  Y
# 8176                                    SOFTAWRE ENGINEER                  Y
# 8328                                   PROGRAMMER/ANALYST                  Y
# 8379                                   PROGRAMMER/ANALYST                  Y
# 8384                                DATABASE ADMINSTRATOR                  Y
# 8814    INFRASTRUCTURE ANALYST (NETWORK SYSTEMS AND DA...                  Y
# 9198                      ECONOMIC ANALYST (GLOBAL TRADE)                  N
# 9661                                DATABASE ADMINSTRATOR                  Y
# 9678                                   PROGRAMMER/ANALYST                  Y
# 9686                                   PROGRAMMER/ANALYST                  Y
# 9706                                  COMPUTER PROGRAMMER                  Y
# 9856                           SYSTEMS ANALYST (BUSINESS)                  Y
# 9860                            COMPUTER SYSTEMS ENGINEER                  Y
# 9867                                    ANALYST/DEVELOPER                  Y
# 9869                                      SYSTEMS ANALYST                  Y
# 9888                      SOFTWARE ENGINEER, APPLICATIONS                  Y
# ...                                                   ...                ...
# 608198                                  SOFTWARE ENGINEER                  Y
# 608941                                 SOFTWARE DEVELOPER                  Y
# 609336                           SENIOR SOFTWARE ENGINEER                  Y
# 611078                                 RESEARCH ASSOCIATE                  Y
# 611392                 POSTDOCTORAL RESEARCH ASSOCIATE II                  Y
# 612142                                  SOFTWARE ENGINEER                  Y
# 612148                                 PROGRAMMER ANALYST                  Y
# 612855                       UFT AUTOMATION TEST ENGINEER                  Y
# 612968                    RELIGOIUS COUNSELING SPECIALIST                  Y
# 613292                     BUSINESS DIRECTOR, FOOD & WINE                  Y
# 615270                                 SOFTWARE DEVELOPER                  Y
# 615378                           COMPUTER SYSTEMS ANALYST                  Y
# 615730                                 PROGRAMMER ANALYST                  Y
# 616311                                 PROGRAMMER ANALYST                  Y
# 617005                                         QA ANALYST                  Y
# 617320                                      AEM ARCHITECT                  Y
# 617415                                  PROJECT ANALYST 2                  Y
# 618301                                         QA ANALYST                  Y
# 618475                    RELIGIOUS COUNSELING SPECIALIST                  Y
# 618638                                 SOFTWARE DEVELOPER                  Y
# 618687                                  SENIOR CONSULTANT                  Y
# 618779                             QA AUTOMATION ENGINEER                  Y
# 619427                                 SOFTWARE DEVELOPER                  Y
# 620483                                  DEVELOPER ANALYST                  Y
# 621127                                 PROGRAMMER ANALYST                  Y
# 621520                                 PROGRAMMER ANALYST                  Y
# 622081                             DATABASE ADMINISTRATOR                  Y
# 623301                                 PROGRAMMER ANALYST                  Y
# 624033                                   SYSTEMS ENGINEER                  Y
# 624262                        COMPUTER PROGRAMMER ANALYST                  Y
#
#         PREVAILING_WAGE          WORKSITE_CITY WORKSITE_STATE  YEAR
# 229            62067.00         WASHINGTON, DC             DC  2011
# 436            62067.00         WASHINGTON, DC             DC  2011
# 691            42786.00            HICKORY, NC             NC  2011
# 1904           60362.00           BETHESDA, MD             MD  2011
# 2482           50357.00     ARLINGTON HEIGHTS,             IL  2011
# 2525           62067.00         WASHINGTON, DC             MD  2011
# 2968           26686.00  RIO PIEDRAS, SAN JUAN             PR  2011
# 5558           65770.00             CHARLOTTE,             NC  2011
# 5646           68682.00           LOS ANGELES,             CA  2011
# 5828           58490.00               HOUSTON,             TX  2011
# 6819           65582.00              NEW YORK,             NY  2011
# 7047           78083.00              BRISBANE,             CA  2011
# 7691           51875.00             BEACHWOOD,             OH  2011
# 7706           40394.00         ABITA SPRINGS,             LA  2011
# 8092           66622.00         WASHINGTON, DC             DC  2011
# 8176           68661.00              NEW YORK,             NY  2011
# 8328           60986.00    WEST DES MOINES, IA             IA  2011
# 8379           58843.00             SALISBURY,             NC  2011
# 8384           63877.00             SALISBURY,             SC  2011
# 8814           39707.20         OKLAHOMA CITY,             OK  2011
# 9198           52395.20      CITY OF INDUSTRY,             CA  2011
# 9661           58843.00             SALISBURY,             NC  2011
# 9678           65582.00          WHITE PLAINS,             NY  2011
# 9686           47986.00          INDIANAPOLIS,             IN  2011
# 9706           54080.00            FRAMINGHAM,             MA  2011
# 9856           58115.00               BUFFALO,             NY  2011
# 9860           46218.00            PITTSBURGH,             PA  2011
# 9867           51043.00            PITTSBURGH,             PA  2011
# 9869           51376.00            PITTSBURGH,             PA  2011
# 9888           98405.00         WASHINGTON, DC             DC  2011
# ...                 ...                    ...            ...   ...
# 608198         76585.60            CARROLLTON,             TX  2017
# 608941         82098.00               ATLANTA,             GA  2017
# 609336         92768.00        NEW YORK,NY USA             NY  2017
# 611078         37669.00         WASHINGTON, DC             DC  2017
# 611392         40706.00                TUCSON,             AZ  2017
# 612142         91603.00            FRAMINGHAM,             MA  2017
# 612148         72800.00                AUSTIN,             TX  2017
# 612855         54662.00             CHARLOTTE,             NC  2017
# 612968         47694.00      BEDFORD HILLS, NY             NY  2017
# 613292         68141.00             EASTON, PA             PA  2017
# 615270         90002.00               HOUSTON,             TX  2017
# 615378         91333.00       MENOMONEE FALLS,             WI  2017
# 615730         82410.00              ROSELAND,             NJ  2017
# 616311         97822.00               TUKWILA,             WA  2017
# 617005         48173.00           MORRISVILLE,             NC  2017
# 617320         94182.00       WASHINGTON, D.C.             DC  2017
# 617415         74818.00           ROSEMONT, IL             IL  2017
# 618301         64771.00           MORRISVILLE,             NC  2017
# 618475         47694.00      BEDFORD HILLS, NY             NY  2017
# 618638         86154.00           BRIDGEWATER,             NJ  2017
# 618687         77896.00              RICHMOND,             VA  2017
# 618779         87568.00              NEW YORK,             NY  2017
# 619427         72280.00             ROSELAND ,             NJ  2017
# 620483         72800.00             AUSTIN, TX             TX  2017
# 621127         78957.00               ST PAUL,             MN  2017
# 621520         60549.00     STERLING, VA 20166             VA  2017
# 622081         97822.00               TUKWILA,             WA  2017
# 623301         59010.00         OVERLAND PARK,             KS  2017
# 624033         82098.00            ALPHARETTA,             GA  2017
# 624262         64272.00        PROVIDENCE , RI             RI  2017
#
# [10020 rows x 11 columns]

# %% [markdown]
# We can see that 10020 rows have this issue.

# %% [markdown]
# I can split the column by comma and select the first position before the comma (extract the city) as such:

# %%
# extract city
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].str.split(",", expand = True)[0]

# %% [markdown]
# Now to confirm the column is fixed and contains no commas:

# %%
# subset with comma
sum(h1b_data['WORKSITE_CITY'].str.contains(",", na= False))
# Out:
# 0

# %% [markdown]
# Perfect.

# %% [markdown]
# We can also see that a number of records in this column (1947) contain numbers which I would not expect to find in these values:

# %%
sum(h1b_data['WORKSITE_CITY'].str.contains("[0-9]", na= False))
# Out:
# 1942

# %%
# subet base on number
h1b_data[h1b_data['WORKSITE_CITY'].str.contains("[0-9]", na= False)]
# Out:
#                CASE_NUMBER          CASE_STATUS  \
# 1721    I-200-10230-588749            CERTIFIED
# 1781    I-200-10236-666127               DENIED
# 2176    I-200-10258-366766               DENIED
# 4379    I-200-10274-143262            CERTIFIED
# 5554    I-200-10277-676223            CERTIFIED
# 6926    I-200-10278-307138            CERTIFIED
# 9882    I-200-10281-495963            CERTIFIED
# 11287   I-200-10284-833059            CERTIFIED
# 13933   I-200-10286-346421            CERTIFIED
# 15279   I-200-10287-772067            CERTIFIED
# 15659   I-200-10288-330847            CERTIFIED
# 15671   I-200-10288-533623            CERTIFIED
# 16530   I-200-10291-603573            CERTIFIED
# 17068   I-200-10291-832168            CERTIFIED
# 19331   I-200-10293-706999            CERTIFIED
# 20882   I-200-10294-673411  CERTIFIED-WITHDRAWN
# 21161   I-200-10295-445627            CERTIFIED
# 22327   I-200-10295-571175  CERTIFIED-WITHDRAWN
# 24542   I-200-10299-228297               DENIED
# 25743   I-200-10301-445606            CERTIFIED
# 26301   I-200-10300-390554  CERTIFIED-WITHDRAWN
# 26329   I-200-10300-560368  CERTIFIED-WITHDRAWN
# 27572   I-200-10302-261642            CERTIFIED
# 30604   I-200-10306-653659            CERTIFIED
# 32922   I-200-10308-162234               DENIED
# 35014   I-200-10312-612627            CERTIFIED
# 36432   I-200-10313-653212            CERTIFIED
# 37754   I-200-10314-077322            CERTIFIED
# 39170   I-200-10316-211407            CERTIFIED
# 40577   I-200-10319-571361            CERTIFIED
# ...                    ...                  ...
# 520342  I-200-17177-900963            WITHDRAWN
# 529065  I-200-15238-480104  CERTIFIED-WITHDRAWN
# 531501  I-200-17187-932798            CERTIFIED
# 532292  I-200-17173-442683            CERTIFIED
# 533902  I-200-17171-050278  CERTIFIED-WITHDRAWN
# 536016  I-200-17191-843059            CERTIFIED
# 537690  I-200-17193-751487            CERTIFIED
# 538626  I-203-17194-267643               DENIED
# 541306  I-200-17195-438234            CERTIFIED
# 546226  I-200-17198-259798            CERTIFIED
# 547669  I-200-17068-981503  CERTIFIED-WITHDRAWN
# 548501  I-200-17201-424549            CERTIFIED
# 550903  I-203-17203-237511               DENIED
# 552348  I-200-17205-381048            CERTIFIED
# 561705  I-200-17213-980260            CERTIFIED
# 562168  I-200-17209-345732            CERTIFIED
# 564124  I-203-17216-050728               DENIED
# 585316  I-200-17075-692590  CERTIFIED-WITHDRAWN
# 587907  I-200-17234-250079            CERTIFIED
# 595961  I-203-17219-642327               DENIED
# 598356  I-200-17243-674684            CERTIFIED
# 600327  I-200-17244-956579            CERTIFIED
# 602235  I-200-17254-743055            WITHDRAWN
# 611436  I-200-16160-574285  CERTIFIED-WITHDRAWN
# 618291  I-200-17263-038106            CERTIFIED
# 619193  I-200-17263-685259            CERTIFIED
# 620125  I-200-17264-096077            CERTIFIED
# 621730  I-203-17265-964915            CERTIFIED
# 622671  I-200-17265-063275            CERTIFIED
# 623207  I-200-17267-519447            CERTIFIED
#
#                                             EMPLOYER_NAME  \
# 1721                             INNOWAVE TECHNOLOGY, LLC
# 1781                                 SOFTPATH SYSTEMS INC
# 2176                             MY-HANH TRIEU, O.D. INC.
# 4379                       UNIVERSAL SOFTWARE CORPORATION
# 5554           OLD MUTUAL BERMUDA BUSINESS SERVICES, INC.
# 6926                        JACKSON THERAPY PARTNERS, LLC
# 9882                 HEALTH CHOICE HOME CARE SERVICE, LLC
# 11287                       NEXAGE TECHNOLOGIES, USA, INC
# 13933                          WOW GLOBAL CORPORATION LLC
# 15279                                        TRULIA, INC.
# 15659                    LARSEN & TOUBRO INFOTECH LIMITED
# 15671                                         KEANE, INC.
# 16530                               MOVEMENTS AFOOT, INC.
# 17068         GLOBAL ENTERPRISE MANAGEMENT SOLUTIONS, INC
# 19331                            HYTECH PROFESSIONALS LLC
# 20882                         SG AMERICAS SECURITIES, LLC
# 21161                       PRIME CARE TECHNOLOGIES, INC.
# 22327                                  HARVARD UNIVERSITY
# 24542           LIGHTHOUSE FELLOWSHIP CHURCH OF GOD, INC.
# 25743                                         ISPACE, INC
# 26301                                         ISPACE, INC
# 26329                                         ISPACE, INC
# 27572                                 NEW YORK UNIVERSITY
# 30604                                    FIRST OBJECT INC
# 32922                                         DELL USA LP
# 35014                                        BCI-IT, INC.
# 36432                            PRIMATICS FINANCIAL, LLC
# 37754   USDA, ARS, WESTERN HUMAN NUTRITION RESEARCH CE...
# 39170                         RATAN HOSPITALITY GROUP LLC
# 40577                                 NEXT MANAGEMENT LLC
# ...                                                   ...
# 520342                             UNIVERSITY OF HARTFORD
# 529065                                   EMORY UNIVERSITY
# 531501                            MORGAN STATE UNIVERSITY
# 532292                           UNIVERSITY OF NEW MEXICO
# 533902                                       SWANKTEK INC
# 536016                                ACHIEVE REHAB, INC.
# 537690                                SVN IT SERVICES INC
# 538626                                          AVIR, LLC
# 541306                  ABILITY WORKS REHAB SERVICES, LLC
# 546226                         UNITED REHAB SOLUTIONS LLC
# 547669                                REPL CONSULTING INC
# 548501                           EBUSINESS SOLUTIONS, INC
# 550903                          COOPER LS DEVELOPMENT LLC
# 552348                             THERAPY ON DEMAND, LLC
# 561705                                        DEEMSYS INC
# 562168                                      COLOR-AD INC.
# 564124                                   DRIKOLOR USA INC
# 585316      LIBERTY CONSULTING & MANAGEMENT SERVICES, LLC
# 587907                            NORTHEASTERN UNIVERSITY
# 595961             INDEPENDENT PET PARTNERS EMPLOYER, LLC
# 598356                    THE HENRY M. JACKSON FOUNDATION
# 600327                         BRONSON METHODIST HOSPITAL
# 602235                                    IBM CORPORATION
# 611436                     UNIVERSITY MEDICAL GROUP, INC.
# 618291                  ABILITY WORKS REHAB SERVICES, LLC
# 619193                  ABILITY WORKS REHAB SERVICES, LLC
# 620125                  ABILITY WORKS REHAB SERVICES, LLC
# 621730                 RED OAK 1750 MESA MANAGEMENT, INC.
# 622671                  ABILITY WORKS REHAB SERVICES, LLC
# 623207                                       APPSBOAT INC
#
#                                                  SOC_NAME    SOC_CODE  \
# 1721            Computer Software Engineers, Applications  15-1031.00
# 1781                                 Computer Programmers  15-1021.00
# 2176                                         Optometrists  29-1041.00
# 4379                              Database Administrators  15-1061.00
# 5554                                   Financial Managers  11-3031.00
# 6926                                  Physical Therapists  29-1123.00
# 9882                                  Physical Therapists  29-1123.00
# 11287           Computer Software Engineers, Applications  15-1031.00
# 13933                                Computer Programmers  15-1021.00
# 15279       Computer Software Engineers, Systems Software  15-1032.00
# 15659                           Computer Systems Analysts  15-1051.00
# 15671                           Computer Systems Analysts  15-1051.00
# 16530                          Instructional Coordinators  25-9031.00
# 17068                           Computer Systems Analysts  15-1051.00
# 19331               Computer Systems Engineers/Architects  15-1099.02
# 20882                        Operations Research Analysts  15-2031.00
# 21161                                Computer Programmers  15-1021.00
# 22327                                       Statisticians  15-2041.00
# 24542                                  Teacher Assistants  25-9041.00
# 25743                           Computer Systems Analysts  15-1051.00
# 26301                                Computer Programmers  15-1021.00
# 26329                             Database Administrators  15-1061.00
# 27572   Area, Ethnic, and Cultural Studies Teachers, P...  25-1062.00
# 30604                                Computer Programmers  15-1021.00
# 32922              Electronics Engineers, Except Computer  17-2072.00
# 35014                                Computer Programmers  15-1021.00
# 36432                           Computer Systems Analysts  15-1051.00
# 37754                                            Chemists  19-2031.00
# 39170                                    Lodging Managers  11-9081.00
# 40577                                              Models  41-9012.00
# ...                                                   ...         ...
# 520342                   BUSINESS TEACHERS, POSTSECONDARY     25-1011
# 529065                             BIOLOGICAL TECHNICIANS     19-4021
# 531501                 ZOOLOGISTS AND WILDLIFE BIOLOGISTS     19-1023
# 532292         HEALTH SPECIALTIES TEACHERS, POSTSECONDARY     25-1071
# 533902                  SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 536016                                PHYSICAL THERAPISTS     29-1123
# 537690                          COMPUTER SYSTEMS ANALYSTS     15-1121
# 538626                               DESIGNERS, ALL OTHER     27-1029
# 541306                                PHYSICAL THERAPISTS     29-1123
# 546226                                PHYSICAL THERAPISTS     29-1123
# 547669                          COMPUTER SYSTEMS ANALYSTS     15-1121
# 548501                               COMPUTER PROGRAMMERS     15-1131
# 550903                               DESIGNERS, ALL OTHER     27-1029
# 552348                                PHYSICAL THERAPISTS     29-1123
# 561705                  SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 562168       COMPUTER NUMERICALLY CONTROLLED MACHINE TOOL     51-4012
# 564124         BUSINESS OPERATIONS SPECIALISTS, ALL OTHER     13-1199
# 585316                                MANAGEMENT ANALYSTS     13-1111
# 587907                ENGINEERING TEACHERS, POSTSECONDARY     25-1032
# 595961                                   CHIEF EXECUTIVES     11-1011
# 598356                             BIOLOGICAL TECHNICIANS     19-4021
# 600327                 PHYSICIANS AND SURGEONS, ALL OTHER     29-1069
# 602235                  SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
# 611436                                       AUDIOLOGISTS     29-1181
# 618291                                PHYSICAL THERAPISTS     29-1123
# 619193                                PHYSICAL THERAPISTS     29-1123
# 620125                                PHYSICAL THERAPISTS     29-1123
# 621730                                  GRAPHIC DESIGNERS     27-1024
# 622671                                PHYSICAL THERAPISTS     29-1123
# 623207                  SOFTWARE DEVELOPERS, APPLICATIONS     15-1132
#
#                                        JOB_TITLE FULL_TIME_POSITION  \
# 1721        SENIOR PRINCIPAL SOFTWARE CONSULTANT                  Y
# 1781                         COMPUTER PROGRAMMER                  Y
# 2176                                 OPTOMETRIST                  N
# 4379                      DATABASE ADMINISTRATOR                  Y
# 5554          ASSISTANT VICE PRESIDENT - HEDGING                  Y
# 6926                          PHYSICAL THERAPIST                  Y
# 9882                          PHYSICAL THERAPIST                  Y
# 11287                          SOFTWARE ENGINEER                  Y
# 13933                         PROGRAMMER/ANALYST                  Y
# 15279                    DATA WAREHOUSE ENGINEER                  Y
# 15659                COMPUTER PROGRAMMER ANALYST                  Y
# 15671                   COMPUTER SYSTEMS ANALYST                  Y
# 16530                  INSTRUCTIONAL COORDINATOR                  N
# 17068                           BUSINESS ANALYST                  Y
# 19331       FINANCIAL CLIENT SOLUTIONS ARCHITECT                  Y
# 20882                              JUNIOR TRADER                  Y
# 21161                         SOFTWARE DEVELOPER                  Y
# 22327                         RESEARCH ASSOCIATE                  Y
# 24542                     FIRST GRADE SUPERVISOR                  N
# 25743                   COMPUTER SYSTEMS ANALYST                  Y
# 26301                        COMPUTER PROGRAMMER                  Y
# 26329                     DATABASE ADMINISTRATOR                  Y
# 27572                             MASTER TEACHER                  Y
# 30604                         PROGRAMMER ANALYST                  Y
# 32922                TELECOMMUNICATIONS ENGINEER                  Y
# 35014                         PROGRAMMER ANALYST                  Y
# 36432            SENIOR COMPUTER SYSTEMS ANALYST                  Y
# 37754                     NUTRITIONIST (CHEMIST)                  Y
# 39170                            LODGING MANAGER                  Y
# 40577                              FASHION MODEL                  Y
# ...                                          ...                ...
# 520342                       ASSISTANT PROFESSOR                  Y
# 529065                       RESEARCH SPECIALIST                  Y
# 531501     OYSTER GENOMICS SCIENTIST- RESEARCHER                  Y
# 532292                       ASSISTANT PROFESSOR                  Y
# 533902                          ORACLE DEVELOPER                  Y
# 536016                        PHYSICAL THERAPIST                  Y
# 537690                        PROGRAMMER ANALYST                  Y
# 538626                                  DESIGNER                  Y
# 541306                        PHYSICAL THERAPIST                  Y
# 546226                        PHYSICAL THERAPIST                  N
# 547669                         SENIOR CONSULTANT                  Y
# 548501                        PROGRAMMER ANALYST                  Y
# 550903            CREATIVE CONSULTANT & DESIGNER                  Y
# 552348                        PHYSICAL THERAPIST                  Y
# 561705                        SOFTWARE DEVELOPER                  Y
# 562168                            SR. PROGRAMMER                  Y
# 564124                   CHIEF OPERATING OFFICER                  Y
# 585316                          BUSINESS ANALYST                  Y
# 587907                        PART-TIME LECTURER                  Y
# 595961                   CHIEF EXECUTIVE OFFICER                  Y
# 598356                        RESEARCH ASSOCIATE                  Y
# 600327  HOSPITALIST/INFECTIOUS DISEASE PHYSICIAN                  N
# 602235                  DELIVERY PROJECT MANAGER                  Y
# 611436                               AUDIOLOGIST                  Y
# 618291                        PHYSICAL THERAPIST                  Y
# 619193                        PHYSICAL THERAPIST                  Y
# 620125                        PHYSICAL THERAPIST                  Y
# 621730                          GRAPHIC DESIGNER                  Y
# 622671                        PHYSICAL THERAPIST                  Y
# 623207                        SOFTWARE  ENGINEER                  Y
#
#         PREVAILING_WAGE                   WORKSITE_CITY WORKSITE_STATE  YEAR
# 1721          113651.00                       SUITE 230             CA  2011
# 1781           65582.40                     SUITE # 903             NY  2011
# 2176           62545.60               6015 WILSON BLVD.             VA  2011
# 4379           56701.00           3403 YERBA BUENA ROAD             CA  2011
# 5554          125882.00                      32ND FLOOR             NY  2011
# 6926           62233.60        3400 W WASHINGTON STREET             IL  2011
# 9882           52437.00                          #47644             MI  2011
# 11287          56326.40                       SUITE 104             NJ  2011
# 13933          59384.00             3114 GRANDVIEW BLVD             WI  2011
# 15279          97178.00                       SUITE 310             CA  2011
# 15659          51230.00                       SUITE 126             TX  2011
# 15671          68598.00            SUITE 300 SCOTTSDALE             AZ  2011
# 16530          36233.60                   49 W 27TH ST.             NY  2011
# 17068          51230.00                   6555 SIERR DR             TX  2011
# 19331          74963.00                            #900             DC  2011
# 20882          80059.00     1221 AVENUE OF THE AMERICAS             NY  2011
# 21161          50440.00                       SUITE 400             GA  2011
# 22327          61152.00             651 HUNTINGTON AVE.             MA  2011
# 24542          17492.80              1361 CHRISTIAN AVE             IN  2011
# 25743          54517.00                       SUITE 208             NJ  2011
# 26301          52541.00                       SUITE 208             NJ  2011
# 26329          60757.00                       SUITE 208             NJ  2011
# 27572          49440.00                    726 BROADWAY             NY  2011
# 30604          62150.00            FOSTER CITY CA 94404             CA  2011
# 32922          74536.00                         RR2E-32             TX  2011
# 35014          55432.00               4201 WILSON BLVD.             VA  2011
# 36432          79310.00                       SUITE 300             VA  2011
# 37754          53768.00  430 WEST HEALTH SCIENCES DRIVE             CA  2011
# 39170          32261.00                     625 RT 46 E             NJ  2011
# 40577          45489.60                     15 WATTS ST             NY  2011
# ...                 ...                             ...            ...   ...
# 520342         56360.00           200 BLOOMFIELD AVENUE             CT  2017
# 529065         29390.00         2165 NORTH DECATUR ROAD             GA  2017
# 531501         52624.00              10545 MACKALL ROAD             MD  2017
# 532292        100550.00         3001 BROADMOOR BLVD. NE             NM  2017
# 533902         52166.00                      40TH FLOOR             IL  2017
# 536016         62858.00              #19820 DETROIT MSA             MI  2017
# 537690         66040.00                        TETEBOR0             NJ  2017
# 538626         35589.00                   29 CLINTON ST             NY  2017
# 541306         62858.00              #19820 DETROIT MSA             MI  2017
# 546226         78540.80        #47644 MI METRO DIVISION             MI  2017
# 547669         56264.00                   SUITE 126-128             AR  2017
# 548501         56347.00                   330 E 22ND ST             IL  2017
# 550903         35589.00                   29 CLINTON ST             NY  2017
# 552348         67683.00      #19100 DALLASFORTWORTH MSA             TX  2017
# 561705         86923.00               1400 MORRIS DRIVE             PA  2017
# 562168         51085.00                  7200 GARY ROAD             VA  2017
# 564124        120000.00             2471 PERALTA STREET             CA  2017
# 585316         52062.00               1000 SKOKIE BLVD.             IL  2017
# 587907         74588.80             401 TERRY AVENUE N.             WA  2017
# 595961        298792.00     3RD AND 4TH FLOOR SUITE 333             NY  2017
# 598356         56451.00            4301 JONES BRIDGE RD             MD  2017
# 600327        117561.60                          BOX 57             MI  2017
# 602235         84406.00            1 BEAVER VALLEY ROAD             DE  2017
# 611436         77230.00                       SUITE 845             CA  2017
# 618291         67766.00         #41740 SAN DIEGO CA MSA             CA  2017
# 619193         62858.00              #19820 DETROIT MSA             MI  2017
# 620125         67766.00         #41740 SAN DIEGO CA MSA             CA  2017
# 621730         39000.00                6040 E MONTECITO             AZ  2017
# 622671         67766.00         #41740 SAN DIEGO CA MSA             CA  2017
# 623207         74443.00                1930 N POPLAR ST             NC  2017
#
# [1942 rows x 11 columns]

# %% [markdown]
# Because the data was given incorrectly, I will drop these rows from the data set and check it was successful.

# %%
# drop these rows
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].astype(str)
h1b_data = h1b_data[~h1b_data.WORKSITE_CITY.str.contains("[0-9]")]

# %%
sum(h1b_data['WORKSITE_CITY'].str.contains("[0-9]", na= False))
# Out:
# 0

# %% [markdown]
# Another strange artifact is that some records (199) begin with a tag ('&NBSP;' before their actual value in the city column.

# %%
sum(h1b_data['WORKSITE_CITY'].str.contains("&NBSP;", na= False))
# Out:
# 199

# %%
# replace string ""
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace("&NBSP;", "", regex = True)

# %%
sum(h1b_data['WORKSITE_CITY'].str.contains("&NBSP;", na= False))
# Out:
# 0

# %% [markdown]
# A final problem I have seen before is periods in place of missing data or accidentally dropped into the data set. It is not okay to replace them blindly in this case because some cities contain periods (eg "St. Louis). This is also important for these data because I believe data will be entered such that state is replicated with a period following the city (eg: St. Louis. MO). There are also tons of problems which are related to periods in databases which I want to check for - such as individuals putting their street name in the cities column (eg: Apple St.).

# %%
sum(h1b_data['WORKSITE_CITY'].str.contains("\.", na= False))
# Out:
# 21549

# %%
# make subset of cities with periods
periods_df = h1b_data[h1b_data['WORKSITE_CITY'].str.contains("\.", na = False)]

# %%
periods_df['WORKSITE_CITY'].unique().tolist()
# Out:
# ['ST. LOUIS',
#  'ST. LOUIS PARK',
#  'ST. THOMAS',
#  'ST. CROIX',
#  'MT. VERNON',
#  'ST. PETERSBURG',
#  'ST. PAUL',
#  'ST. JOSEPH',
#  'ST. AUGUSTINE',
#  "ST. MARY'S CITY",
#  'ST. CHARLES',
#  'FT. DODGE',
#  'PORT ST. LUCIE',
#  'FT. BELVOIR',
#  'MT. LAUREL',
#  'WASHINGTON D.C',
#  'S. PLAINFIELD',
#  'MS. STATE',
#  'NORTH ST. PAUL',
#  'MISS. STATE',
#  'MOON TWP.',
#  'FT. LEE',
#  'WASHINGTON D.C.',
#  'ST. ALBANS',
#  'MT. RANIER',
#  'FT. LAUDERDALE',
#  'N. MIAMI',
#  'ST. CLOUD',
#  'ST. PORTLAND',
#  'ST. JAMES',
#  'ST. GENEVIEVE',
#  'W.COLUMBIA',
#  'ST.LOUIS',
#  'FT. WAYNE',
#  'FT. WORTH',
#  'ST. CLAIRSVILLE',
#  'MT. CLEMENS',
#  'WAHINGTON D.C.',
#  'FT. PIERCE',
#  'FT. MYERS',
#  'STE. GENEVIEVE',
#  'ST. LUCIE',
#  'ST. CLAIR SHORES',
#  'FT. COLLINS',
#  'CT. FRANKLIN',
#  'ST. GEORGE',
#  'ST. PETERS',
#  'MT. PLEASANT',
#  'MT. ZION',
#  'ST.  LOUIS',
#  'INVER GROVE HTS.',
#  'ST. SIMONS',
#  'S. MINNEAPOLIS',
#  'ST.PAUL',
#  'NORTH ST. PETERSBURG',
#  'WARRENSVILLE HTS.',
#  'FT. CARSON',
#  'E. LANSING',
#  'LAKE ST. LOUIS',
#  'S.W.',
#  'ST. PETE BEACH',
#  'ROWLAND HTS.',
#  'ST. PETER',
#  'ST. HELENA',
#  'MONMOUTH JCT.',
#  'MT. MORRIS',
#  'ST. PTERSBURG',
#  'ST. ROSE',
#  'CUYAHOGA HEIGHTS.',
#  'N. LAS VEGAS',
#  'SAINT. CLOUD',
#  'SOUTH ST. PAUL',
#  'ST. IOWA CITY',
#  'ST. JOHN',
#  'ST. LOUI',
#  'BEDFORD HTS.',
#  'SAN DIEGO.',
#  'MONMOUTH JN.',
#  'MONROE TWP.',
#  'ST. BOISE',
#  'ST.PETERSBURG',
#  'FT. MEYERS',
#  'ST. LOIUS',
#  'S. BELOIT',
#  'WASHINGTON. D.C.',
#  'MT. PROSPECT',
#  'ST. FRANCIS',
#  'MT.PLEASANT',
#  'FT. WASHINGTON',
#  'MT. CARROLL',
#  'FT. LORAMIE',
#  'N.E. PALM BAY',
#  'ST. HELENS',
#  'SAULT STE. MARIE',
#  'ST. LOUISC',
#  'MT. OLIVE',
#  'MT. KISCO',
#  'RICHMOND HTS.',
#  'W. GREENWICH',
#  'ALLENTOWN. PA.',
#  'N. QUINCY',
#  'PORT ST. JOHN',
#  'ST.CLOUD',
#  'ST. MATTHEWS',
#  'MT. DORA',
#  'CLINTON TWP.',
#  'N. FT. MYERS',
#  'FT. IRWIN',
#  'MT. BRADDOCK',
#  'WASHINTGON D.C.',
#  'ST.CHARLES',
#  'W. SACRAMENTO',
#  'ST. BONAVENTURE',
#  'ST. PETE',
#  'SHAKER HTS.',
#  '.',
#  'MT. GILEAD',
#  'MOUNTAIN VIEW.',
#  'E. CLEVELAND',
#  'FT. LAUDERDALE-DAVIE',
#  'SO. SAN FRANCISCO',
#  'ST. JOHNSBURY',
#  'LONG IS. CITY',
#  '. PORT WASHINGTON',
#  'E.MICHIGAN ST',
#  'SO. NORWALK',
#  'ST. TERESA',
#  'ST.CLAIR SHORES',
#  'N. PEAPACK',
#  'N. MIAMI BEACH',
#  'ST. PAULS',
#  'MINNEAPOLIS/ST. PAUL',
#  'FT.LAUDERDALE',
#  'N. CHELMSFORD',
#  'VAN BUREN TWP.',
#  'W. HOLLYWOOD',
#  'MT. STERLING',
#  'FORT. LEE',
#  'S. ST. PUAL',
#  'MT. VIEW',
#  'S. ST. PAUL',
#  'ST. CROIX FALLS',
#  'ST. PARIS',
#  'N. KANSAS CITY',
#  'ST. MARYS',
#  'MT. AIRY',
#  'NW. WASHINGTON',
#  'E. HARTFORD',
#  'FT. GEORGE MEADE',
#  'ST. CATHARINE',
#  'ST.SAN JOSE',
#  'NO. BABYLON',
#  'FT. DEFIANCE',
#  'ST. JAMESST',
#  'NEW BRUNSWICK DR.',
#  'MT.KISCO',
#  "ST. MARY'S",
#  'N. READING',
#  'ST. PETERSBUG',
#  'ST. FRANICS',
#  'ST. GABRIEL',
#  'S. EL MONTE',
#  'ST.PETERBURG',
#  'ST.CHARLOTTE',
#  'EAST ST. LOUIS',
#  'ST. ANTHONY',
#  'PORT ST. JOE',
#  'HIGHLAND HTS.',
#  'FT. MILL',
#  'MT. ARLINGTON',
#  'E. PEORIA',
#  'ST. PETERESBURG',
#  'SO. LANCASTER',
#  'ST. CLAIR',
#  'ST. ALANS',
#  'FT. BENNING',
#  'N. WILKESBORO',
#  'W. BLOOMFIELD',
#  'ST.LOUIS. MO',
#  'COMMERCE TWP.',
#  'VBROWN@DUANEMORRIS.COM',
#  'W. HENRIETTA',
#  'S. AURORA',
#  'W. LAFAYETTER',
#  'BROWNSTOWN TWP.',
#  'N. DARTMOUTH',
#  'MT. CARMEL',
#  'FT. STOCKTON',
#  'E. SETAUKET',
#  'ST .PAUL',
#  'BAY ST. LOUIS',
#  'STA. CLARA',
#  'S. PITTSBURG',
#  'ST. MAYO',
#  'ST.PETERSBIRG',
#  'E. ADA',
#  'ST. CLAIRE SHORES',
#  'UPPER ST. CLAIR',
#  'S. HOLLAND',
#  'MT. POCONO',
#  'MT. AYR',
#  'SO. BURLINGTON',
#  'SOUTH EL. MONTE',
#  'N.MIAMI',
#  'N. SMITHFIELD',
#  'E. AMHERST',
#  'CLEVELAND HTS.',
#  'ST.LOUIS PARK',
#  'ST. LUIS PARK',
#  'MT.LAUREL',
#  'FT.  WORTH',
#  'WASHINGTON D. C.',
#  'ST. LOUIS MISSOURI',
#  'MARINE ON ST. CROIX',
#  'WEST ST. PAUL',
#  'ST. STEPHEN',
#  'N. CHARLESTON',
#  'E. WALPOLE',
#  'FT. LUPTON',
#  'W. LEBANON',
#  'N. KENT',
#  'MT. JULIET',
#  'E. NORRITON',
#  'DR.EAGAN',
#  'ST. CLAIRE',
#  'LONGISLAND.CITY',
#  'S. JORDAN',
#  'ROCHESTER RD.',
#  'ST. DAVIDS',
#  'MT. HOLLY',
#  'FT. MITCHELL',
#  'E. NORTHPORT',
#  'ST.THOMAS',
#  'ST. PETERSBURGH COURT',
#  'SW. FARGO',
#  'L.I.C.',
#  'ST. PETERSBURGH',
#  'FT. VALLEY',
#  'S. HILLVIEW DRIVE',
#  'DR. LANGHORNE',
#  'WASHIONTON D.C.',
#  'STA. CLARITA',
#  'WHITE RIVER JCT.',
#  'COLUMBUS OH.',
#  'MT.OLIVE',
#  'ST. MARTINVILLE',
#  'MT. CHARLESTON',
#  'ONE SHIELDS AVE.',
#  'CRANBERRY TWP.',
#  'DR.BEAVERTON',
#  'N. SALT LAKE CITY',
#  'WASHINGTON.',
#  'E. FALMOUTH',
#  'W. NORRITON',
#  'S. PORTLAND',
#  'BLDG.',
#  'MR. LAUREL',
#  'ST. FRANCISVILLE',
#  'MT. GRETNA',
#  'FT. MORGAN',
#  'E. ADA TOWNSHIP',
#  'FT. BRAGG',
#  'N. PLYMOUTH',
#  'FT. WRIGHT',
#  'E. MOLINE',
#  'JONESD@JACKSONLEWIS.COM',
#  'S. SAN FRANCISCO',
#  'ST. MARIES',
#  'E.BRUNSWICK',
#  'PHILADELPHIA PA.',
#  'N. AMITYVILLE',
#  'HARRISON TWP.',
#  'ST. GAFFNEY',
#  'ST. HELEN',
#  'ST.LOIUS',
#  'CUSTER AVE.',
#  'ST.LOUIS CITY',
#  'W. CONSHOHOCKEN',
#  'ST. LOUSIS',
#  'W. HOUSTON',
#  'S. TUKWILA',
#  'HAZLE TWP.',
#  'W. ROXBURY',
#  'FT. SILL',
#  'SO. MINNEAPOLIS',
#  'PALO ALTO.',
#  'FT. RILEY',
#  'S.HAUPPAUGE',
#  'E. CHANHASSEN',
#  'ST. IGNACE',
#  'ST.JOSEPH',
#  'E. HANOVER',
#  'S. ATTLEBORO',
#  'EL SEGUNDO BLVD.',
#  'S. OZONE PARK',
#  'STA. ANA',
#  'STONE MTN.',
#  'E. SYRACUSE',
#  'N. ARLINGTON',
#  'PRINCETON JN.',
#  'WASHINGRTON D.C.',
#  'ST. MICHAEL',
#  'LIVONIA.',
#  'FT.WORTH',
#  '. SUNNYVALE',
#  'UNIVERSITY HTS.',
#  'S. WAVERLY',
#  'JOHN S. TOLL PHYSICS BUILDING',
#  'METUCHEN.',
#  'DR. URBANDALE',
#  'MS. STAE',
#  'ST. TORRANCE',
#  'BRONX.NEW YORK',
#  'N.WASHINGTON AVE',
#  'ST. CLOUDS',
#  'ST. PETERSBUGH',
#  'N. HOUSTON',
#  'PRINCETON JCT.',
#  'ST. JOHNS',
#  'N. NEWTON',
#  'FOSTER PARK DR.',
#  'W. TRENTON',
#  'FT. PAYNE',
#  'ST. JOHNSVILLE',
#  'N.W. WASHINGTON',
#  'ST. LOUISE',
#  'E. EL MONTE',
#  'ST. LOUISPARK',
#  'W. SEATTLE',
#  'S. MILWAUKEE',
#  'SAULT ST. MARIE',
#  'ST. JOSPEH',
#  'FT. SMITH',
#  'N.BETHESDA',
#  'MT. PROSPECT DR.',
#  'VALATIE.',
#  'ST. JOSEPHS',
#  'PARMA HTS.',
#  'ST.ELMIRA',
#  'NO. BURNSWICK',
#  'SGT. BLUFF',
#  'COMMACK. NY',
#  'W. CHICAGO',
#  'N. BETHESDA',
#  'N. OXFORD',
#  'N. HOLLYWOOD',
#  'W. MEMPHIS',
#  'E. RANCHO DOMINGUEZ',
#  'DR. RICHARDSON',
#  'N. FORT MYERS',
#  'H.',
#  'FT. GAINES',
#  'N. WILSON',
#  'MT. HOLLY SPRINGS',
#  'FT. LAUDERDALEFT. LAUDERDALE',
#  'ST. JOHNSBURTY',
#  'NO. LITTLE ROCK',
#  'N. OMAHA',
#  'MT. RAINIER',
#  "ST. PAUL'S",
#  'ST.PITTSBURGH',
#  'N. CANTON',
#  'RENCHVILLE RD.',
#  'DALLAS FT. WORTH',
#  'DR. PAWTUCKET',
#  'ATLANTIC CITY INTL. AIRPORT',
#  'MT. HAMILTON',
#  'N. BILLERICA',
#  'NW WASHINGTON D.C.',
#  'D.C.',
#  'ST.AUGUSTINE',
#  'W. COLUMBIA',
#  'ST. SAN JOSE',
#  'METRO ST. LOUIS',
#  'ST . PAUL',
#  'E.HARTFORD',
#  'ST. PALO ALTO',
#  'PT. RICHEY',
#  'N. CHESTERFIELD',
#  'SOUTH EL.MONTE',
#  'S. RICHFIELD',
#  'E. LIBERTY',
#  'NEW ALBANY.',
#  'SOUTHBOROUGH.',
#  'W. DES MOINES',
#  'SR. CHARLES',
#  'ST.HONOLULU',
#  'DEARBORN HTS.',
#  'MT.VERNON',
#  'S. LACROSSE',
#  'ST. MARY OF THE WOODS',
#  'E. PLYMOUTH',
#  'ST. MICHAELS',
#  'FT. WINGATE',
#  'ST. LOUIS PARTK',
#  'FT. MCCOY',
#  'N.FORT MYERS',
#  'N. BELLMORE',
#  'E. COLLINGSWOOD',
#  'MT. LAYREL',
#  'N. WHITE PLAINS',
#  'WASHINTON D.C',
#  'MT. PROSPECTS',
#  'PORT  ST. JOE',
#  'SYMMES TWP.',
#  'E. PETERSBURG',
#  'FT. WALTON BEACH',
#  'ST. GARDENA',
#  'ST. PETERSBERG',
#  'FT. THOMAS',
#  'ST. DAVID',
#  'S. MIAMI',
#  'ST. ALBANY',
#  'ST.  PETERSBURG',
#  'N.CHICAGO',
#  'E. MILAN',
#  'ST. PHOENIX',
#  'N.W.ROCHESTER',
#  'ST.. PETERSBURG',
#  'ST. COLUMBUS',
#  'ST. PERTERSBURG',
#  'EAGAN.',
#  'FT. LAUDERSALE',
#  'MT. LAURAL',
#  'S. FARGO',
#  'LAKE ST.LOUIS',
#  'ST. PETERSBURH',
#  'N. CHICAGO',
#  'NORTH FT. MYERS',
#  'ST . LOUIS',
#  'ST. BRISTOL',
#  'W. CHESTERFIELD',
#  'ST. LOUIS CITY',
#  'ST. JOE',
#  'VANBUREN TWP.',
#  'CLEVELAND (CUYAHOGA HTS.)',
#  'ST. ALBANS CITY',
#  'MT. OLIVET',
#  'SO. EL MONTE',
#  'FT. GEORGE G. MEADE',
#  'ST. ROBERT',
#  'E. SILSBEE',
#  'FT. FAIRFIELD',
#  'ST. RICHMOND',
#  'MR. VERNON',
#  'E. CHICAGO',
#  'FT. EDWARD',
#  'WOOLWICH TWP.',
#  'E. WEYMOUTH',
#  'EWING TWP.',
#  'ST. LEO',
#  'TAMPA.',
#  'N. MYRTLE BEACH',
#  'N. LITTLE ROCK',
#  'ST. LUIS',
#  'S. THOMAS',
#  'DR.MCLEAN',
#  'MAYFIELD HTS.',
#  'SAINT.LOUIS',
#  'FT. PAINE',
#  'S.FARGO',
#  'ST.HARRISBURG',
#  'HAMILTON TWP.',
#  'SUB BASE ST. THOMAS',
#  'ST. ANN',
#  'MT.PROSPECT',
#  'PLYMOUTH TWP.',
#  'MT. LAURELL',
#  'ST.VISTA',
#  'FT. YATES',
#  'MT.CARMEL',
#  'WASHINGTON  D.C.',
#  'ST. LANSING',
#  'S .BLOOMINGTON',
#  'MT. SHASTA',
#  'WATERFORD TWP.',
#  'W. ENGLEWOOD',
#  'ST. CARLOS',
#  'ST. MURRAY',
#  'N. BROOKLYN PARK']

# %% [markdown]
# **List of problems found:**
# * WAHINGTON D.C.
# * WASHINGTON. D.C.
# * WASHIONTON D.C.
# * WASHINGRTON D.C.
# * NW WASHINGTON D.C.
# * WASHINTON D.C'
# * D.C.
# * WASHINGTON.
# * CUYAHOGA HEIGHTS.
# * SAN DIEGO.
# * MT.PLEASANT
# * ALLENTOWN. PA.
# * '.'
# * . PORT WASHINGTON
# * MINNEAPOLIS/ST. PAUL
# * S. ST. PUAL
# * ST.LOUIS. MO
# * ST.LOIUS
# * ST. LOUSIS
# * ST. LOUISE
# * ST.LOUIS CITY
# * VBROWN@DUANEMORRIS.COM
# * ST.PETERSBIRG
# * MARINE ON ST. CROIX
# * DR.EAGAN
# * L.I.C.
# * DR. LANGHORNE
# * COLUMBUS OH.
# * DR.BEAVERTON
# * BLDG.
# * JONESD@JACKSONLEWIS.COM
# * PHILADELPHIA PA.
# * CUSTER AVE.
# * LIVONIA.
# * . SUNNYVALE
# * JOHN S. TOLL PHYSICS BUILDING
# * METUCHEN.
# * DR. URBANDALE
# * MS. STAE
# * BRONX.NEW YORK
# * N.WASHINGTON AVE
# * FOSTER PARK DR.
# * MT. PROSPECT DR.
# * VALATIE.
# * COMMACK. NY
# * DR. RICHARDSON
# * H.
# * FT. LAUDERDALEFT. LAUDERDALE
# * FT. LAUDERSALE
# * ST. JOHNSBURTY
# * RENCHVILLE RD.
# * DALLAS FT. WORTH
# * DR. PAWTUCKET
# * ATLANTIC CITY INTL. AIRPORT
# * SOUTHBOROUGH.
# * SR. CHARLES
# * EAGAN.
# * ST.. PETERSBURG
# * CLEVELAND (CUYAHOGA HTS.)
# * TAMPA.
# * SUB BASE ST. THOMAS

# %% [markdown]
# I will start fixing these issues to allow for easier geo-encoding and geo work in the future. I will make lists of common errors which can be replaced by the same city and then use a hash table to make all the replacements in one call.
#
# I will begin with swooping replacements which can be replaced by one term.

# %%
# replaced with WASHINGTON
wash_replace = ["WAHINGTON D.C.", "WASHINGTON. D.C.", "WASHIONTON D.C.", "WASHINGRTON D.C.", 
                "NW WASHINGTON D.C.", "WASHINTON D.C", "D.C.", "WASHINGTON.", "WASHINGTON D.C", "WASHINGTON D. C.", 
                "WASHINGTON D.C.", "WASHINTGON D.C.", "N.WASHINGTON AVE"]
# replaced with St. Louis
stLouis_replace = ["ST.LOUIS. MO", "ST.LOIUS", "ST. LOUSIS", "ST. LOUISE",  "ST.LOUIS CITY"]

# replaced with ""
trash_replace = [". ", "VBROWN@DUANEMORRIS.COM", "DR.EAGAN", "L.I.C.", "DR. LANGHORNE", "DR.BEAVERTON", 
                 "BLDG.", "JONESD@JACKSONLEWIS.COM", "CUSTER AVE.", "JOHN S. TOLL PHYSICS BUILDING", 
                 "DR. URBANDALE", "MS. STAE", "FOSTER PARK DR", "MT. PROSPECT DR.", "DR. RICHARDSON",
                 "H.", "RENCHVILLE RD.", "DR. PAWTUCKET"]

# %% [markdown]
# Now for the other mistakes:

# %%
# change lists to tuples
period_hash =  { "CUYAHOGA HEIGHTS." : "CUYAHOGA HEIGHTS",  "SAN DIEGO." : "SAN DIEGO", 
                 "MT.PLEASANT" : "MT. PLEASANT", "ALLENTOWN. PA." : "ALLENTOWN", 
                 ". PORT WASHINGTON" : "PORT WASHINGTON", "MINNEAPOLIS/ST. PAUL" : "MINNEAPOLIS", 
                 "S. ST. PUAL" : "ST. PAUL", "METUCHEN." : "METUCHEN", "BRONX.NEW YORK": "BRONX", 
                 "VALATIE." : "VALATIE", "COMMACK. NY" : "COMMACK", "FT. LAUDERDALEFT. LAUDERDALE" : "FT. LAUDERDALEFT", 
                 "ST. JOHNSBURTY" : "ST. JOHNSBURY", "DALLAS FT. WORTH" : "DALLAS", 
                 "ATLANTIC CITY INTL. AIRPORT" : "ATLANTIC CITY", "SOUTHBOROUGH." : "SOUTHBOROUGH", 
                 "EAGAN." : "EAGAN", "ST.. PETERSBURG" : "ST. PETERSBURG", "CLEVELAND (CUYAHOGA HTS.)" : "CLEVELAND", 
                 "TAMPA." : "TAMPA", "SUB BASE ST. THOMAS" : "ST. THOMAS" }

# %% [markdown]
# Next, I will make a dictionary of key value pairs from the lists made above:

# %%
# generate key value pairs:
wash = dict.fromkeys(wash_replace, 'WASHINGTON')
louis = dict.fromkeys(stLouis_replace, 'ST. LOUIS')
trash = dict.fromkeys(trash_replace, '')

# %% [markdown]
# Now, I will apply these key values pairs to make the appropriate replacements.

# %%
# apply replacements for each list:
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace(wash)
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace(louis)
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace(trash)

# %% [markdown]
# Finally, I will apply the hash table to replace unique errors which cannot be replaced with a single term.

# %%
# apply hash replacement:
h1b_data = h1b_data.replace({"WORKSITE_STATE": period_hash})

# %% [markdown]
# Finally, there are a few records which cannot be replaced using a hash table (for a seemingly unknown reason). I will replace manually.

# %%
# manual replacements:
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace(". PORT WASHINGTON", "PORT WASHINGTON")
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace(". SUNNYVALE", "SUNNYVALE")
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace(":LAS VEGAS" , "LAS VEGAS" )
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace('"FRAMINGHAM' , 'FRAMINGHAM' )
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace('"NEW YORK' , 'NEW YORK' )
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace("'CHARLESTON" , "CHARLESTON" )
h1b_data['WORKSITE_CITY'] = h1b_data['WORKSITE_CITY'].replace("ÒAKBROOK TERRACE" , "OAKBROOK TERRACE" )

# %% [markdown]
# Errors solved.

# %% [markdown]
# Next, I need to change the state abbreviations to their complete names to latter merge then with cities. Changing the abbreviated states into their full forms can be done using a Python dictionary as a hashmap.

# %%
# hash table for states
state_hash = { "AK" : "alaska",  "AL" : "alabama", "AR" : "arkansas", "AZ" : "arizona", 
               "CA" : "california", "CO" : "colorado", "CT" : "connecticut", "DC" : "district of columbia",
               "DE" : "delaware", "FL" : "florida", "GA" : "georgia", "HI" : "hawaii",
               "IA" : "iowa", "ID" : "idaho", "IL" : "illinois", "IN" : "indiana",
               "KS" : "kansas", "KY" : "kentucky", "LA" : "louisiana", "MA" : "massachusetts",
               "MD" : "maryland", "ME" : "maine", "MI" : "michigan", "MN" : "minnesota",
               "MO" : "missouri", "MS" : "mississippi", "MT" : "montana", 
               "NC" : "north carolina", "ND" : "north dakota", "NE" : "nebraska", "NH" : "new hampshire",
               "NJ" : "new jersey", "NM" : "new mexico", "NV" : "nevada", "NY" : "new york",
               "OH" : "ohio", "OK" : "oklahoma", "OR" : "oregon", "PA" : "pennsylvania",
               "PR" : "puerto rico", "RI" : "rhode island", "SC" : "south carolina", "SD" : "south dakota",
               "TN" : "tennessee", "TX" : "texas", "UT" : "utah", "VA" : "virginia", 
               "VT" : "vermont", "WA" : "washington", "WI" : "wisconsin", "WV" : "west virginia", 
               "WY" : "wyoming" }

# %% [markdown]
# Replace the abbreviations:

# %%
# replace the values 
h1b_data = h1b_data.replace({"WORKSITE_STATE": state_hash})

# %%
h1b_data['WORKSITE_STATE'].head(6)
# Out:
# 0    massachusetts
# 1         new york
# 2            texas
# 3            texas
# 4    massachusetts
# 5           oregon
# Name: WORKSITE_STATE, dtype: object

# %% [markdown]
# The states have successfully being replaced with their full names. Now I can merge cities and states into one column:

# %%
# merge city and state
def site_merge(city, state):
    city = str(city)
    state = str(state) 
    if city == "" and state == "":
        return ""
    elif city == "":
        return f"{state.upper()}"
    elif state == "":
        return f"{city}"
    else:
        return f"{city},  {state.upper()}"

# %% [markdown]
# The really tricky part here is that I do not want to merge records which have NaN values in either column or else I will have records which will look like ",NEW YORK" or "NEW YORK," after applying the merging function. This means I want to apply the function only to non-null records, which I have taken care of in the function above.

# %%
# make new col by merge
h1b_data['WORKSITE'] = h1b_data[['WORKSITE_CITY','WORKSITE_STATE']].apply(
   lambda x: site_merge(*x), axis = 1
)

# %% [markdown]
# Now that the city and states have been merged into one new column named 'WORKSITE', let's check the merge was successful:

# %%
h1b_data['WORKSITE'].head(6)
# Out:
# 0    EASTHAMPTON,  MASSACHUSETTS
# 1            NEW YORK,  NEW YORK
# 2                HOUSTON,  TEXAS
# 3          THE WOODLANDS,  TEXAS
# 4         BOSTON,  MASSACHUSETTS
# 5             BEAVERTON,  OREGON
# Name: WORKSITE, dtype: object

# %% [markdown]
# Looks great - although I am sure it is not perfect. I could spend a week just fixing these types of errors.  I know I have now at least taken care of some big and prevalent ones.

# %% [markdown]
# After merging the city and state, the city column can be dropped:

# %%
# drop col
h1b_data = h1b_data.drop("WORKSITE_CITY", axis = 1)

# %% [markdown]
# Here's a look at some of the worksites after merging. Again, I could find many more errors and incorporate regular expressions to do so, but for now this is fine.

# %%
# unique worksties:
h1b_data['WORKSITE'].unique().tolist()
# Out:
# ['EASTHAMPTON,  MASSACHUSETTS',
#  'NEW YORK,  NEW YORK',
#  'HOUSTON,  TEXAS',
#  'THE WOODLANDS,  TEXAS',
#  'BOSTON,  MASSACHUSETTS',
#  'BEAVERTON,  OREGON',
#  'SALISBURY,  MARYLAND',
#  'MERRIMACK,  NEW HAMPSHIRE',
#  'FORT MYERS,  FLORIDA',
#  'SAN DIEGO,  CALIFORNIA',
#  'NEWARK,  CALIFORNIA',
#  'VISTA,  CALIFORNIA',
#  'FREDERICK,  MARYLAND',
#  'SEATTLE,  WASHINGTON',
#  'BROOKLYN,  NEW YORK',
#  'SANTA CLARA,  CALIFORNIA',
#  'NEW ALBANY,  OHIO',
#  'WESTON,  FLORIDA',
#  'HONOLULU,  HAWAII',
#  'HARTLAND,  WISCONSIN',
#  'SAN ANTONIO,  TEXAS',
#  'MALVERN,  PENNSYLVANIA',
#  'WATERTOWN,  NEW YORK',
#  'ANDREWS,  TEXAS',
#  'COLLIERVILLE,  TENNESSEE',
#  'WASHINGTON,  DISTRICT OF COLUMBIA',
#  'NEWPORT BEACH,  CALIFORNIA',
#  'RICHMOND,  VIRGINIA',
#  'MIAMI,  FLORIDA',
#  'AUSTIN,  TEXAS',
#  'SUNNYVALE,  CALIFORNIA',
#  'nan,  NAN',
#  'NORTHWOOD,  OHIO',
#  'RIVERWOODS,  ILLINOIS',
#  'HOPEWELL,  VIRGINIA',
#  'WEST CHESTER,  OHIO',
#  'JACKSONVILLE,  FLORIDA',
#  'CARLSBAD,  CALIFORNIA',
#  'FEDERAL WAY,  WASHINGTON',
#  'DURHAM,  NORTH CAROLINA',
#  'WATERTOWN,  MASSACHUSETTS',
#  'CINCINNATI,  OHIO',
#  'PUEBLO,  COLORADO',
#  'EAST WINDSOR,  CONNECTICUT',
#  'MILFORD,  CONNECTICUT',
#  'SAN RAFAEL,  CALIFORNIA',
#  'JACKSON,  TENNESSEE',
#  'PETERSBURG,  VIRGINIA',
#  'TYLER,  TEXAS',
#  'CAMBRIDGE,  MASSACHUSETTS',
#  'WINSTEAD,  CONNECTICUT',
#  'GREENSBORO,  NORTH CAROLINA',
#  'BERKELEY HEIGHTS,  NEW JERSEY',
#  'CHAMBERSBURG,  PENNSYLVANIA',
#  'WESTMONT,  ILLINOIS',
#  'CARSON CITY,  NEVADA',
#  'MIAMI BEACH,  FLORIDA',
#  'SPRINGFIELD,  MASSACHUSETTS',
#  'CLARKSBURG,  WEST VIRGINIA',
#  'WEST DESMOINES,  IOWA',
#  'COLORADO SPRINGS,  COLORADO',
#  'BEDFORD,  MASSACHUSETTS',
#  'DULUTH,  GEORGIA',
#  'LOS ANGELES,  CALIFORNIA',
#  'MEMPHIS,  TENNESSEE',
#  'NEW ORLEANS,  LOUISIANA',
#  'LEWISPORT,  KENTUCKY',
#  'MARSHALL,  MICHIGAN',
#  'AUBURN HILLS,  MICHIGAN',
#  'PHOENIX,  ARIZONA',
#  'SAN JOSE,  CALIFORNIA',
#  'BOCA RATON,  FLORIDA',
#  'OCALA,  FLORIDA',
#  'GLEN ALLEN,  VIRGINIA',
#  'CARY,  NORTH CAROLINA',
#  'PLANO,  TEXAS',
#  'WAYNE,  PENNSYLVANIA',
#  'POMONA,  CALIFORNIA',
#  'MIDLAND,  MICHIGAN',
#  'ASSUMPTION,  ILLINOIS',
#  'LAKE FOREST,  CALIFORNIA',
#  'MCLEAN,  VIRGINIA',
#  'SHORTER,  ALABAMA',
#  'NASHVILLE,  TENNESSEE',
#  'STERLING,  VIRGINIA',
#  'PLYMOUTH,  MINNESOTA',
#  'ROCKVILLE,  MARYLAND',
#  'SECAUCUS,  NEW JERSEY',
#  'DAYTON,  OHIO',
#  'RIVERWOOD,  ILLINOIS',
#  'CHICAGO,  ILLINOIS',
#  'LA PALMA,  CALIFORNIA',
#  'ATLANTA,  GEORGIA',
#  'HARTFORD,  CONNECTICUT',
#  'CALISTOGA,  CALIFORNIA',
#  'GREENVILLE,  OHIO',
#  'BUFFALO,  NEW YORK',
#  'MOUNTAIN VIEW,  CALIFORNIA',
#  'ALTON,  ILLINOIS',
#  'BREA,  CALIFORNIA',
#  'GRAND RAPIDS,  MICHIGAN',
#  'SOMERSET,  NEW JERSEY',
#  'TORRANCE,  CALIFORNIA',
#  'TALLAHASSEE,  FLORIDA',
#  'APPLETON,  WISCONSIN',
#  'CONCORD,  MASSACHUSETTS',
#  'BLOOMINGTON,  INDIANA',
#  'LOWELL,  MASSACHUSETTS',
#  'RED BANK,  NEW JERSEY',
#  'MAHWAH,  NEW JERSEY',
#  'NORCROSS,  GEORGIA',
#  'BOTHELL,  WASHINGTON',
#  'TAMPA,  FLORIDA',
#  'NEEDHAM,  MASSACHUSETTS',
#  'CHELMSFORD,  MASSACHUSETTS',
#  'IRVING,  TEXAS',
#  'NAPERVILLE,  ILLINOIS',
#  'TROY,  MICHIGAN',
#  'GRANVILLE,  OHIO',
#  'MENLO PARK,  CALIFORNIA',
#  'HARRISON,  ARKANSAS',
#  'LA CROSSE,  WISCONSIN',
#  'CUPERTINO,  CALIFORNIA',
#  'REDWOOD CITY,  CALIFORNIA',
#  'ISLANDIA,  NEW YORK',
#  'JERSEY CITY,  NEW JERSEY',
#  'ALLSTON,  MASSACHUSETTS',
#  'WHITE PLAINS,  NEW YORK',
#  'TEANECK,  NEW JERSEY',
#  'OMAHA,  NEBRASKA',
#  'PARSIPPANY,  NEW JERSEY',
#  'FRAMINGHAM,  MASSACHUSETTS',
#  'WILMINGTON,  DELAWARE',
#  'MOUNTLAKE TERRACE,  WASHINGTON',
#  'FLUSHING,  NEW YORK',
#  'FORT WORTH,  TEXAS',
#  'RESTON,  VIRGINIA',
#  'MANASSAS,  VIRGINIA',
#  'COLUMIBA,  MARYLAND',
#  'SUGAR LAND,  TEXAS',
#  'SOUTH PLAINFIELD,  NEW JERSEY',
#  'ALISO VIEJO,  CALIFORNIA',
#  'CITY OF INDUSTRY,  CALIFORNIA',
#  'BOULDER,  COLORADO',
#  'PAOLI,  PENNSYLVANIA',
#  'BOISE,  IDAHO',
#  'JAMAICA,  NEW YORK',
#  'FARGO,  NORTH DAKOTA',
#  "JOHN'S CREEK,  GEORGIA",
#  'CLARKSVILLE,  TENNESSEE',
#  'LONGVIEW,  TEXAS',
#  'ELK GROVE VILLAGE,  ILLINOIS',
#  'WALLINGFORD,  CONNECTICUT',
#  'MACON,  GEORGIA',
#  'NEW YORK CITY,  NEW YORK',
#  'SAN FRANCISCO,  CALIFORNIA',
#  'CARIBOU,  MAINE',
#  'NOBLESVILLE,  INDIANA',
#  'NEWARK,  DELAWARE',
#  'HAMILTON,  NEW JERSEY',
#  'RANCHO PALOS VERDES,  CALIFORNIA',
#  'IRVINE,  CALIFORNIA',
#  'CARTERET,  NEW JERSEY',
#  'LEWIS CENTER,  OHIO',
#  'PHILADELPHIA,  PENNSYLVANIA',
#  'PLATTSBURGH,  NEW YORK',
#  'BROOMFIELD,  COLORADO',
#  'GREENWOOD VILLAGE,  COLORADO',
#  'MERIDEN,  CONNECTICUT',
#  'DANVILLE,  PENNSYLVANIA',
#  'FRANKFORT,  KENTUCKY',
#  'EDISON,  NEW JERSEY',
#  'HUNTINGTON BEACH,  CALIFORNIA',
#  'CHASKA,  MINNESOTA',
#  'MELVILLE,  NEW YORK',
#  'NANUET,  NEW YORK',
#  'WATERTOWN,  TEXAS',
#  'ALBANY,  NEW YORK',
#  'CARSON,  CALIFORNIA',
#  'GALVESTON,  TEXAS',
#  'EVANSTON,  ILLINOIS',
#  'SAN MATEO,  CALIFORNIA',
#  'HENRICO,  VIRGINIA',
#  'RAYMOND,  OHIO',
#  'NEW HUDSON,  MICHIGAN',
#  'DALLAS,  TEXAS',
#  'AHOSKIE,  NORTH CAROLINA',
#  'DANVERS,  MASSACHUSETTS',
#  'FOOTHILL RANCH,  CALIFORNIA',
#  'CARMEL,  INDIANA',
#  'BRISBANE,  CALIFORNIA',
#  'HARRISONBURG,  VIRGINIA',
#  'ORLANDO,  FLORIDA',
#  'RYE,  NEW YORK',
#  'INDIANAPOLIS,  INDIANA',
#  'SOUTHGATE,  MICHIGAN',
#  'ST. LOUIS,  MISSOURI',
#  'DETROIT,  MICHIGAN',
#  'GAINESVILLE,  FLORIDA',
#  'AMARILLO,  TEXAS',
#  'SWAMPSCOTT,  MASSACHUSETTS',
#  'ANGLETON,  TEXAS',
#  'DANBURY,  CONNECTICUT',
#  'MOON TOWNSHIP,  PENNSYLVANIA',
#  'WACO,  TEXAS',
#  'MINNEAPOLIS,  MINNESOTA',
#  'ST. LOUIS PARK,  MINNESOTA',
#  'COLLEGE STATION,  TEXAS',
#  'PACIFIC,  MISSOURI',
#  'PORTLAND,  OREGON',
#  'ALEXANDRIA,  VIRGINIA',
#  'DAVENPORT,  IOWA',
#  'CHARLOTTE,  NORTH CAROLINA',
#  'BEDFORD,  NEW HAMPSHIRE',
#  'SAN JUAN CAPISTRANO,  CALIFORNIA',
#  'DELAND,  FLORIDA',
#  'BALTIMORE,  MARYLAND',
#  'REYNOLDSBURG,  OHIO',
#  'PRINCETON JUNCTION,  NEW JERSEY',
#  'BELLEVUE,  WASHINGTON',
#  'SANTA CRUZ,  CALIFORNIA',
#  'DENVER,  COLORADO',
#  'FOSTER CITY,  CALIFORNIA',
#  'EASTON,  PENNSYLVANIA',
#  'NORWALK,  CONNECTICUT',
#  'MILWAUKEE,  WISCONSIN',
#  'ARDEN HILLS,  MINNESOTA',
#  'MIDLOTHIAN,  VIRGINIA',
#  'OAKLAND,  CALIFORNIA',
#  'REDMOND,  WASHINGTON',
#  'KENNER,  LOUISIANA',
#  'ARLINGTON HEIGHTS,  ILLINOIS',
#  'BOLINGBROOK,  ILLINOIS',
#  'LINCOLNSHIRE,  ILLINOIS',
#  'DAVIE,  FLORIDA',
#  'EL SEGUNDO,  CALIFORNIA',
#  'WILLIAMSBURG,  VIRGINIA',
#  'ROLLING MEADOWS,  ILLINOIS',
#  'BRAINTREE,  MASSACHUSETTS',
#  'TORRINGTON,  CONNECTICUT',
#  'PASADENA,  TEXAS',
#  'NORTH BRUNSWICK,  NEW JERSEY',
#  'ST CHARLES,  MISSOURI',
#  'ARLINGTON,  VIRGINIA',
#  'ST LOUIS,  MISSOURI',
#  'WOLCOTT,  CONNECTICUT',
#  'NAPA,  CALIFORNIA',
#  'BURLINGTON,  MASSACHUSETTS',
#  'ANNANDALE,  VIRGINIA',
#  'CHEYENNE,  WYOMING',
#  'BIRMINGHAM,  ALABAMA',
#  'BRYAN,  TEXAS',
#  'TECUMSEH,  MICHIGAN',
#  'BAD AXE,  MICHIGAN',
#  'HERNDON,  VIRGINIA',
#  'BEAR,  DELAWARE',
#  'WESTMINSTER,  COLORADO',
#  'OLDSMAR,  FLORIDA',
#  'PROVIDENCE,  RHODE ISLAND',
#  'PRINCETON,  NEW JERSEY',
#  'KANSAS CITY,  MISSOURI',
#  'ARMONK,  NEW YORK',
#  'BAY POINT,  CALIFORNIA',
#  'COLUMBUS,  GEORGIA',
#  'FREMONT,  CALIFORNIA',
#  'GONZALES,  TEXAS',
#  'LOUISVILLE,  KENTUCKY',
#  'NEW YORK,  CALIFORNIA',
#  'PRATTVILLE,  ALABAMA',
#  'TUSCALOOSA,  ALABAMA',
#  'UPPER SADDLE RIVER,  NEW JERSEY',
#  'COSTA MESA,  CALIFORNIA',
#  'FONTANA,  CALIFORNIA',
#  'HAUPPAUGE,  NEW YORK',
#  'NEWTOWN,  PENNSYLVANIA',
#  'MOUNT CLEMENS,  MICHIGAN',
#  'ST. THOMAS,  VI',
#  'EAGAN,  MINNESOTA',
#  'REDWOOD SHORES,  CALIFORNIA',
#  'SACRAMENTO,  CALIFORNIA',
#  'JAMAICA PLAIN,  MASSACHUSETTS',
#  'LUMBERTON,  NORTH CAROLINA',
#  'DEVON,  PENNSYLVANIA',
#  'WENTZVILLE,  MISSOURI',
#  'MONTEREY PARK,  CALIFORNIA',
#  'S FORT WORTH,  TEXAS',
#  'NAMPA,  IDAHO',
#  'PLAINVILLE,  CONNECTICUT',
#  'ST THOMAS,  VI',
#  'BENSENVILLE,  ILLINOIS',
#  'ROSEMONT,  ILLINOIS',
#  'DES PLAINES,  ILLINOIS',
#  'FULLERTON,  CALIFORNIA',
#  'ALPHARETTA,  GEORGIA',
#  'MORGANTOWN,  WEST VIRGINIA',
#  'CONROE,  TEXAS',
#  'DECATUR,  ILLINOIS',
#  'EVERETT,  WASHINGTON',
#  'KINGWOOD,  TEXAS',
#  'RIVERSIDE,  CALIFORNIA',
#  'STURGEON BAY,  WISCONSIN',
#  'LEHI,  UTAH',
#  'DOVER,  NEW HAMPSHIRE',
#  'SAINT JOSEPH,  ILLINOIS',
#  'COLUMBIA,  MARYLAND',
#  'ATHENS,  TENNESSEE',
#  'MONTGOMERY,  ALABAMA',
#  'HICKORY,  NORTH CAROLINA',
#  'SOUTH BARRINGTON,  ILLINOIS',
#  'LAFAYETTE,  INDIANA',
#  'LOS ALTOS,  CALIFORNIA',
#  'CALABASAS,  CALIFORNIA',
#  'ARLINGTON HEIGH,  ILLINOIS',
#  'JOHNSON CITY,  TENNESSEE',
#  'ST. CROIX,  VI',
#  'MILFORD,  OHIO',
#  'ZION,  ILLINOIS',
#  'LANSING,  MICHIGAN',
#  'PICATAWAY,  NEW JERSEY',
#  'LONG ISLAND CITY,  NEW YORK',
#  'NORTH ANDOVER,  MASSACHUSETTS',
#  'WHIPPANY,  NEW JERSEY',
#  'GERMANTWON,  MARYLAND',
#  'PERTH AMBOY,  NEW JERSEY',
#  'NORTHBROOK,  ILLINOIS',
#  'KOKOMO,  INDIANA',
#  'CAMP HILL,  PENNSYLVANIA',
#  'EAST RUTHERFORD,  NEW JERSEY',
#  'SYRACUSE,  NEW YORK',
#  'FRANKLIN LAKES,  NEW JERSEY',
#  'CULVER CITY,  CALIFORNIA',
#  'UPPER ARLINGTON,  OHIO',
#  'MT. VERNON,  OHIO',
#  'UNION CITY,  CALIFORNIA',
#  'LYNCHBURG,  VIRGINIA',
#  'CHEVY CHASE,  MARYLAND',
#  'GROTON,  CONNECTICUT',
#  'SUNYVALE,  CALIFORNIA',
#  'SHREWSBURY,  MASSACHUSETTS',
#  'FOSTER,  CALIFORNIA',
#  'BRANCHBURG,  NEW JERSEY',
#  'CHATTANOOGA,  TENNESSEE',
#  'SOUTH PORTLAND,  MAINE',
#  'SKOKIE,  ILLINOIS',
#  'SKOWHEGAN,  MAINE',
#  'CANTON,  MASSACHUSETTS',
#  'LITTLE ROCK,  ARKANSAS',
#  'ST. PETERSBURG,  FLORIDA',
#  'HALLANDALE,  FLORIDA',
#  'ROYAL OAKS,  MICHIGAN',
#  'GAITHERSBURG,  MARYLAND',
#  'NEW BRIGHTON,  MINNESOTA',
#  'PITTSBURGH,  PENNSYLVANIA',
#  'BELTSVILLE,  MARYLAND',
#  'GLENDALE,  CALIFORNIA',
#  'METRO CHICAGO,  ILLINOIS',
#  'PASADENA,  CALIFORNIA',
#  'BELLAIRE,  TEXAS',
#  'EDGEWOOD,  NEW YORK',
#  'HOLLYWOOD,  FLORIDA',
#  'MURRAY,  UTAH',
#  'LIVINGSTON,  NEW JERSEY',
#  'WOBURN,  MASSACHUSETTS',
#  'ISELIN,  NEW JERSEY',
#  'MARLBOROUGH,  MASSACHUSETTS',
#  'REDBANK,  NEW JERSEY',
#  'OVERLAND PARK,  KANSAS',
#  'PORT WASHINGTON,  NEW YORK',
#  'COLUMBUS,  OHIO',
#  'RICHARDSON,  TEXAS',
#  'HUMBLE,  TEXAS',
#  'MORRISTOWN,  NEW JERSEY',
#  'ST. PAUL,  MINNESOTA',
#  'FOLSOM,  CALIFORNIA',
#  'HUNTINGTON,  MASSACHUSETTS',
#  'DAVENPORT,  FLORIDA',
#  'EDINA,  MINNESOTA',
#  'PONTIAC,  MICHIGAN',
#  'KIRKLAND,  WASHINGTON',
#  'GRAPEVINE,  TEXAS',
#  'ISSAQUAH,  WASHINGTON',
#  'SURRY,  VIRGINIA',
#  'GREENBELT,  MARYLAND',
#  'MONTVALE,  NEW JERSEY',
#  'HEBRON,  KENTUCKY',
#  'ADDISON,  TEXAS',
#  'ARTESIA,  CALIFORNIA',
#  'ANKENY,  IOWA',
#  'CHAPARRAL,  NEW MEXICO',
#  'MUNROE FALLS,  OHIO',
#  'ORANGE,  CALIFORNIA',
#  'WORCESTER,  MASSACHUSETTS',
#  'WARREN,  NEW JERSEY',
#  'WARRENVILLE,  ILLINOIS',
#  'ODGENSBURG,  NEW YORK',
#  'WEEHAWKEN,  NEW JERSEY',
#  'MIDDLESEX,  MASSACHUSETTS',
#  'PORTSMOUTH,  NEW HAMPSHIRE',
#  'KING OF PRUSSIA,  PENNSYLVANIA',
#  'TRINITY,  TEXAS',
#  'FRANKLIN,  TENNESSEE',
#  'INDIANAPOLIS,  ILLINOIS',
#  'CYPRESS,  CALIFORNIA',
#  'SCOTTSDALE,  ARIZONA',
#  'SIOUX FALLS,  SOUTH DAKOTA',
#  'LAKE MARY,  FLORIDA',
#  'ORANGE COUNTY,  CALIFORNIA',
#  'PLEASANTON,  CALIFORNIA',
#  'HOPKINS,  MINNESOTA',
#  'ALLENTOWN,  PENNSYLVANIA',
#  'NEW ROCHELLE,  NEW YORK',
#  'JERICHO,  NEW YORK',
#  'LIVERMORE,  CALIFORNIA',
#  'DENHAM SPRINGS,  LOUISIANA',
#  'STONE MTN,  GEORGIA',
#  'ALBUQUERQUE,  NEW MEXICO',
#  'METAIRIE,  LOUISIANA',
#  'AKRON,  NEW YORK',
#  'GARLAND,  TEXAS',
#  'MIDDLETOWN,  NEW JERSEY',
#  'WASHINGTON DC,  DISTRICT OF COLUMBIA',
#  'WILLOUGHBY,  OHIO',
#  'SUNRISE,  FLORIDA',
#  'COLLIERVILLE,  PENNSYLVANIA',
#  'ROCHESTER,  NEW YORK',
#  'OAK CREEK,  WISCONSIN',
#  'PLAINVIEW,  NEW YORK',
#  'BLOOMFIELD,  CONNECTICUT',
#  'WEST LAFAYETTE,  INDIANA',
#  'BAYTOWN,  TEXAS',
#  'HORSHAM,  PENNSYLVANIA',
#  'SAN BRUNO,  CALIFORNIA',
#  'WEST KINGSTON,  RHODE ISLAND',
#  'BUCKEYE,  ARIZONA',
#  'EWING,  NEW JERSEY',
#  'MADISON,  WISCONSIN',
#  'FLORHAM PARK,  NEW JERSEY',
#  'STAMFORD,  CONNECTICUT',
#  'DUBLIN,  OHIO',
#  'RANCHO CORDOVA,  CALIFORNIA',
#  'SANTA CLARITA,  CALIFORNIA',
#  'DUNEDIN,  FLORIDA',
#  'SANFORD,  FLORIDA',
#  'MORROW,  GEORGIA',
#  'MOONACHIE,  NEW JERSEY',
#  'MANCHESTER,  NEW HAMPSHIRE',
#  'HOLLYWOOD,  CALIFORNIA',
#  'PISCATAWAY,  NEW JERSEY',
#  'SHELBY TOWNSHIP,  MICHIGAN',
#  'HAILEY,  IDAHO',
#  'MERIDIAN,  IDAHO',
#  'VIENNA,  VIRGINIA',
#  'STOCKTON,  CALIFORNIA',
#  'ALAMEDA,  CALIFORNIA',
#  'CHANTILLY,  VIRGINIA',
#  'CLOVIS,  CALIFORNIA',
#  'SILVER SPRING,  MARYLAND',
#  'WILTON MANORS,  FLORIDA',
#  'TIMONIUM,  MARYLAND',
#  'STANFORD,  CALIFORNIA',
#  'RUTHERFORD,  NEW JERSEY',
#  'HARRISBURG,  PENNSYLVANIA',
#  'COMMACK,  NEW YORK',
#  'CRYSTAL RIVER,  FLORIDA',
#  'SMYRNA,  TENNESSEE',
#  'BERNARDSVILLE,  NEW JERSEY',
#  'FARMINGDALE,  NEW YORK',
#  'GREAT BARRINGTON,  MASSACHUSETTS',
#  'MIDDLETOWN,  OHIO',
#  'PRESIDIO,  TEXAS',
#  'GREENWICH,  CONNECTICUT',
#  'LAS VEGAS,  NEVADA',
#  'MILLS,  WYOMING',
#  'SPRINGFIELD,  NEW JERSEY',
#  'EL DORADO HILLS,  CALIFORNIA',
#  'NORMAL,  ILLINOIS',
#  'ROLLING FORK,  MISSISSIPPI',
#  'GAHANNA,  OHIO',
#  'SANTA MONICA,  CALIFORNIA',
#  'COLUMBIA,  SOUTH CAROLINA',
#  'NEWARK,  NEW JERSEY',
#  'SOUTHFIELD,  MICHIGAN',
#  'LEXINGTON,  MASSACHUSETTS',
#  'PENNINGTON,  NEW JERSEY',
#  'PEORIA,  ARIZONA',
#  'SANTA ANA,  CALIFORNIA',
#  'EDEN PRAIRIE,  MINNESOTA',
#  'MASON,  MICHIGAN',
#  'CORTE MADERA,  CALIFORNIA',
#  'OXFORD,  MISSISSIPPI',
#  'PALO ALTO,  CALIFORNIA',
#  'PALATINE,  ILLINOIS',
#  'NOVI,  MICHIGAN',
#  'PLAINSBORO,  NEW JERSEY',
#  'CHINO,  CALIFORNIA',
#  'GALENA PARK,  TEXAS',
#  'ELLICOTT CITY,  MARYLAND',
#  'LADYSMITH,  WISCONSIN',
#  'NEWTON,  MASSACHUSETTS',
#  'GEORGETOWN,  SOUTH CAROLINA',
#  'BERKELEY,  CALIFORNIA',
#  'OKLAHOMA CITY,  OKLAHOMA',
#  'DRAPER,  UTAH',
#  'WAUKESHA,  WISCONSIN',
#  'ATHENS,  GEORGIA',
#  'BEVERLY HILLS,  CALIFORNIA',
#  'JONESBORO,  GEORGIA',
#  'RENTON,  WASHINGTON',
#  'BROWNSVILLE,  TEXAS',
#  'HARWICK,  PENNSYLVANIA',
#  'HENDERSON,  KENTUCKY',
#  'EAU CLAIRE,  WISCONSIN',
#  'ARLINGTON HTS,  ILLINOIS',
#  'GREAT NECK,  NEW YORK',
#  'ELMHURST,  NEW YORK',
#  'LANHAM,  MARYLAND',
#  'RICHFIELD,  MINNESOTA',
#  'ARLINGTON,  TEXAS',
#  'CLEARWATER,  FLORIDA',
#  'SIDNEY,  NEBRASKA',
#  'GARDENA,  CALIFORNIA',
#  'EAST MOLINE,  ILLINOIS',
#  'TARRYTOWN,  NEW YORK',
#  'HOBOKEN,  NEW JERSEY',
#  'WAUWATOSA,  WISCONSIN',
#  'CHANDLER,  ARIZONA',
#  'PALM BEACH GARDENS,  FLORIDA',
#  'ST. JOSEPH,  MICHIGAN',
#  'EL PASO,  TEXAS',
#  'HAMDEN,  CONNECTICUT',
#  'CHARLESTON,  SOUTH CAROLINA',
#  'TOWN AND COUNTRY,  MISSOURI',
#  'CLEVELAND,  OHIO',
#  'LAVERGNE,  TENNESSEE',
#  'PASCO,  WASHINGTON',
#  'LAKE WORTH,  FLORIDA',
#  'SAN RAMON,  CALIFORNIA',
#  'BUFORD,  GEORGIA',
#  'ANDOVER,  MASSACHUSETTS',
#  'CENTENNIAL,  COLORADO',
#  'TUSTIN,  CALIFORNIA',
#  'FALL RIVER,  MASSACHUSETTS',
#  'HARBOR CITY,  CALIFORNIA',
#  'MONROVIA,  CALIFORNIA',
#  'TULSA,  OKLAHOMA',
#  'FALLS CHURCH,  VIRGINIA',
#  'LAGUNA BEACH,  CALIFORNIA',
#  'ENGLEWOOD,  COLORADO',
#  'WEBSTER,  TEXAS',
#  'CHESTER,  PENNSYLVANIA',
#  'DULLES,  VIRGINIA',
#  'OPELOUSAS,  LOUISIANA',
#  'PAINTED POST,  NEW YORK',
#  'RAMSEY,  NEW JERSEY',
#  'EUREKA,  CALIFORNIA',
#  'SCHWARTZ CREEK,  MICHIGAN',
#  'LAKEWOOD,  COLORADO',
#  'CHATHAM,  VIRGINIA',
#  'PINGREE GROVE,  ILLINOIS',
#  'DORAL,  FLORIDA',
#  'ALACHUA,  FLORIDA',
#  'BLACKSBURG,  VIRGINIA',
#  'ONE ELLIOT WAY,  NEW HAMPSHIRE',
#  'HYATTSVILLE,  MARYLAND',
#  'ROCHESTER,  MINNESOTA',
#  'SALT LAKE CITY,  UTAH',
#  'NORTH GRAFTON,  MASSACHUSETTS',
#  'PORT CHARLOTTE,  FLORIDA',
#  'ARLINGTON,  TENNESSEE',
#  'BRADENTON,  FLORIDA',
#  'EATONTOWN,  NEW JERSEY',
#  'BEDFORD,  VIRGINIA',
#  'PLYMOUTH,  MICHIGAN',
#  'COTTONDALE,  ALABAMA',
#  'GLEN BURNIE,  MARYLAND',
#  'STRAWBERRY PLAINS,  TENNESSEE',
#  'TEMPLE,  TEXAS',
#  'FAIRFIELD,  IOWA',
#  'ALBURQUERQUE,  NEW MEXICO',
#  'LOVEJOY,  GEORGIA',
#  'SAN RAMAN,  CALIFORNIA',
#  'SHORT HILLS,  NEW JERSEY',
#  'CROSSVILLE,  TENNESSEE',
#  'SHOREVIEW,  MINNESOTA',
#  'SAN ANTONIO,  CALIFORNIA',
#  'OAK BROOK,  ILLINOIS',
#  'GLASTONBURY,  CONNECTICUT',
#  'PEARLAND,  TEXAS',
#  'FRANKLIN PARK,  ILLINOIS',
#  'ATHERTON,  CALIFORNIA',
#  'WEST DES MOINES,  IOWA',
#  'BETHESDA,  MARYLAND',
#  'BOONE,  NORTH CAROLINA',
#  'SEBRING,  FLORIDA',
#  'WESTBOROUGH,  MASSACHUSETTS',
#  'CAMPBELL,  CALIFORNIA',
#  'LAUREL,  MARYLAND',
#  'BATTLE CREEK,  MICHIGAN',
#  'SIMI VALLEY,  CALIFORNIA',
#  'BARRINGTON,  ILLINOIS',
#  'CHESAPEAKE CITY,  MARYLAND',
#  'WILTON,  CONNECTICUT',
#  'RALEIGH,  NORTH CAROLINA',
#  'CARMEL,  NEW YORK',
#  'IRWINDALE,  CALIFORNIA',
#  'LOGAN,  UTAH',
#  'HAMMONDSPORT,  NEW YORK',
#  'FRESNO,  CALIFORNIA',
#  'ITASCA,  ILLINOIS',
#  'SUGARLAND,  TEXAS',
#  'BRENTWOOD,  TENNESSEE',
#  'TUCSON,  ARIZONA',
#  'EAST ROCHESTER,  NEW YORK',
#  'MINNETONKA,  MINNESOTA',
#  'COTTAGE GROVE,  WISCONSIN',
#  'GREELEY,  COLORADO',
#  'LAKEVILLE,  MINNESOTA',
#  'NASHUA,  NEW HAMPSHIRE',
#  'SUMMIT,  NEW JERSEY',
#  'GATHERSBURG,  MARYLAND',
#  'BROCKTON,  MASSACHUSETTS',
#  'QUINCY,  MASSACHUSETTS',
#  'COVINGTON,  GEORGIA',
#  'HAZLET,  NEW JERSEY',
#  'WOODCLIFF LAKE,  NEW JERSEY',
#  'WALNUT CREEK,  CALIFORNIA',
#  'LAMAR,  COLORADO',
#  'GAINESVILLE,  GEORGIA',
#  'PALM COAST,  FLORIDA',
#  'DEL MAR,  CALIFORNIA',
#  'HUTTO,  TEXAS',
#  'NEW CASTLE,  DELAWARE',
#  'IPSWICH,  MASSACHUSETTS',
#  'FORT COLLINS,  COLORADO',
#  'TINTON FALLS,  NEW JERSEY',
#  'WINSTON SALEM,  NORTH CAROLINA',
#  'ANNAPOLIS,  MARYLAND',
#  'URBANCREST,  OHIO',
#  'LAKELAND,  FLORIDA',
#  'EAST HANOVER,  NEW JERSEY',
#  'RICHMOND,  KENTUCKY',
#  'SIGNAL HILL,  CALIFORNIA',
#  'MESA,  ARIZONA',
#  'ALLEN,  TEXAS',
#  'MIDDLEBURG,  VIRGINIA',
#  'WESTBURY,  NEW YORK',
#  'FORESTVILLE,  MARYLAND',
#  'SANTA FE,  NEW MEXICO',
#  'VALLEY LEE,  MARYLAND',
#  'LAGRANGE,  KENTUCKY',
#  'NORMAN,  OKLAHOMA',
#  'LAFAYETTE,  GEORGIA',
#  'WILLIAMSPORT,  MARYLAND',
#  'WASILLA,  ALASKA',
#  'ROUND ROCK,  TEXAS',
#  'WESTLAKE VILLAGE,  CALIFORNIA',
#  'WINDSOR,  CONNECTICUT',
#  'ANN ARBOR,  MICHIGAN',
#  'BETHPAGE,  NEW YORK',
#  'STILLWATER,  OKLAHOMA',
#  'MENOMONEE FALLS,  WISCONSIN',
#  'ELMHURST,  ILLINOIS',
#  'WALNUT,  CALIFORNIA',
#  'OLYMPIA,  WASHINGTON',
#  'ORANGEBURG,  NEW YORK',
#  'WEST NEWBURY,  VERMONT',
#  'NOVATO,  CALIFORNIA',
#  'MILWAUKIE,  OREGON',
#  'YPSILANTI,  MICHIGAN',
#  'HOFFMAN ESTATES,  ILLINOIS',
#  'LAVONIA,  GEORGIA',
#  'KENT,  WASHINGTON',
#  'PARKER,  COLORADO',
#  'CHESTERTOWN,  MARYLAND',
#  'MORGANVILLE,  NEW JERSEY',
#  'CLINTON,  MASSACHUSETTS',
#  'BRIDGEWATER,  NEW JERSEY',
#  'MCALLEN,  TEXAS',
#  'RESEARCH TRIANGLE PARK,  NORTH CAROLINA',
#  'WEST HAVEN,  CONNECTICUT',
#  'PERRYTON,  TEXAS',
#  'LONG PRAIRIE,  MINNESOTA',
#  'UNIVERSAL CITY,  CALIFORNIA',
#  'COLUMBUS,  INDIANA',
#  'JOHNSON CITY,  NEW YORK',
#  'MAPLE GROVE,  MINNESOTA',
#  'GRANDVIEW,  WASHINGTON',
#  'YORK,  PENNSYLVANIA',
#  'SPENCER,  WEST VIRGINIA',
#  'BERKLEY,  MICHIGAN',
#  'WALTHAM,  MASSACHUSETTS',
#  'HILLSBORO,  OREGON',
#  'KATY,  TEXAS',
#  'MADISON HEIGHTS,  MICHIGAN',
#  'MOUNT PROSPECT,  ILLINOIS',
#  'OAK PARK,  MICHIGAN',
#  'BERGENFIELD,  NEW JERSEY',
#  'WEST CHESTER,  PENNSYLVANIA',
#  'SCHAUMBURG,  ILLINOIS',
#  'CELEBRATION,  FLORIDA',
#  'THORNWOOD,  NEW YORK',
#  'WHEATON,  MARYLAND',
#  'HARLINGEN,  TEXAS',
#  'HOPKINTON,  MASSACHUSETTS',
#  'BROOKFIELD,  WISCONSIN',
#  'LOVELAND,  OHIO',
#  'SMITHFIELD,  RHODE ISLAND',
#  'NEW BRUNSWICK,  NEW JERSEY',
#  'SOUTHBOROUGH,  MASSACHUSETTS',
#  'COMMERCE,  CALIFORNIA',
#  'NEW HAVEN,  CONNECTICUT',
#  'PLYMOUTH MEETING,  PENNSYLVANIA',
#  'CAMBRIDGE,  OHIO',
#  'PORT ARTHUR,  TEXAS',
#  'ROWLAND HEIGHTS,  CALIFORNIA',
#  'NORTH OLMSTED,  OHIO',
#  'GLENWOOD,  MINNESOTA',
#  'SPENCER,  INDIANA',
#  'MUNHALL,  PENNSYLVANIA',
#  'HUNT VALLEY,  MARYLAND',
#  'VISALIA,  CALIFORNIA',
#  'SHELTON,  CONNECTICUT',
#  'PORTLAND,  MAINE',
#  'WEST SACRAMENTO,  CALIFORNIA',
#  'JACSKONVILLE,  FLORIDA',
#  'HUDSON,  MASSACHUSETTS',
#  'THOUSAND OAKS,  CALIFORNIA',
#  'WATERLOO,  IOWA',
#  'ALTANTA,  GEORGIA',
#  'MANHATTAN BEACH,  CALIFORNIA',
#  'BURR RIDGE,  ILLINOIS',
#  'CORNING,  NEW YORK',
#  'DEER PARK,  NEW YORK',
#  'UNIVESAL CITY,  CALIFORNIA',
#  'CORONA,  CALIFORNIA',
#  'FAIRFAX,  VIRGINIA',
#  'BRANDON,  FLORIDA',
#  'MILPITAS,  CALIFORNIA',
#  'TEMPE,  ARIZONA',
#  'EVANSVILLE,  INDIANA',
#  'COLLEGEVILLE,  PENNSYLVANIA',
#  'GRASS VALLEY,  CALIFORNIA',
#  'JUNO BEACH,  FLORIDA',
#  'DORCHESTER,  MASSACHUSETTS',
#  'SNOQUALMIE,  WASHINGTON',
#  'FORT LEE,  NEW JERSEY',
#  'NILES,  FLORIDA',
#  'LEXINGTON,  NORTH CAROLINA',
#  'LIBERTY,  TEXAS',
#  'FAYETTEVILLE,  GEORGIA',
#  'BATON ROUGE,  LOUISIANA',
#  'NORTH HAVEN,  CONNECTICUT',
#  'HERCULES,  CALIFORNIA',
#  'WELLESLEY,  MASSACHUSETTS',
#  'WEBSTER,  NEW YORK',
#  'ALTAMONTE SPRINGS,  FLORIDA',
#  'NEW HOPE,  PENNSYLVANIA',
#  'DIAMOND BAR,  CALIFORNIA',
#  'CAMAS,  WASHINGTON',
#  'CARLSTADT,  NEW JERSEY',
#  'DUBLIN,  CALIFORNIA',
#  'MARYVILLE,  TENNESSEE',
#  'CANTON,  MICHIGAN',
#  'PEORIA,  ILLINOIS',
#  'ST. AUGUSTINE,  FLORIDA',
#  'SPRINGFIELD,  MISSOURI',
#  'WOODBURY,  NEW YORK',
#  'MORRISVILLE,  NORTH CAROLINA',
#  'MIAMI LAKES,  FLORIDA',
#  'FORT LAUDERDALE,  FLORIDA',
#  'COPPELL,  TEXAS',
#  'WARWICK,  RHODE ISLAND',
#  'PEARL RIVER,  NEW YORK',
#  'ANNANDALE-ON-HUDSON,  NEW YORK',
#  'WEST NYACK,  NEW YORK',
#  'WESTFORD,  MASSACHUSETTS',
#  'MORRIS PLAINS,  NEW JERSEY',
#  'OPA LOCKA,  FLORIDA',
#  'MIRAMAR,  FLORIDA',
#  'NORTH QUINCY,  MASSACHUSETTS',
#  'WESTWOOD,  MASSACHUSETTS',
#  'LEXINGTON,  KENTUCKY',
#  'COLUMUBUS,  OHIO',
#  'PHOENIXVILLE,  PENNSYLVANIA',
#  'INVER GROVE HEIGHTS,  MINNESOTA',
#  'VOORHEES,  NEW JERSEY',
#  'MARTINSBURG,  WEST VIRGINIA',
#  'FOWLERVILLE,  MICHIGAN',
#  'RAINELLE,  WEST VIRGINIA',
#  'WILMINGTON,  OHIO',
#  'HAGERSTOWN,  INDIANA',
#  'EMERYVILLE,  CALIFORNIA',
#  'LEWISBERRY,  PENNSYLVANIA',
#  'HOLLAND,  MICHIGAN',
#  'SOUTH SAN FRANCISCO,  CALIFORNIA',
#  'READING,  PENNSYLVANIA',
#  'AGOURA HILLS,  CALIFORNIA',
#  'WINONA,  MINNESOTA',
#  'LEBANON,  NEW HAMPSHIRE',
#  'OAKTON,  VIRGINIA',
#  'SPRINGFIELD,  VIRGINIA',
#  'OLNEY,  MARYLAND',
#  'TUCKER,  GEORGIA',
#  'LIBERTYVILLE,  ILLINOIS',
#  'BELLVUE,  COLORADO',
#  'TACOMA,  WASHINGTON',
#  'BURBANK,  CALIFORNIA',
#  'GREENVILLE,  TEXAS',
#  'BLAINE,  MINNESOTA',
#  'MIDLAND,  TEXAS',
#  'CHARLESTON,  WEST VIRGINIA',
#  'COMPTON,  CALIFORNIA',
#  'WASHINGTON,  MARYLAND',
#  'MIDDLETOWN,  PENNSYLVANIA',
#  'BARTLETT,  ILLINOIS',
#  'EAST FISHKILL,  NEW YORK',
#  'DEARBORN,  MICHIGAN',
#  'LITITZ,  PENNSYLVANIA',
#  'WEST NORRITON,  PENNSYLVANIA',
#  'KEW GARDENS,  NEW YORK',
#  'MURRAYVILLE,  GEORGIA',
#  'FARMINGTON,  NEW MEXICO',
#  'WARREN,  MICHIGAN',
#  'BRONX,  NEW YORK',
#  'WATERBURY,  CONNECTICUT',
#  'LINCOLN,  NEBRASKA',
#  'LEONIA,  NEW JERSEY',
#  'BYRON CENTER,  MICHIGAN',
#  'HAGATNA,  GU',
#  'FOOTHILLS RANCH,  CALIFORNIA',
#  'BLOUNTSTOWN,  FLORIDA',
#  'HUDSON,  OHIO',
#  'MEDIA,  PENNSYLVANIA',
#  'CREVE COEUR,  MISSOURI',
#  "ST. MARY'S CITY,  MARYLAND",
#  'PUTNAM,  CONNECTICUT',
#  'MARSHALL,  MINNESOTA',
#  'BALA CYNWYD,  PENNSYLVANIA',
#  'AMHERST,  MASSACHUSETTS',
#  'GRAND PRAIRIE,  TEXAS',
#  'MATEWAN,  WEST VIRGINIA',
#  'NEW KENSINGTON,  PENNSYLVANIA',
#  'FORT SMITH,  ARKANSAS',
#  'BINGHAMTON,  NEW YORK',
#  'TOMBALL,  TEXAS',
#  'SHADY GROVE,  PENNSYLVANIA',
#  'CINCINNATTI,  OHIO',
#  'TEMPLE TERRACE,  FLORIDA',
#  'NORTH TONAWANDA,  NEW YORK',
#  'ELKHART,  INDIANA',
#  'GOLDEN,  COLORADO',
#  'OSSINING,  NEW YORK',
#  'COLLEGE POINT,  NEW YORK',
#  'GEORGETOWN,  KENTUCKY',
#  'MIAMISBURG,  OHIO',
#  'WORTHINGTON,  OHIO',
#  'WALPOLE,  MASSACHUSETTS',
#  'CARMICHAEL,  CALIFORNIA',
#  'ST. CHARLES,  MISSOURI',
#  'RICHWOOD,  LOUISIANA',
#  'BEND,  OREGON',
#  'MISSION,  TEXAS',
#  'HANOVER,  NEW HAMPSHIRE',
#  'STAFFORD,  TEXAS',
#  'SEAFORD,  NEW YORK',
#  'AKRON,  OHIO',
#  'GOODYEAR,  ARIZONA',
#  'LINDON,  UTAH',
#  'DOWNERS GROVE,  ILLINOIS',
#  'SANTA ROSA,  CALIFORNIA',
#  'FORT WASHINGTON,  PENNSYLVANIA',
#  'MONTEREY,  CALIFORNIA',
#  'LYNNWOOD,  WASHINGTON',
#  'METTAWA,  ILLINOIS',
#  'EVANSVILLE,  WYOMING',
#  'GETZVILLE,  NEW YORK',
#  'BLOOMFIELD HILLS,  MICHIGAN',
#  'POUGHKEEPSIE,  NEW YORK',
#  'CONCORD,  CALIFORNIA',
#  'HERMITAGE,  TENNESSEE',
#  'REDLANDS,  CALIFORNIA',
#  'NEWPORT,  RHODE ISLAND',
#  'MCCLEAN,  VIRGINIA',
#  'JEFFERSON CITY,  MISSOURI',
#  'SUSSEX,  WISCONSIN',
#  'LEAGUE CITY,  TEXAS',
#  'BAKERSFIELD,  CALIFORNIA',
#  'LIVONIA,  MICHIGAN',
#  'WYOMING,  WYOMING',
#  'MCKINLEYVILLE,  CALIFORNIA',
#  'WAVERLY,  IOWA',
#  'DEDHAM,  MASSACHUSETTS',
#  'GLEN ELLYN,  ILLINOIS',
#  'ROANOKE,  VIRGINIA',
#  'EL MONTE,  CALIFORNIA',
#  'nan,  DISTRICT OF COLUMBIA',
#  'GUAM,  GU',
#  'WALKERSVILLE,  MARYLAND',
#  'GROVE CITY,  PENNSYLVANIA',
#  'DES MOINES,  IOWA',
#  'YONKERS,  NEW YORK',
#  'LA JOLLA,  CALIFORNIA',
#  'NUTLEY,  NEW JERSEY',
#  'MODESTO,  CALIFORNIA',
#  'KOHLER,  WISCONSIN',
#  'WOODBURY,  MINNESOTA',
#  'FRIDLEY,  MINNESOTA',
#  'ARCADIA,  CALIFORNIA',
#  'RICHMOND,  CALIFORNIA',
#  'BELMONT,  CALIFORNIA',
#  'FLORENCE,  SOUTH CAROLINA',
#  'HALSEY,  OREGON',
#  'GLEN RAVEN,  NORTH CAROLINA',
#  'CEDAR RAPIDS,  IOWA',
#  'EAST BRUNSWICK,  NEW JERSEY',
#  'WINSTON-SALEM,  NORTH CAROLINA',
#  'WAYNE,  NEW JERSEY',
#  'NATICK,  MASSACHUSETTS',
#  'SALISBURY,  NORTH CAROLINA',
#  'VERNON,  CONNECTICUT',
#  'RIO PIEDRAS,  PUERTO RICO',
#  'HENDERSON,  NEVADA',
#  'FARMINGTON,  CONNECTICUT',
#  'HOPKINS,  SOUTH CAROLINA',
#  'GREENVILLE,  NORTH CAROLINA',
#  'MADBURY,  NEW HAMPSHIRE',
#  'CERRITOS,  CALIFORNIA',
#  'GARDEN GROVE,  CALIFORNIA',
#  'BROCKPORT,  NEW YORK',
#  'LAKE SUCCESS,  NEW YORK',
#  'BASKING RIDGE,  NEW JERSEY',
#  'CYPRESS,  TEXAS',
#  'OKEMOS,  MICHIGAN',
#  'D/FW AIRPORT,  TEXAS',
#  'STONY BROOK,  NEW YORK',
#  'PLAYA VISTA,  CALIFORNIA',
#  'STRASBURG,  VIRGINIA',
#  'FRISCO,  TEXAS',
#  'FT. DODGE,  IOWA',
#  'LONG BEACH,  CALIFORNIA',
#  'ROCKLIN,  CALIFORNIA',
#  'GROVEPORT,  OHIO',
#  'ROCKLEIGH,  NEW JERSEY',
#  'MARSHFIELD,  WISCONSIN',
#  'MOUNTAINVIEW,  CALIFORNIA',
#  'MARLBORO,  MASSACHUSETTS',
#  'PORT ST. LUCIE,  FLORIDA',
#  'RENSSELAER,  NEW YORK',
#  'GLEN MILLS,  PENNSYLVANIA',
#  'SPRING,  TEXAS',
#  'WARSAW,  INDIANA',
#  'WESTPORT,  CONNECTICUT',
#  'SUMNER,  WASHINGTON',
#  'CARROLLTON,  TEXAS',
#  'HIGHLANDS RANCH,  COLORADO',
#  'CHATSWORTH,  CALIFORNIA',
#  'AJO,  ARIZONA',
#  'ESSEX JUNCTION,  VERMONT',
#  'WILSONVILLE,  OREGON',
#  'FARMINGTON HILLS,  MICHIGAN',
#  'TAMUNING,  GU',
#  'PIMA,  ARIZONA',
#  'THE VILLAGE,  OKLAHOMA',
#  'EDMOND,  OKLAHOMA',
#  'TIGARD,  OREGON',
#  'WOODLAND HILLS,  CALIFORNIA',
#  'RUSSELLVILLE,  ARKANSAS',
#  'HERSHEY,  PENNSYLVANIA',
#  'BELLMORE,  NEW YORK',
#  'DAVIDSON,  NORTH CAROLINA',
#  'NORTH DARTMOUTH,  MASSACHUSETTS',
#  'DULUTH,  MINNESOTA',
#  'BALDWIN,  NEW YORK',
#  'POMPANO BEACH,  FLORIDA',
#  'SOUTHLAKE,  TEXAS',
#  'MONTGOMERYVILLE,  PENNSYLVANIA',
#  'WINTER PARK,  FLORIDA',
#  'COVINA,  CALIFORNIA',
#  'LIBERTY,  INDIANA',
#  'ROSEMEAD,  CALIFORNIA',
#  'MARYLAND HEIGHTS,  MISSOURI',
#  'MOUNTIAN VIEW,  CALIFORNIA',
#  'HACKETTSTOWN,  NEW JERSEY',
#  'STOUGHTON,  WISCONSIN',
#  'CHULA VISTA,  CALIFORNIA',
#  'VAN NUYS,  CALIFORNIA',
#  'WICHITA,  KANSAS',
#  'LAKEWAY,  TEXAS',
#  'WALL TOWNSHIP,  NEW JERSEY',
#  'WELLESLEY HILLS,  MASSACHUSETTS',
#  'TAYLOR,  MICHIGAN',
#  'ST. CHARLES,  ILLINOIS',
#  'PORTERVILLE,  CALIFORNIA',
#  'MANGILAO,  GU',
#  'LAFAYETTE,  LOUISIANA',
#  'UNIVERSITY PARK,  PENNSYLVANIA',
#  'MARYSVILLE,  OHIO',
#  'WATERTOWN,  CONNECTICUT',
#  'UNIONDALE,  NEW YORK',
#  'VERSAILLES,  KENTUCKY',
#  ...]

# %% [markdown]
# ### Correcting misspellings

# %% [markdown]
# Now that some silly mistakes have been taken out, I can move on to correct honest misspelling of words.

# %% [markdown]
# This spell checker is taken from here: http://norvig.com/spell-correct.html. It works based on probabilities and a full explanation can be found on that web page. To obtain probabilities, a hash table of work sites and their corresponding counts is required.
#
# I will begin by getting counts of each worksite.

# %%
# aggregate counts grouped by worksite
counts = h1b_data.groupby('WORKSITE').agg('count')

# %% [markdown]
# I will put the aggregated counts, sorted in descending order, into a tidy data frame. This is very easy with dplyr and magrittr and not so nice with pandas.

# %%
# sort vals of firsrt col
counts = pd.DataFrame(counts['CASE_NUMBER'].sort_values(ascending=False))
counts['SITE_COUNTS'] = counts['CASE_NUMBER'] # rename
counts = counts.drop(['CASE_NUMBER'], axis = 1) # drop old cols

# %% [markdown]
# Here are the top 10 worksites represented in these data:

# %%
counts.head(10)
# Out:
#                             SITE_COUNTS
# WORKSITE
# NEW YORK,  NEW YORK              228262
# HOUSTON,  TEXAS                   96781
# SAN FRANCISCO,  CALIFORNIA        78267
# CHICAGO,  ILLINOIS                62966
# ATLANTA,  GEORGIA                 62841
# SAN JOSE,  CALIFORNIA             60746
# SUNNYVALE,  CALIFORNIA            43115
# DALLAS,  TEXAS                    39451
# BOSTON,  MASSACHUSETTS            37984
# IRVING,  TEXAS                    37977

# %% [markdown]
# Next, I'll make a hash table of the sites and their corresponding counts.

# %%
sites_hash = counts.to_dict()

# %% [markdown]
# Now to import the spell checker from the website linked at the start of this section:

# %%
import re
from collections import Counter

def words(text): return re.findall(r'\w+', text.lower())

WORDS = Counter(words(open("C:/Users/nicho/Desktop/big data course proj/H-1B data/big.txt").read()))

def P(word, N=sum(WORDS.values())): 
    "Probability of `word`."
    return WORDS[word] / N

def correction(word): 
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

def candidates(word): 
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words): 
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)

def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
#site_count <- function(site, site_hash) {
  
#  if(site_hash$has_key(site)) {
#    return(site_hash[[site]])
#  }
#  return(site)
#}

# %%
def site_count(site, site_hash):
    if(site in site_hash):
        return site_hash[[site]]
    return site

# %%
temp = counts.reset_index(drop=False)
site_counts = pd.DataFrame()
site_counts = pd.concat([site_counts, temp[['WORKSITE', 'SITE_COUNTS']]], axis=1)

# %%
sites = site_counts['WORKSITE']
sites_before = []
sites_after = []
count = 0

# %%
for site in sites:
    #count of current worksite
    curr_count <- site_count(site, site_hash)
    
    if curr_count < 100: # threshold
        corrected = correction()

# %%
h1b_data.head()
# Out:
#           CASE_NUMBER          CASE_STATUS                  EMPLOYER_NAME  \
# 0  I-200-09124-371007            CERTIFIED   WILLISTON NORTHAMPTON SCHOOL
# 1  I-200-09125-717448            CERTIFIED                    NYFIX, INC.
# 2  I-200-09126-530125  CERTIFIED-WITHDRAWN  TGS-NOPEC GEOPHYSICAL COMPANY
# 3  I-200-09127-370154            CERTIFIED                AFREN USA, INC.
# 4  I-200-09127-334015            CERTIFIED                BA-INSIGHT, LLC
#
#                                     SOC_NAME    SOC_CODE  \
# 0       Teachers and Instructors, All Other*     25-3999
# 1  Computer Software Engineers, Applications  15-1031.00
# 2  Computer Software Engineers, Applications  15-1031.00
# 3                       Engineering Managers  11-9041.00
# 4               Computer Support Specialists  15-1041.00
#
#                                  JOB_TITLE FULL_TIME_POSITION  \
# 0                          CHINESE TEACHER                  Y
# 1                          PROJECT MANAGER                  Y
# 2  PRINCIPAL TRAINER / DEVELOPMENT ANALYST                  Y
# 3                         DRILLING MANAGER                  Y
# 4               TECHNICAL SUPPORT ENGINEER                  Y
#
#    PREVAILING_WAGE WORKSITE_STATE  YEAR                     WORKSITE
# 0         23350.00  massachusetts  2011  EASTHAMPTON,  MASSACHUSETTS
# 1        101088.00       new york  2011          NEW YORK,  NEW YORK
# 2         77480.00          texas  2011              HOUSTON,  TEXAS
# 3        165506.00          texas  2011        THE WOODLANDS,  TEXAS
# 4         62358.00  massachusetts  2011       BOSTON,  MASSACHUSETTS

# %%
# write to csv
h1b_data.to_csv("./Desktop/big data course proj/H-1B data/pregeo_encoding.csv", index = False)
